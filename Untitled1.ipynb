# %%
import itertools
import numpy as np
import random

from keras.models import Sequential
from keras.layers import LSTM,RepeatVector,Dense,Activation,Dropout
from keras.layers.wrappers import TimeDistributed,Bidirectional
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
# Out:
# D:\Anaconda3-4.2.0\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
CHARS = [str(n) for n in range(10)] + ['*','+','-', ' ', '\0']
CHAR_TO_INDEX = {i: c for c, i in enumerate(CHARS)}
INDEX_TO_CHAR = {c: i for c, i in enumerate(CHARS)}
          
MIN_NUMBER = 100
MAX_NUMBER = 999

MAX_N_EXAMPLES = (MAX_NUMBER - MIN_NUMBER) ** 2
N_EXAMPLES = 100000
N_FEATURES = len(CHARS)
MAX_NUMBER_LENGTH_LEFT_SIDE = len(str(MAX_NUMBER))
MAX_NUMBER_LENGTH_RIGHT_SIDE = MAX_NUMBER_LENGTH_LEFT_SIDE *2
MAX_EQUATION_LENGTH = (MAX_NUMBER_LENGTH_LEFT_SIDE * 2) + 4
MAX_RESULT_LENGTH = MAX_NUMBER_LENGTH_RIGHT_SIDE + 1

SPLIT = .1
EPOCHS = 500
LEARNING_RATE = 0.001
BATCH_SIZE = 256
HIDDEN_SIZE = 128
ENCODER_DEPTH = 1
DECODER_DEPTH = 1
DROPOUT = 0
BATCH_NORM = True

##模型参数设置：
##最新数字为100，最大数字为999.
##数字范围是 1798
##总共生成data 的数目为100000
##考虑到乘法的情况下将 MAX_NUMBER_LENGTH_LEFT_SIDE *2
##最大input长度是 15
##最大output长度是7

##模型参数设置
##encoder 和decoder 均为一层
##batch 为256
##hidden state 为128

# %%
def generate_equations(max_count=None):
        number_permutations=itertools.permutations(range(100,1000),2)
        if max_count is not None:
            number_permutations=itertools.islice(number_permutations,max_count)
        number_permutations=list(number_permutations)
        random.shuffle(number_permutations)
        for x,y in number_permutations:
            p=random.randint(1,2)
            if p==1:
                if x>y:
                    yield'{}-{}'.format(x,y)
                else:
                    yield'{}-{}'.format(y,x)
            if p==2:
                    yield'{}+{}'.format(x,y)
            if p==3 or p==4:
                    yield'{}*{}'.format(x,y)
 
##随机生成 范围为100-1000的eqution




def one_hot_to_index(vector):
    if not np.any(vector):
        return -1
    return np.argmax(vector)

def one_hot_to_char(vector):
    index=one_hot_to_index(vector)
    if index==-1:
        return''
    return INDEX_TO_CHAR[index]

def one_hot_to_string(matrix):
    return ''.join(one_hot_to_char(vector) for vector in matrix)              





def equations_to_x_y(equations,n):
     x=np.zeros((n,MAX_EQUATION_LENGTH,N_FEATURES),dtype=np.bool)
     y=np.zeros((n,MAX_RESULT_LENGTH,N_FEATURES),dtype=np.bool)             
     for i,equation in enumerate(itertools.islice(equations,n)):
         result=str(eval(equation))
         result=' ' *(MAX_RESULT_LENGTH-1-len(result))+result
         
         equation +='\0'
         result   +='\0'
         for t,char in enumerate(equation):
            x[i,t,CHAR_TO_INDEX[char]]=1
         for t,char in enumerate(result):
            y[i,t,CHAR_TO_INDEX[char]]=1
     return x,y
 
##eval and encode data to one-hot-vector
##such as data ”123+345“ we will get result string ”458“ and then get one-hot vector ”00010000000000 .......“



def build_dataset():
    generator=generate_equations(max_count=1000000)
    n_test=round(SPLIT*N_EXAMPLES)
    n_train=N_EXAMPLES-n_test
    
    x_test,y_test=equations_to_x_y(generator,n_test)
    x_train,y_train=equations_to_x_y(generator,n_train)
    
    x_train_name="C:/Users/hasee/Desktop/lstm-sub/x_train.txt"
    y_train_name="C:/Users/hasee/Desktop/lstm-sub/y_train.txt"
    x_test_name  ="C:/Users/hasee/Desktop/lstm-sub/x_test.txt"
    y_test_name="C:/Users/hasee/Desktop/lstm-sub/y_test.txt"
    
    p_train=np.reshape(x_train,[-1,N_FEATURES])
    q_train=np.reshape(y_train,[-1,N_FEATURES])
    p_test=np.reshape(x_test,[-1,N_FEATURES])
    q_test=np.reshape(y_test,[-1,N_FEATURES])
    
    np.savetxt(x_train_name,np.array(p_train),fmt="%s", delimiter=",")
    np.savetxt(y_train_name,np.array(q_train),fmt="%s", delimiter=",")
    np.savetxt(x_test_name, np.array(p_test), fmt="%s", delimiter=",")
    np.savetxt(y_test_name, np.array(q_test), fmt="%s", delimiter=",")
    
    
    return x_test,y_test,x_train,y_train

##build dataset 
##0.9 of example to train
##0.1 of example to validate

def print_example_prediction(count,model,x_test,y_test):
    print('Examples:')
    prediction_indices=np.random.choice(x_test.shape[0],size=count,replace=False)
    print(np.array(x_test[prediction_indices,:]).shape)
    predictions=model.predict(x_test[prediction_indices,:])
    for i in range(count): 
        correct=one_hot_to_string(y_test[prediction_indices[i]])
        guess=one_hot_to_string(predictions[i])
        
        print('Q {} - {} '.format(one_hot_to_string(x_test[prediction_indices[i]]),one_hot_to_string(predictions[i])),end=' ')
        print('T', correct, end=' ')  
        if correct == guess:
            print( 'ok',end=' ')
        else:
            print( 'not ok',end=' ')
        print('\n')
      
        
def build_model():
    """
    Builds and returns the model based on the global config.
    """
    input_shape = (MAX_EQUATION_LENGTH, N_FEATURES)

    model = Sequential()

    # Encoder:
    model.add(Bidirectional(LSTM(20), input_shape=input_shape))
    model.add(BatchNormalization())

    # The RepeatVector-layer repeats the input n times
    model.add(RepeatVector(MAX_RESULT_LENGTH))

    # Decoder:
    model.add(Bidirectional(LSTM(20, return_sequences=True)))
    model.add(BatchNormalization())

    model.add(TimeDistributed(Dense(N_FEATURES)))
    model.add(Activation('softmax'))

    model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(lr=0.01),
        metrics=['accuracy'],
    )

    return model


### build model
### we choose a seq2seq model
### Sequence to sequence learning deals with problems in which a source sequence of inputs 
### has to be mapped to a target sequence of outputs where each output is not necessarily directly dependent on a single input. 
### The classical example is translation.How do you learn that a Chinese input phrase “他现在已经在路上了。” 
### equals “She is on her way.” in English?

###an encoder based on RNNs learns an abstract representation.
###Then a decoder also based on RNNs learns to decode it to another language, 
###generating a new sequence from the encoding as output.

###I choose a Bidirectional Lstm as encoder and decoder.
###After them,a fully connected layer help me to get result which have the same length as ground-truth

# %%
def main():
     
    
    
    model=build_model()
    model.summary()
    print()    
    
    x_test,y_test,x_train,y_train=build_dataset()
    
    print()
    print_example_prediction(5,model,x_test,y_test)
    print()
    
    for iteration in range(100):
        print()
        print('-'*50)
        print('Iteration',iteration)
        model.fit(x_train, y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(x_test, y_test))
        print_example_prediction(10,model,x_test,y_test)
        model.save('my_model.h5')
        
        
###first experiment get add and sub  together

# %% [markdown]
# main()

# %%
def generate_equations_three_sum(max_count=None):
        number_permutations=itertools.permutations(range(100,1000),2)
        if max_count is not None:
            number_permutations=itertools.islice(number_permutations,max_count)
        number_permutations=list(number_permutations)
        random.shuffle(number_permutations)
        for x,y in number_permutations:
            z=random.randint(100,1000)
            yield'{}+{}+{}'.format(x,y,z)

# %%
import itertools
import numpy as np
import random

from keras.models import Sequential
from keras.layers import LSTM,RepeatVector,Dense,Activation,Dropout
from keras.layers.wrappers import TimeDistributed,Bidirectional
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint

MIN_NUMBER = 100
MAX_NUMBER = 999

CHARS = [str(n) for n in range(10)] + ['*','+','-', ' ', '\0']
CHAR_TO_INDEX = {i: c for c, i in enumerate(CHARS)}
INDEX_TO_CHAR = {c: i for c, i in enumerate(CHARS)}

MAX_N_EXAMPLES = (MAX_NUMBER - MIN_NUMBER) ** 2
N_EXAMPLES = 30000
N_FEATURES = len(CHARS)
MAX_NUMBER_LENGTH_LEFT_SIDE = len(str(MAX_NUMBER))
MAX_NUMBER_LENGTH_RIGHT_SIDE = MAX_NUMBER_LENGTH_LEFT_SIDE *2
MAX_EQUATION_LENGTH = (MAX_NUMBER_LENGTH_LEFT_SIDE * 3) + 4
MAX_RESULT_LENGTH = MAX_NUMBER_LENGTH_RIGHT_SIDE + 1

SPLIT = .1
EPOCHS = 500
LEARNING_RATE = 0.001
BATCH_SIZE = 256
HIDDEN_SIZE = 128
ENCODER_DEPTH = 1
DECODER_DEPTH = 1
DROPOUT = 0
BATCH_NORM = True
# Out:
# D:\Anaconda3-4.2.0\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def build_dataset_three_sum():
    generator=generate_equations_three_sum(max_count=1000000)
    n_test=round(SPLIT*N_EXAMPLES)
    n_train=N_EXAMPLES-n_test
    
    x_test,y_test=equations_to_x_y(generator,n_test)
    x_train,y_train=equations_to_x_y(generator,n_train)
    
 
    
    
    return x_test,y_test,x_train,y_train

# %%
def main2():
     
    
    
    model=build_model()
    model.summary()
    print()    
    
    x_test,y_test,x_train,y_train=build_dataset_three_sum()
    
    print()
    print_example_prediction(5,model,x_test,y_test)
    print()
    
    for iteration in range(300):
        print()
        print('-'*50)
        print('Iteration',iteration)
        model.fit(x_train, y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(x_test, y_test))
        print_example_prediction(10,model,x_test,y_test)

# %%
def generate_equations(max_count=None):
        number_permutations=itertools.permutations(range(100,1000),2)
        if max_count is not None:
            number_permutations=itertools.islice(number_permutations,max_count)
        number_permutations=list(number_permutations)
        random.shuffle(number_permutations)
        for x,y in number_permutations:
            p=random.randint(1,2)
            if p==1:
                if x>y:
                    yield'{}-{}'.format(x,y)
                else:
                    yield'{}-{}'.format(y,x)
            if p==2:
                    yield'{}+{}'.format(x,y)
            if p==3 or p==4:
                    yield'{}*{}'.format(x,y)
 

def one_hot_to_index(vector):
    if not np.any(vector):
        return -1
    return np.argmax(vector)

def one_hot_to_char(vector):
    index=one_hot_to_index(vector)
    if index==-1:
        return''
    return INDEX_TO_CHAR[index]

def one_hot_to_string(matrix):
    return ''.join(one_hot_to_char(vector) for vector in matrix)              
                
def equations_to_x_y(equations,n):
     x=np.zeros((n,MAX_EQUATION_LENGTH,N_FEATURES),dtype=np.bool)
     y=np.zeros((n,MAX_RESULT_LENGTH,N_FEATURES),dtype=np.bool)             
     for i,equation in enumerate(itertools.islice(equations,n)):
         result=str(eval(equation))
         result=' ' *(MAX_RESULT_LENGTH-1-len(result))+result
         
         equation +='\0'
         result   +='\0'
         for t,char in enumerate(equation):
            x[i,t,CHAR_TO_INDEX[char]]=1
         for t,char in enumerate(result):
            y[i,t,CHAR_TO_INDEX[char]]=1
     return x,y
     
def build_dataset():
    generator=generate_equations(max_count=1000000)
    n_test=round(SPLIT*N_EXAMPLES)
    n_train=N_EXAMPLES-n_test
    
    x_test,y_test=equations_to_x_y(generator,n_test)
    x_train,y_train=equations_to_x_y(generator,n_train)
    
    x_train_name="C:/Users/hasee/Desktop/lstm-sub/x_train.txt"
    y_train_name="C:/Users/hasee/Desktop/lstm-sub/y_train.txt"
    x_test_name  ="C:/Users/hasee/Desktop/lstm-sub/x_test.txt"
    y_test_name="C:/Users/hasee/Desktop/lstm-sub/y_test.txt"
    
    p_train=np.reshape(x_train,[-1,N_FEATURES])
    q_train=np.reshape(y_train,[-1,N_FEATURES])
    p_test=np.reshape(x_test,[-1,N_FEATURES])
    q_test=np.reshape(y_test,[-1,N_FEATURES])
    
    np.savetxt(x_train_name,np.array(p_train),fmt="%s", delimiter=",")
    np.savetxt(y_train_name,np.array(q_train),fmt="%s", delimiter=",")
    np.savetxt(x_test_name, np.array(p_test), fmt="%s", delimiter=",")
    np.savetxt(y_test_name, np.array(q_test), fmt="%s", delimiter=",")
    
    
    return x_test,y_test,x_train,y_train
    
def print_example_prediction(count,model,x_test,y_test):
    print('Examples:')
    prediction_indices=np.random.choice(x_test.shape[0],size=count,replace=False)
    print(np.array(x_test[prediction_indices,:]).shape)
    predictions=model.predict(x_test[prediction_indices,:])
    for i in range(count): 
        correct=one_hot_to_string(y_test[prediction_indices[i]])
        guess=one_hot_to_string(predictions[i])
        
        print('Q {} - {} '.format(one_hot_to_string(x_test[prediction_indices[i]]),one_hot_to_string(predictions[i])),end=' ')
        print('T', correct, end=' ')  
        if correct == guess:
            print( 'ok',end=' ')
        else:
            print( 'not ok',end=' ')
        print('\n')
      
        
def build_model():
    """
    Builds and returns the model based on the global config.
    """
    input_shape = (MAX_EQUATION_LENGTH, N_FEATURES)

    model = Sequential()

    # Encoder:
    model.add(Bidirectional(LSTM(20), input_shape=input_shape))
    model.add(BatchNormalization())

    # The RepeatVector-layer repeats the input n times
    model.add(RepeatVector(MAX_RESULT_LENGTH))

    # Decoder:
    model.add(Bidirectional(LSTM(20, return_sequences=True)))
    model.add(BatchNormalization())

    model.add(TimeDistributed(Dense(N_FEATURES)))
    model.add(Activation('softmax'))

    model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(lr=0.01),
        metrics=['accuracy'],
    )

    return model

# %%
main2()
###第二个实验，将数字增加为3个.
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 40)                5760
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40)                160
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 7, 40)             0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 7, 40)             9760
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 7, 40)             160
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 7, 15)             615
# _________________________________________________________________
# activation_1 (Activation)    (None, 7, 15)             0
# =================================================================
# Total params: 16,455
# Trainable params: 16,295
# Non-trainable params: 160
# _________________________________________________________________
#
#
# Examples:
# (5, 13, 15)
# Q 839+473+192 - 7033333  T   1504 not ok
#
# Q 932+612+506 - 0099999  T   2050 not ok
#
# Q 143+214+105 - 7777777  T    462 not ok
#
# Q 247+998+407 - 000007   T   1652 not ok
#
# Q 179+381+552 - 7777777  T   1112 not ok
#
#
#
# --------------------------------------------------
# Iteration 0
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 10s 363us/step - loss: 1.3346 - acc: 0.5287 - val_loss: 2.2206 - val_acc: 0.2834
# Examples:
# (10, 13, 15)
# Q 911+567+224 -  111112  T   1702 not ok
#
# Q 162+303+280 -  111112  T    745 not ok
#
# Q 855+534+378 -  111112  T   1767 not ok
#
# Q 527+265+667 -  111112  T   1459 not ok
#
# Q 944+729+706 -  111112  T   2379 not ok
#
# Q 958+447+225 -  111112  T   1630 not ok
#
# Q 369+906+883 -  111112  T   2158 not ok
#
# Q 549+224+422 -  111112  T   1195 not ok
#
# Q 899+729+431 -  111112  T   2059 not ok
#
# Q 174+895+483 -  111112  T   1552 not ok
#
#
# --------------------------------------------------
# Iteration 1
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 262us/step - loss: 0.9390 - acc: 0.6405 - val_loss: 1.6995 - val_acc: 0.5048
# Examples:
# (10, 13, 15)
# Q 433+654+984 -   19110  T   2071 not ok
#
# Q 778+214+941 -   19110  T   1933 not ok
#
# Q 755+939+188 -   18110  T   1882 not ok
#
# Q 869+257+766 -   1811  T   1892 not ok
#
# Q 957+313+466 -   1711  T   1736 not ok
#
# Q 499+357+683 -   1711  T   1539 not ok
#
# Q 344+276+897 -   1711  T   1517 not ok
#
# Q 449+434+501 -   1611  T   1384 not ok
#
# Q 147+155+768 -   1611  T   1070 not ok
#
# Q 787+888+640 -   19110  T   2315 not ok
#
#
# --------------------------------------------------
# Iteration 2
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 279us/step - loss: 0.8401 - acc: 0.6703 - val_loss: 1.5907 - val_acc: 0.5774
# Examples:
# (10, 13, 15)
# Q 115+520+972 -   1610  T   1607 not ok
#
# Q 163+595+630 -   1510  T   1388 not ok
#
# Q 860+968+996 -   2030  T   2824 not ok
#
# Q 947+311+948 -   1810  T   2206 not ok
#
# Q 506+891+374 -   1610  T   1771 not ok
#
# Q 764+278+668 -   1610  T   1710 not ok
#
# Q 893+994+684 -   1030  T   2571 not ok
#
# Q 492+151+424 -   1430  T   1067 not ok
#
# Q 150+191+888 -   1410  T   1229 not ok
#
# Q 915+254+161 -   1410  T   1330 not ok
#
#
# --------------------------------------------------
# Iteration 3
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 265us/step - loss: 0.8075 - acc: 0.6842 - val_loss: 1.4156 - val_acc: 0.5991
# Examples:
# (10, 13, 15)
# Q 627+205+736 -   1563  T   1568 not ok
#
# Q 498+890+957 -   2063  T   2345 not ok
#
# Q 812+902+872 -   2137  T   2586 not ok
#
# Q 676+627+272 -   1563  T   1575 not ok
#
# Q 797+844+169 -   1763  T   1810 not ok
#
# Q 624+868+583 -   1863  T   2075 not ok
#
# Q 738+533+622 -   1863  T   1893 not ok
#
# Q 300+391+389 -   1331  T   1080 not ok
#
# Q 141+767+524 -   1513  T   1432 not ok
#
# Q 378+671+881 -   1863  T   1930 not ok
#
#
# --------------------------------------------------
# Iteration 4
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 263us/step - loss: 0.7964 - acc: 0.6877 - val_loss: 1.0877 - val_acc: 0.6182
# Examples:
# (10, 13, 15)
# Q 933+471+530 -   1899  T   1934 not ok
#
# Q 893+859+404 -   1949  T   2156 not ok
#
# Q 186+482+755 -   1479  T   1423 not ok
#
# Q 335+543+460 -   1349  T   1338 not ok
#
# Q 218+443+985 -   1699  T   1646 not ok
#
# Q 291+480+220 -   1199  T    991 not ok
#
# Q 810+106+132 -   1199  T   1048 not ok
#
# Q 147+155+768 -   1199  T   1070 not ok
#
# Q 958+960+410 -   2159  T   2328 not ok
#
# Q 822+474+921 -   2049  T   2217 not ok
#
#
# --------------------------------------------------
# Iteration 5
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 259us/step - loss: 0.8014 - acc: 0.6837 - val_loss: 0.9002 - val_acc: 0.6372
# Examples:
# (10, 13, 15)
# Q 921+722+163 -   1733  T   1806 not ok
#
# Q 804+332+857 -   1835  T   1993 not ok
#
# Q 421+364+342 -   1008  T   1127 not ok
#
# Q 858+433+815 -   1055  T   2106 not ok
#
# Q 136+609+102 -    800  T    847 not ok
#
# Q 695+811+115 -   1533  T   1621 not ok
#
# Q 336+478+831 -   1533  T   1645 not ok
#
# Q 723+157+596 -   1479  T   1476 not ok
#
# Q 380+923+295 -   1553  T   1598 not ok
#
# Q 539+819+561 -   1835  T   1919 not ok
#
#
# --------------------------------------------------
# Iteration 6
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 261us/step - loss: 0.7839 - acc: 0.6932 - val_loss: 0.9564 - val_acc: 0.6149
# Examples:
# (10, 13, 15)
# Q 443+427+366 -   1333  T   1236 not ok
#
# Q 884+616+895 -   2443  T   2395 not ok
#
# Q 943+889+375 -   2314  T   2207 not ok
#
# Q 611+676+204 -   1533  T   1491 not ok
#
# Q 982+700+631 -   2444  T   2313 not ok
#
# Q 890+613+910 -   2443  T   2413 not ok
#
# Q 646+651+946 -   2314  T   2243 not ok
#
# Q 213+119+874 -   1333  T   1206 not ok
#
# Q 338+908+160 -   1433  T   1406 not ok
#
# Q 707+383+709 -   1833  T   1799 not ok
#
#
# --------------------------------------------------
# Iteration 7
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 260us/step - loss: 0.8004 - acc: 0.6837 - val_loss: 0.7964 - val_acc: 0.6944
# Examples:
# (10, 13, 15)
# Q 547+286+210 -    955  T   1043 not ok
#
# Q 417+525+195 -   1055  T   1137 not ok
#
# Q 274+135+191 -    655  T    600 not ok
#
# Q 444+801+867 -   2194  T   2112 not ok
#
# Q 714+902+354 -   1957  T   1970 not ok
#
# Q 798+522+337 -   1673  T   1657 not ok
#
# Q 746+169+519 -   1433  T   1434 not ok
#
# Q 108+805+329 -   1155  T   1242 not ok
#
# Q 795+949+730 -   2443  T   2474 not ok
#
# Q 299+475+488 -   1155  T   1262 not ok
#
#
# --------------------------------------------------
# Iteration 8
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 260us/step - loss: 0.7740 - acc: 0.6957 - val_loss: 0.8927 - val_acc: 0.6438
# Examples:
# (10, 13, 15)
# Q 317+553+786 -   1666  T   1656 not ok
#
# Q 412+583+818 -   1746  T   1813 not ok
#
# Q 369+410+615 -   1234  T   1394 not ok
#
# Q 625+733+115 -   1444  T   1473 not ok
#
# Q 217+422+950 -   1568  T   1589 not ok
#
# Q 147+691+356 -   1107  T   1194 not ok
#
# Q 534+851+129 -   1448  T   1514 not ok
#
# Q 117+772+332 -   1108  T   1221 not ok
#
# Q 953+311+690 -   1934  T   1954 not ok
#
# Q 738+277+650 -   1558  T   1665 not ok
#
#
# --------------------------------------------------
# Iteration 9
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 258us/step - loss: 0.7829 - acc: 0.6918 - val_loss: 0.8093 - val_acc: 0.6755
# Examples:
# (10, 13, 15)
# Q 541+339+950 -   1844  T   1830 not ok
#
# Q 261+232+296 -    722  T    789 not ok
#
# Q 943+567+106 -   1634  T   1616 not ok
#
# Q 583+349+692 -   1604  T   1624 not ok
#
# Q 378+448+858 -   1744  T   1684 not ok
#
# Q 926+205+805 -   1934  T   1936 not ok
#
# Q 301+196+207 -    622  T    704 not ok
#
# Q 608+947+734 -   2444  T   2289 not ok
#
# Q 971+875+431 -   2344  T   2277 not ok
#
# Q 102+180+970 -   1214  T   1252 not ok
#
#
# --------------------------------------------------
# Iteration 10
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 259us/step - loss: 0.7708 - acc: 0.6955 - val_loss: 1.3818 - val_acc: 0.5889
# Examples:
# (10, 13, 15)
# Q 639+444+960 -   1889  T   2043 not ok
#
# Q 164+319+961 -   1328  T   1444 not ok
#
# Q 824+218+717 -   1688  T   1759 not ok
#
# Q 201+793+544 -   1388  T   1538 not ok
#
# Q 466+330+912 -   1588  T   1708 not ok
#
# Q 688+438+494 -   1488  T   1620 not ok
#
# Q 360+206+768 -   1287  T   1334 not ok
#
# Q 290+275+840 -   1227  T   1405 not ok
#
# Q 750+808+771 -   2199  T   2329 not ok
#
# Q 550+495+215 -   1177  T   1260 not ok
#
#
# --------------------------------------------------
# Iteration 11
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 255us/step - loss: 0.7759 - acc: 0.6947 - val_loss: 0.7714 - val_acc: 0.6960
# Examples:
# (10, 13, 15)
# Q 590+857+456 -   1935  T   1903 not ok
#
# Q 126+131+697 -    832  T    954 not ok
#
# Q 336+974+609 -   1936  T   1919 not ok
#
# Q 130+544+820 -   1433  T   1494 not ok
#
# Q 705+329+926 -   1935  T   1960 not ok
#
# Q 421+663+107 -   1122  T   1191 not ok
#
# Q 723+547+424 -   1633  T   1694 not ok
#
# Q 878+595+786 -   2355  T   2259 not ok
#
# Q 300+700+326 -   1322  T   1326 not ok
#
# Q 950+453+979 -   2305  T   2382 not ok
#
#
# --------------------------------------------------
# Iteration 12
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 258us/step - loss: 0.7785 - acc: 0.6937 - val_loss: 0.9408 - val_acc: 0.6402
# Examples:
# (10, 13, 15)
# Q 786+622+276 -   1753  T   1684 not ok
#
# Q 205+219+375 -    742  T    799 not ok
#
# Q 393+897+643 -   2033  T   1933 not ok
#
# Q 555+348+847 -   1855  T   1750 not ok
#
# Q 387+147+721 -   1224  T   1255 not ok
#
# Q 490+635+570 -   1756  T   1695 not ok
#
# Q 770+455+431 -   1653  T   1656 not ok
#
# Q 786+921+521 -   2333  T   2228 not ok
#
# Q 223+215+821 -   1224  T   1259 not ok
#
# Q 744+505+597 -   1933  T   1846 not ok
#
#
# --------------------------------------------------
# Iteration 13
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 273us/step - loss: 0.7740 - acc: 0.6953 - val_loss: 0.8638 - val_acc: 0.6611
# Examples:
# (10, 13, 15)
# Q 695+839+940 -   2542  T   2474 not ok
#
# Q 519+179+756 -   1400  T   1454 not ok
#
# Q 681+112+145 -    762  T    938 not ok
#
# Q 301+264+354 -    872  T    919 not ok
#
# Q 832+799+704 -   2442  T   2335 not ok
#
# Q 594+867+129 -   1590  T   1590 ok
#
# Q 290+275+840 -   1327  T   1405 not ok
#
# Q 760+353+584 -   1779  T   1697 not ok
#
# Q 533+244+909 -   1679  T   1686 not ok
#
# Q 925+883+445 -   2310  T   2253 not ok
#
#
# --------------------------------------------------
# Iteration 14
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 268us/step - loss: 0.7888 - acc: 0.6896 - val_loss: 0.9288 - val_acc: 0.6199
# Examples:
# (10, 13, 15)
# Q 434+240+652 -   1344  T   1326 not ok
#
# Q 796+539+635 -   2044  T   1970 not ok
#
# Q 962+222+932 -   2255  T   2116 not ok
#
# Q 206+470+361 -   1055  T   1037 not ok
#
# Q 164+319+961 -   1444  T   1444 ok
#
# Q 560+313+412 -   1345  T   1285 not ok
#
# Q 880+374+963 -   2354  T   2217 not ok
#
# Q 989+791+186 -   2055  T   1966 not ok
#
# Q 178+674+825 -   1784  T   1677 not ok
#
# Q 201+741+126 -   1155  T   1068 not ok
#
#
# --------------------------------------------------
# Iteration 15
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 273us/step - loss: 0.7671 - acc: 0.6978 - val_loss: 0.7521 - val_acc: 0.6988
# Examples:
# (10, 13, 15)
# Q 657+273+861 -   1780  T   1791 not ok
#
# Q 656+646+610 -   1990  T   1912 not ok
#
# Q 922+659+212 -   1889  T   1793 not ok
#
# Q 847+499+577 -   1998  T   1923 not ok
#
# Q 394+690+573 -   1699  T   1657 not ok
#
# Q 251+902+792 -   1999  T   1945 not ok
#
# Q 761+785+511 -   2090  T   2057 not ok
#
# Q 652+638+367 -   1695  T   1657 not ok
#
# Q 957+313+466 -   1785  T   1736 not ok
#
# Q 336+742+346 -   1471  T   1424 not ok
#
#
# --------------------------------------------------
# Iteration 16
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 275us/step - loss: 0.7650 - acc: 0.6992 - val_loss: 0.8868 - val_acc: 0.6420
# Examples:
# (10, 13, 15)
# Q 619+340+723 -   1663  T   1682 not ok
#
# Q 338+908+160 -   1322  T   1406 not ok
#
# Q 761+183+542 -   1433  T   1486 not ok
#
# Q 478+493+337 -   1222  T   1308 not ok
#
# Q 947+544+678 -   2062  T   2169 not ok
#
# Q 573+279+784 -   1558  T   1636 not ok
#
# Q 809+918+859 -   2512  T   2586 not ok
#
# Q 144+241+821 -   1122  T   1206 not ok
#
# Q 193+529+790 -   1438  T   1512 not ok
#
# Q 634+922+207 -   1663  T   1763 not ok
#
#
# --------------------------------------------------
# Iteration 17
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 267us/step - loss: 0.7767 - acc: 0.6938 - val_loss: 0.7626 - val_acc: 0.6960
# Examples:
# (10, 13, 15)
# Q 860+449+345 -   1619  T   1654 not ok
#
# Q 925+883+445 -   2212  T   2253 not ok
#
# Q 911+319+814 -   2029  T   2044 not ok
#
# Q 488+991+489 -   2029  T   1968 not ok
#
# Q 259+298+342 -    952  T    899 not ok
#
# Q 615+587+910 -   2122  T   2112 not ok
#
# Q 412+288+142 -    852  T    842 not ok
#
# Q 381+398+133 -    978  T    912 not ok
#
# Q 449+906+416 -   1719  T   1771 not ok
#
# Q 379+614+670 -   1611  T   1663 not ok
#
#
# --------------------------------------------------
# Iteration 18
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 283us/step - loss: 0.7686 - acc: 0.6982 - val_loss: 0.7767 - val_acc: 0.6837
# Examples:
# (10, 13, 15)
# Q 929+585+173 -   1613  T   1687 not ok
#
# Q 507+775+523 -   1713  T   1805 not ok
#
# Q 911+491+741 -   2128  T   2143 not ok
#
# Q 556+591+499 -   1613  T   1646 not ok
#
# Q 856+163+224 -   1233  T   1243 not ok
#
# Q 963+246+580 -   1713  T   1789 not ok
#
# Q 586+934+422 -   1811  T   1942 not ok
#
# Q 964+590+166 -   1613  T   1720 not ok
#
# Q 604+715+324 -   1613  T   1643 not ok
#
# Q 328+987+185 -   1411  T   1500 not ok
#
#
# --------------------------------------------------
# Iteration 19
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 271us/step - loss: 0.7838 - acc: 0.6901 - val_loss: 0.8703 - val_acc: 0.6461
# Examples:
# (10, 13, 15)
# Q 664+103+394 -   1209  T   1161 not ok
#
# Q 525+887+311 -   1799  T   1723 not ok
#
# Q 964+548+621 -   2199  T   2133 not ok
#
# Q 968+832+215 -   2099  T   2015 not ok
#
# Q 820+397+345 -   1599  T   1562 not ok
#
# Q 109+456+746 -   1329  T   1311 not ok
#
# Q 738+601+402 -   1799  T   1741 not ok
#
# Q 547+286+210 -   1199  T   1043 not ok
#
# Q 144+406+227 -    830  T    777 not ok
#
# Q 837+635+649 -   2299  T   2121 not ok
#
#
# --------------------------------------------------
# Iteration 20
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 284us/step - loss: 0.7603 - acc: 0.7025 - val_loss: 0.9596 - val_acc: 0.6175
# Examples:
# (10, 13, 15)
# Q 484+408+706 -   1500  T   1598 not ok
#
# Q 356+612+365 -   1227  T   1333 not ok
#
# Q 334+289+674 -   1227  T   1297 not ok
#
# Q 376+331+624 -   1207  T   1331 not ok
#
# Q 578+518+309 -   1327  T   1405 not ok
#
# Q 169+703+684 -   1408  T   1556 not ok
#
# Q 982+897+772 -   2645  T   2651 not ok
#
# Q 328+987+185 -   1322  T   1500 not ok
#
# Q 528+424+330 -   1227  T   1282 not ok
#
# Q 778+281+947 -   1900  T   2006 not ok
#
#
# --------------------------------------------------
# Iteration 21
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 267us/step - loss: 0.7657 - acc: 0.6990 - val_loss: 0.8402 - val_acc: 0.6645
# Examples:
# (10, 13, 15)
# Q 880+100+816 -   1888  T   1796 not ok
#
# Q 421+364+342 -   1104  T   1127 not ok
#
# Q 474+167+708 -   1314  T   1349 not ok
#
# Q 642+612+818 -   2166  T   2072 not ok
#
# Q 803+448+283 -   1564  T   1534 not ok
#
# Q 502+813+306 -   1664  T   1621 not ok
#
# Q 884+223+184 -   1385  T   1291 not ok
#
# Q 573+767+533 -   1968  T   1873 not ok
#
# Q 174+895+483 -   1664  T   1552 not ok
#
# Q 410+313+853 -   1664  T   1576 not ok
#
#
# --------------------------------------------------
# Iteration 22
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 267us/step - loss: 0.7594 - acc: 0.7017 - val_loss: 0.7616 - val_acc: 0.6956
# Examples:
# (10, 13, 15)
# Q 666+921+683 -   2377  T   2270 not ok
#
# Q 107+112+803 -    977  T   1022 not ok
#
# Q 502+813+306 -   1666  T   1621 not ok
#
# Q 285+494+510 -   1267  T   1289 not ok
#
# Q 616+368+965 -   1977  T   1949 not ok
#
# Q 771+872+381 -   2077  T   2024 not ok
#
# Q 144+241+821 -   1157  T   1206 not ok
#
# Q 325+360+977 -   1666  T   1662 not ok
#
# Q 166+101+250 -    548  T    517 not ok
#
# Q 188+156+305 -    598  T    649 not ok
#
#
# --------------------------------------------------
# Iteration 23
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 278us/step - loss: 0.7690 - acc: 0.6976 - val_loss: 0.9087 - val_acc: 0.6380
# Examples:
# (10, 13, 15)
# Q 699+865+177 -   1688  T   1741 not ok
#
# Q 164+319+961 -   1428  T   1444 not ok
#
# Q 899+205+777 -   1811  T   1881 not ok
#
# Q 291+426+272 -    944  T    989 not ok
#
# Q 854+139+986 -   1800  T   1979 not ok
#
# Q 586+915+610 -   2082  T   2111 not ok
#
# Q 530+915+872 -   2120  T   2317 not ok
#
# Q 185+270+441 -    842  T    896 not ok
#
# Q 779+784+920 -   2300  T   2483 not ok
#
# Q 309+497+497 -   1204  T   1303 not ok
#
#
# --------------------------------------------------
# Iteration 24
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 275us/step - loss: 0.7664 - acc: 0.6979 - val_loss: 1.0236 - val_acc: 0.6175
# Examples:
# (10, 13, 15)
# Q 801+162+349 -   1326  T   1312 not ok
#
# Q 547+587+845 -   2047  T   1979 not ok
#
# Q 161+573+709 -   1526  T   1443 not ok
#
# Q 508+460+493 -   1566  T   1461 not ok
#
# Q 756+204+349 -   1320  T   1309 not ok
#
# Q 992+740+965 -   2728  T   2697 not ok
#
# Q 385+999+434 -   1944  T   1818 not ok
#
# Q 229+438+348 -   1064  T   1015 not ok
#
# Q 817+926+199 -   2040  T   1942 not ok
#
# Q 807+593+170 -   1624  T   1570 not ok
#
#
# --------------------------------------------------
# Iteration 25
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 266us/step - loss: 0.7530 - acc: 0.7051 - val_loss: 0.7425 - val_acc: 0.7069
# Examples:
# (10, 13, 15)
# Q 444+860+436 -   1758  T   1740 not ok
#
# Q 223+215+821 -   1244  T   1259 not ok
#
# Q 407+103+937 -   1448  T   1447 not ok
#
# Q 934+320+811 -   2066  T   2065 not ok
#
# Q 466+330+912 -   1658  T   1708 not ok
#
# Q 463+395+984 -   1888  T   1842 not ok
#
# Q 677+983+611 -   2397  T   2271 not ok
#
# Q 979+406+771 -   2155  T   2156 not ok
#
# Q 175+319+735 -   1244  T   1229 not ok
#
# Q 249+980+905 -   2166  T   2134 not ok
#
#
# --------------------------------------------------
# Iteration 26
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 291us/step - loss: 0.7627 - acc: 0.7008 - val_loss: 0.7765 - val_acc: 0.6912
# Examples:
# (10, 13, 15)
# Q 632+659+496 -   1788  T   1787 not ok
#
# Q 120+779+706 -   1588  T   1605 not ok
#
# Q 162+418+852 -   1387  T   1432 not ok
#
# Q 508+460+493 -   1488  T   1461 not ok
#
# Q 357+316+446 -   1054  T   1119 not ok
#
# Q 503+992+225 -   1688  T   1720 not ok
#
# Q 519+978+812 -   2399  T   2309 not ok
#
# Q 529+619+320 -   1487  T   1468 not ok
#
# Q 113+249+846 -   1164  T   1208 not ok
#
# Q 224+823+315 -   1387  T   1362 not ok
#
#
# --------------------------------------------------
# Iteration 27
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 275us/step - loss: 0.7627 - acc: 0.7002 - val_loss: 0.7676 - val_acc: 0.6893
# Examples:
# (10, 13, 15)
# Q 714+940+433 -   2038  T   2087 not ok
#
# Q 300+517+522 -   1322  T   1339 not ok
#
# Q 951+616+130 -   1633  T   1697 not ok
#
# Q 744+932+712 -   2388  T   2388 ok
#
# Q 770+153+851 -   1782  T   1774 not ok
#
# Q 936+236+626 -   1711  T   1798 not ok
#
# Q 454+843+789 -   2039  T   2086 not ok
#
# Q 205+170+835 -   1122  T   1210 not ok
#
# Q 503+992+225 -   1683  T   1720 not ok
#
# Q 922+127+242 -   1232  T   1291 not ok
#
#
# --------------------------------------------------
# Iteration 28
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 276us/step - loss: 0.7570 - acc: 0.7026 - val_loss: 0.8536 - val_acc: 0.6526
# Examples:
# (10, 13, 15)
# Q 488+587+293 -   1322  T   1368 not ok
#
# Q 514+379+849 -   1646  T   1742 not ok
#
# Q 335+543+460 -   1225  T   1338 not ok
#
# Q 786+622+276 -   1655  T   1684 not ok
#
# Q 308+488+704 -   1442  T   1500 not ok
#
# Q 159+630+590 -   1355  T   1379 not ok
#
# Q 508+460+493 -   1442  T   1461 not ok
#
# Q 540+572+265 -   1355  T   1377 not ok
#
# Q 237+712+210 -   1100  T   1159 not ok
#
# Q 794+541+218 -   1432  T   1553 not ok
#
#
# --------------------------------------------------
# Iteration 29
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 279us/step - loss: 0.7526 - acc: 0.7055 - val_loss: 0.7590 - val_acc: 0.6990
# Examples:
# (10, 13, 15)
# Q 625+733+115 -   1430  T   1473 not ok
#
# Q 961+796+639 -   2355  T   2396 not ok
#
# Q 723+775+848 -   2365  T   2346 not ok
#
# Q 120+593+874 -   1569  T   1587 not ok
#
# Q 152+362+674 -   1114  T   1188 not ok
#
# Q 406+676+151 -   1200  T   1233 not ok
#
# Q 512+571+956 -   2059  T   2039 not ok
#
# Q 212+469+726 -   1300  T   1407 not ok
#
# Q 254+550+174 -    988  T    978 not ok
#
# Q 113+763+162 -   1008  T   1038 not ok
#
#
# --------------------------------------------------
# Iteration 30
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 285us/step - loss: 0.7591 - acc: 0.7021 - val_loss: 0.9141 - val_acc: 0.6420
# Examples:
# (10, 13, 15)
# Q 428+796+558 -   1828  T   1782 not ok
#
# Q 606+877+375 -   1944  T   1858 not ok
#
# Q 273+348+788 -   1442  T   1409 not ok
#
# Q 375+242+518 -   1107  T   1135 not ok
#
# Q 257+814+997 -   2179  T   2068 not ok
#
# Q 113+763+162 -   1067  T   1038 not ok
#
# Q 393+479+692 -   1624  T   1564 not ok
#
# Q 202+825+772 -   1849  T   1799 not ok
#
# Q 156+194+888 -   1244  T   1238 not ok
#
# Q 577+975+811 -   2414  T   2363 not ok
#
#
# --------------------------------------------------
# Iteration 31
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 283us/step - loss: 0.7578 - acc: 0.7024 - val_loss: 0.7649 - val_acc: 0.6970
# Examples:
# (10, 13, 15)
# Q 992+740+965 -   2631  T   2697 not ok
#
# Q 714+940+433 -   2038  T   2087 not ok
#
# Q 921+663+142 -   1733  T   1726 not ok
#
# Q 342+354+123 -    755  T    819 not ok
#
# Q 850+581+138 -   1533  T   1569 not ok
#
# Q 539+819+561 -   1849  T   1919 not ok
#
# Q 129+408+172 -    665  T    709 not ok
#
# Q 748+665+316 -   1755  T   1729 not ok
#
# Q 612+938+996 -   2512  T   2546 not ok
#
# Q 862+345+379 -   1533  T   1586 not ok
#
#
# --------------------------------------------------
# Iteration 32
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 279us/step - loss: 0.7561 - acc: 0.7031 - val_loss: 0.7822 - val_acc: 0.6855
# Examples:
# (10, 13, 15)
# Q 417+698+582 -   1778  T   1697 not ok
#
# Q 441+582+162 -   1275  T   1185 not ok
#
# Q 642+933+733 -   2398  T   2308 not ok
#
# Q 107+615+730 -   1576  T   1452 not ok
#
# Q 355+931+427 -   1798  T   1713 not ok
#
# Q 933+317+969 -   2290  T   2219 not ok
#
# Q 317+553+786 -   1678  T   1656 not ok
#
# Q 979+939+363 -   2277  T   2281 not ok
#
# Q 541+531+390 -   1476  T   1462 not ok
#
# Q 568+544+342 -   1477  T   1454 not ok
#
#
# --------------------------------------------------
# Iteration 33
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 271us/step - loss: 0.7621 - acc: 0.7012 - val_loss: 0.9073 - val_acc: 0.6404
# Examples:
# (10, 13, 15)
# Q 608+947+734 -   2224  T   2289 not ok
#
# Q 454+843+789 -   2044  T   2086 not ok
#
# Q 863+218+773 -   1714  T   1854 not ok
#
# Q 962+285+932 -   2044  T   2179 not ok
#
# Q 188+832+600 -   1554  T   1620 not ok
#
# Q 982+809+278 -   2094  T   2069 not ok
#
# Q 240+667+734 -   1544  T   1641 not ok
#
# Q 184+158+944 -   1124  T   1286 not ok
#
# Q 806+445+232 -   1489  T   1483 not ok
#
# Q 465+149+325 -    852  T    939 not ok
#
#
# --------------------------------------------------
# Iteration 34
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 277us/step - loss: 0.7544 - acc: 0.7038 - val_loss: 0.7316 - val_acc: 0.7126
# Examples:
# (10, 13, 15)
# Q 299+767+108 -   1127  T   1174 not ok
#
# Q 801+162+349 -   1389  T   1312 not ok
#
# Q 344+425+734 -   1492  T   1503 not ok
#
# Q 571+354+130 -   1002  T   1055 not ok
#
# Q 504+804+681 -   1999  T   1989 not ok
#
# Q 919+998+935 -   2788  T   2852 not ok
#
# Q 199+180+609 -    997  T    988 not ok
#
# Q 814+800+404 -   2029  T   2018 not ok
#
# Q 419+675+918 -   2099  T   2012 not ok
#
# Q 606+515+591 -   1699  T   1712 not ok
#
#
# --------------------------------------------------
# Iteration 35
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 281us/step - loss: 0.7580 - acc: 0.7025 - val_loss: 0.7265 - val_acc: 0.7211
# Examples:
# (10, 13, 15)
# Q 575+332+664 -   1584  T   1571 not ok
#
# Q 844+883+399 -   2144  T   2126 not ok
#
# Q 519+158+840 -   1566  T   1517 not ok
#
# Q 998+904+507 -   2418  T   2409 not ok
#
# Q 399+347+678 -   1444  T   1424 not ok
#
# Q 554+644+843 -   2068  T   2041 not ok
#
# Q 627+690+671 -   2041  T   1988 not ok
#
# Q 298+158+253 -    763  T    709 not ok
#
# Q 960+355+851 -   2256  T   2166 not ok
#
# Q 217+227+798 -   1234  T   1242 not ok
#
#
# --------------------------------------------------
# Iteration 36
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 270us/step - loss: 0.7488 - acc: 0.7083 - val_loss: 0.7329 - val_acc: 0.7136
# Examples:
# (10, 13, 15)
# Q 231+826+189 -   1266  T   1246 not ok
#
# Q 419+675+918 -   2048  T   2012 not ok
#
# Q 853+464+794 -   2077  T   2111 not ok
#
# Q 834+662+829 -   2342  T   2325 not ok
#
# Q 346+338+700 -   1322  T   1384 not ok
#
# Q 998+661+265 -   1841  T   1924 not ok
#
# Q 309+269+166 -    799  T    744 not ok
#
# Q 852+481+549 -   1847  T   1882 not ok
#
# Q 639+807+926 -   2312  T   2372 not ok
#
# Q 666+936+761 -   2312  T   2363 not ok
#
#
# --------------------------------------------------
# Iteration 37
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 284us/step - loss: 0.7471 - acc: 0.7090 - val_loss: 0.9405 - val_acc: 0.6338
# Examples:
# (10, 13, 15)
# Q 695+480+363 -   1457  T   1538 not ok
#
# Q 547+546+691 -   1746  T   1784 not ok
#
# Q 233+306+604 -   1056  T   1143 not ok
#
# Q 803+410+891 -   2039  T   2104 not ok
#
# Q 642+104+112 -    667  T    858 not ok
#
# Q 357+316+446 -   1057  T   1119 not ok
#
# Q 353+367+287 -    977  T   1007 not ok
#
# Q 312+551+839 -   1666  T   1702 not ok
#
# Q 427+688+339 -   1356  T   1454 not ok
#
# Q 121+578+812 -   1466  T   1511 not ok
#
#
# --------------------------------------------------
# Iteration 38
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 275us/step - loss: 0.7552 - acc: 0.7049 - val_loss: 0.8779 - val_acc: 0.6581
# Examples:
# (10, 13, 15)
# Q 185+626+798 -   1511  T   1609 not ok
#
# Q 265+562+472 -   1288  T   1299 not ok
#
# Q 555+267+101 -    999  T    923 not ok
#
# Q 341+742+286 -   1310  T   1369 not ok
#
# Q 406+676+151 -   1208  T   1233 not ok
#
# Q 599+504+114 -   1188  T   1217 not ok
#
# Q 384+377+897 -   1666  T   1658 not ok
#
# Q 336+478+831 -   1566  T   1645 not ok
#
# Q 784+820+876 -   2400  T   2480 not ok
#
# Q 771+872+381 -   1982  T   2024 not ok
#
#
# --------------------------------------------------
# Iteration 39
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 277us/step - loss: 0.7519 - acc: 0.7059 - val_loss: 0.7380 - val_acc: 0.7107
# Examples:
# (10, 13, 15)
# Q 159+492+400 -   1000  T   1051 not ok
#
# Q 686+743+205 -   1631  T   1634 not ok
#
# Q 234+196+860 -   1255  T   1290 not ok
#
# Q 851+492+293 -   1635  T   1636 not ok
#
# Q 533+177+725 -   1433  T   1435 not ok
#
# Q 686+658+705 -   2011  T   2049 not ok
#
# Q 814+941+605 -   2436  T   2360 not ok
#
# Q 297+279+397 -   1038  T    973 not ok
#
# Q 297+749+212 -   1253  T   1258 not ok
#
# Q 222+555+597 -   1344  T   1374 not ok
#
#
# --------------------------------------------------
# Iteration 40
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 280us/step - loss: 0.7465 - acc: 0.7094 - val_loss: 0.7245 - val_acc: 0.7191
# Examples:
# (10, 13, 15)
# Q 410+313+853 -   1568  T   1576 not ok
#
# Q 673+602+842 -   2167  T   2117 not ok
#
# Q 139+322+105 -    642  T    566 not ok
#
# Q 187+454+545 -   1184  T   1186 not ok
#
# Q 798+522+337 -   1672  T   1657 not ok
#
# Q 173+447+932 -   1575  T   1552 not ok
#
# Q 147+601+686 -   1422  T   1434 not ok
#
# Q 253+472+849 -   1576  T   1574 not ok
#
# Q 890+613+910 -   2404  T   2413 not ok
#
# Q 301+196+207 -    733  T    704 not ok
#
#
# --------------------------------------------------
# Iteration 41
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 282us/step - loss: 0.6912 - acc: 0.7352 - val_loss: 0.8599 - val_acc: 0.7179
# Examples:
# (10, 13, 15)
# Q 982+286+190 -   1510  T   1458 not ok
#
# Q 353+367+287 -   1040  T   1007 not ok
#
# Q 414+922+722 -   2078  T   2058 not ok
#
# Q 123+454+930 -   1500  T   1507 not ok
#
# Q 554+473+592 -   1630  T   1619 not ok
#
# Q 329+266+262 -    855  T    857 not ok
#
# Q 268+239+725 -   11  T   1232 not ok
#
# Q 770+882+750 -   2409  T   2402 not ok
#
# Q 691+918+631 -   2229  T   2240 not ok
#
# Q 586+155+759 -   1400  T   1500 not ok
#
#
# --------------------------------------------------
# Iteration 42
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 274us/step - loss: 0.5629 - acc: 0.7872 - val_loss: 0.5418 - val_acc: 0.8040
# Examples:
# (10, 13, 15)
# Q 202+851+616 -   1664  T   1669 not ok
#
# Q 895+673+904 -   2465  T   2472 not ok
#
# Q 469+350+437 -   1255  T   1256 not ok
#
# Q 653+654+910 -   2225  T   2217 not ok
#
# Q 629+585+131 -   1344  T   1345 not ok
#
# Q 214+625+952 -   1794  T   1791 not ok
#
# Q 114+629+913 -   1665  T   1656 not ok
#
# Q 523+411+447 -   1376  T   1381 not ok
#
# Q 803+520+561 -   1884  T   1884 ok
#
# Q 963+282+598 -   1845  T   1843 not ok
#
#
# --------------------------------------------------
# Iteration 43
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 284us/step - loss: 0.5056 - acc: 0.8081 - val_loss: 0.5984 - val_acc: 0.7638
# Examples:
# (10, 13, 15)
# Q 514+788+122 -   1428  T   1424 not ok
#
# Q 908+149+727 -   1782  T   1784 not ok
#
# Q 988+639+834 -   2356  T   2461 not ok
#
# Q 723+134+839 -   1696  T   1696 ok
#
# Q 639+741+221 -   1606  T   1601 not ok
#
# Q 392+760+644 -   1782  T   1796 not ok
#
# Q 161+635+273 -    066  T   1069 not ok
#
# Q 126+131+697 -    945  T    954 not ok
#
# Q 551+616+877 -   2045  T   2044 not ok
#
# Q 488+587+293 -   1345  T   1368 not ok
#
#
# --------------------------------------------------
# Iteration 44
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 289us/step - loss: 0.4873 - acc: 0.8123 - val_loss: 0.4712 - val_acc: 0.8220
# Examples:
# (10, 13, 15)
# Q 729+470+826 -   2025  T   2025 ok
#
# Q 107+149+192 -    544  T    448 not ok
#
# Q 642+985+793 -   2414  T   2420 not ok
#
# Q 308+336+605 -   1245  T   1249 not ok
#
# Q 549+506+227 -   1284  T   1282 not ok
#
# Q 985+380+127 -   1494  T   1492 not ok
#
# Q 298+993+464 -   1745  T   1755 not ok
#
# Q 609+126+694 -   1424  T   1429 not ok
#
# Q 759+842+805 -   2304  T   2406 not ok
#
# Q 928+790+591 -   2209  T   2309 not ok
#
#
# --------------------------------------------------
# Iteration 45
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 281us/step - loss: 0.4621 - acc: 0.8214 - val_loss: 0.6355 - val_acc: 0.7474
# Examples:
# (10, 13, 15)
# Q 194+170+101 -    567  T    465 not ok
#
# Q 289+697+412 -   1406  T   1398 not ok
#
# Q 524+904+885 -   2314  T   2313 not ok
#
# Q 784+820+876 -   2484  T   2480 not ok
#
# Q 304+971+223 -   1596  T   1498 not ok
#
# Q 716+965+745 -   2425  T   2426 not ok
#
# Q 605+726+768 -   2106  T   2099 not ok
#
# Q 525+447+362 -   1434  T   1334 not ok
#
# Q 114+787+394 -   1396  T   1295 not ok
#
# Q 744+604+618 -   1966  T   1966 ok
#
#
# --------------------------------------------------
# Iteration 46
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 284us/step - loss: 0.4577 - acc: 0.8241 - val_loss: 0.4816 - val_acc: 0.8193
# Examples:
# (10, 13, 15)
# Q 573+629+148 -   1355  T   1350 not ok
#
# Q 767+913+866 -   2545  T   2546 not ok
#
# Q 746+868+578 -   2194  T   2192 not ok
#
# Q 287+905+558 -   1755  T   1750 not ok
#
# Q 922+590+436 -   1955  T   1948 not ok
#
# Q 226+585+462 -   1274  T   1273 not ok
#
# Q 983+819+555 -   2355  T   2357 not ok
#
# Q 410+829+881 -   2025  T   2120 not ok
#
# Q 824+462+416 -   1711  T   1702 not ok
#
# Q 576+875+276 -   1725  T   1727 not ok
#
#
# --------------------------------------------------
# Iteration 47
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 282us/step - loss: 0.4531 - acc: 0.8250 - val_loss: 0.4160 - val_acc: 0.8440
# Examples:
# (10, 13, 15)
# Q 714+996+898 -   2607  T   2608 not ok
#
# Q 758+640+352 -   1751  T   1750 not ok
#
# Q 879+230+208 -   1315  T   1317 not ok
#
# Q 817+292+110 -   1215  T   1219 not ok
#
# Q 576+929+440 -   1940  T   1945 not ok
#
# Q 974+772+989 -   2735  T   2735 ok
#
# Q 143+808+420 -   1261  T   1371 not ok
#
# Q 200+484+127 -    813  T    811 not ok
#
# Q 708+873+139 -   1725  T   1720 not ok
#
# Q 778+477+168 -   1425  T   1423 not ok
#
#
# --------------------------------------------------
# Iteration 48
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 280us/step - loss: 0.4530 - acc: 0.8245 - val_loss: 0.4335 - val_acc: 0.8333
# Examples:
# (10, 13, 15)
# Q 507+649+517 -   1665  T   1673 not ok
#
# Q 292+331+481 -   1007  T   1104 not ok
#
# Q 289+626+674 -   1585  T   1589 not ok
#
# Q 363+342+961 -   1665  T   1666 not ok
#
# Q 151+606+497 -   1257  T   1254 not ok
#
# Q 649+829+474 -   1955  T   1952 not ok
#
# Q 384+997+372 -   1757  T   1753 not ok
#
# Q 283+378+842 -   1507  T   1503 not ok
#
# Q 139+665+785 -   1586  T   1589 not ok
#
# Q 237+712+210 -   1165  T   1159 not ok
#
#
# --------------------------------------------------
# Iteration 49
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 283us/step - loss: 0.4313 - acc: 0.8336 - val_loss: 0.4113 - val_acc: 0.8428
# Examples:
# (10, 13, 15)
# Q 981+389+770 -   2146  T   2140 not ok
#
# Q 953+311+690 -   1956  T   1954 not ok
#
# Q 261+245+706 -   1204  T   1212 not ok
#
# Q 965+439+303 -   1705  T   1707 not ok
#
# Q 441+644+760 -   1845  T   1845 ok
#
# Q 893+859+404 -   2156  T   2156 ok
#
# Q 112+624+509 -   1234  T   1245 not ok
#
# Q 778+477+168 -   1427  T   1423 not ok
#
# Q 314+118+973 -   1405  T   1405 ok
#
# Q 627+865+375 -   1867  T   1867 ok
#
#
# --------------------------------------------------
# Iteration 50
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 297us/step - loss: 0.4286 - acc: 0.8351 - val_loss: 0.4350 - val_acc: 0.8280
# Examples:
# (10, 13, 15)
# Q 568+854+433 -   1858  T   1855 not ok
#
# Q 192+863+636 -   1790  T   1691 not ok
#
# Q 639+741+221 -   1605  T   1601 not ok
#
# Q 394+629+391 -   1413  T   1414 not ok
#
# Q 619+254+189 -    962  T   1062 not ok
#
# Q 149+628+455 -   1238  T   1232 not ok
#
# Q 447+823+311 -   1588  T   1581 not ok
#
# Q 612+783+348 -   1748  T   1743 not ok
#
# Q 423+176+657 -   1257  T   1256 not ok
#
# Q 786+592+148 -   1520  T   1526 not ok
#
#
# --------------------------------------------------
# Iteration 51
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 296us/step - loss: 0.4227 - acc: 0.8374 - val_loss: 0.4208 - val_acc: 0.8344
# Examples:
# (10, 13, 15)
# Q 714+996+898 -   2607  T   2608 not ok
#
# Q 454+474+109 -   1034  T   1037 not ok
#
# Q 989+107+412 -   1502  T   1508 not ok
#
# Q 861+246+463 -   1575  T   1570 not ok
#
# Q 642+259+741 -   1640  T   1642 not ok
#
# Q 520+366+744 -   1624  T   1630 not ok
#
# Q 341+181+363 -    881  T    885 not ok
#
# Q 118+314+782 -   1212  T   1214 not ok
#
# Q 416+680+658 -   1752  T   1754 not ok
#
# Q 533+847+584 -   1965  T   1964 not ok
#
#
# --------------------------------------------------
# Iteration 52
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 288us/step - loss: 0.4123 - acc: 0.8414 - val_loss: 0.4171 - val_acc: 0.8411
# Examples:
# (10, 13, 15)
# Q 814+364+797 -   1978  T   1975 not ok
#
# Q 213+605+958 -   1778  T   1776 not ok
#
# Q 347+586+194 -   1123  T   1127 not ok
#
# Q 568+123+125 -    813  T    816 not ok
#
# Q 384+167+805 -   1351  T   1356 not ok
#
# Q 441+582+162 -   1180  T   1185 not ok
#
# Q 926+205+805 -   1931  T   1936 not ok
#
# Q 488+723+982 -   2198  T   2193 not ok
#
# Q 100+776+211 -   1088  T   1087 not ok
#
# Q 248+223+670 -   1148  T   1141 not ok
#
#
# --------------------------------------------------
# Iteration 53
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 287us/step - loss: 0.4159 - acc: 0.8401 - val_loss: 0.4514 - val_acc: 0.8249
# Examples:
# (10, 13, 15)
# Q 916+375+787 -   2975  T   2078 not ok
#
# Q 857+699+560 -   2110  T   2116 not ok
#
# Q 614+718+303 -   1639  T   1635 not ok
#
# Q 148+206+327 -    688  T    681 not ok
#
# Q 336+742+346 -   1423  T   1424 not ok
#
# Q 156+194+888 -   1237  T   1238 not ok
#
# Q 796+424+879 -   2097  T   2099 not ok
#
# Q 810+792+840 -   2443  T   2442 not ok
#
# Q 770+882+750 -   2407  T   2402 not ok
#
# Q 275+949+294 -   1512  T   1518 not ok
#
#
# --------------------------------------------------
# Iteration 54
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 293us/step - loss: 0.4330 - acc: 0.8338 - val_loss: 0.3984 - val_acc: 0.8459
# Examples:
# (10, 13, 15)
# Q 285+704+300 -   1284  T   1289 not ok
#
# Q 222+555+597 -   1374  T   1374 ok
#
# Q 688+438+494 -   1625  T   1620 not ok
#
# Q 501+251+549 -   1305  T   1301 not ok
#
# Q 802+912+948 -   2564  T   2662 not ok
#
# Q 175+779+967 -   1926  T   1921 not ok
#
# Q 314+178+923 -   1415  T   1415 ok
#
# Q 415+331+952 -   1695  T   1698 not ok
#
# Q 955+222+881 -   2055  T   2058 not ok
#
# Q 638+127+284 -   1046  T   1049 not ok
#
#
# --------------------------------------------------
# Iteration 55
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 287us/step - loss: 0.4068 - acc: 0.8439 - val_loss: 0.3835 - val_acc: 0.8522
# Examples:
# (10, 13, 15)
# Q 583+977+352 -   1912  T   1912 ok
#
# Q 846+413+723 -   1983  T   1982 not ok
#
# Q 299+920+258 -   1473  T   1477 not ok
#
# Q 836+261+862 -   1951  T   1959 not ok
#
# Q 577+356+535 -   1460  T   1468 not ok
#
# Q 203+846+494 -   1543  T   1543 ok
#
# Q 708+337+373 -   1412  T   1418 not ok
#
# Q 100+776+211 -   1080  T   1087 not ok
#
# Q 563+497+366 -   1423  T   1426 not ok
#
# Q 583+349+692 -   1621  T   1624 not ok
#
#
# --------------------------------------------------
# Iteration 56
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 284us/step - loss: 0.4031 - acc: 0.8451 - val_loss: 0.3887 - val_acc: 0.8479
# Examples:
# (10, 13, 15)
# Q 120+364+110 -    593  T    594 not ok
#
# Q 116+826+140 -   1081  T   1082 not ok
#
# Q 651+566+205 -   1422  T   1422 ok
#
# Q 646+806+498 -   1945  T   1950 not ok
#
# Q 569+791+850 -   2214  T   2210 not ok
#
# Q 622+326+808 -   1750  T   1756 not ok
#
# Q 662+688+838 -   2185  T   2188 not ok
#
# Q 556+628+473 -   1655  T   1657 not ok
#
# Q 765+579+796 -   2135  T   2140 not ok
#
# Q 462+692+968 -   2124  T   2122 not ok
#
#
# --------------------------------------------------
# Iteration 57
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 289us/step - loss: 0.4102 - acc: 0.8426 - val_loss: 0.3843 - val_acc: 0.8532
# Examples:
# (10, 13, 15)
# Q 922+234+719 -   1879  T   1875 not ok
#
# Q 992+163+342 -   1495  T   1497 not ok
#
# Q 206+137+379 -    723  T    722 not ok
#
# Q 705+982+508 -   2193  T   2195 not ok
#
# Q 641+796+870 -   2300  T   2307 not ok
#
# Q 963+246+580 -   1783  T   1789 not ok
#
# Q 536+412+966 -   1913  T   1914 not ok
#
# Q 904+941+159 -   2003  T   2004 not ok
#
# Q 222+555+597 -   1378  T   1374 not ok
#
# Q 861+246+463 -   1578  T   1570 not ok
#
#
# --------------------------------------------------
# Iteration 58
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 288us/step - loss: 0.4098 - acc: 0.8429 - val_loss: 0.4116 - val_acc: 0.8393
# Examples:
# (10, 13, 15)
# Q 238+560+905 -   1605  T   1703 not ok
#
# Q 941+231+377 -   1554  T   1549 not ok
#
# Q 499+357+683 -   1545  T   1539 not ok
#
# Q 396+752+980 -   2135  T   2128 not ok
#
# Q 423+804+233 -   1456  T   1460 not ok
#
# Q 499+723+928 -   2156  T   2150 not ok
#
# Q 873+468+116 -   1454  T   1457 not ok
#
# Q 978+909+202 -   2086  T   2089 not ok
#
# Q 502+970+436 -   1905  T   1908 not ok
#
# Q 856+642+863 -   2366  T   2361 not ok
#
#
# --------------------------------------------------
# Iteration 59
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 294us/step - loss: 0.4046 - acc: 0.8446 - val_loss: 0.4040 - val_acc: 0.8424
# Examples:
# (10, 13, 15)
# Q 989+672+501 -   2168  T   2162 not ok
#
# Q 551+616+877 -   2048  T   2044 not ok
#
# Q 834+273+386 -   1495  T   1493 not ok
#
# Q 458+686+967 -   2104  T   2111 not ok
#
# Q 610+891+533 -   2038  T   2034 not ok
#
# Q 666+545+652 -   1869  T   1863 not ok
#
# Q 493+792+792 -   2075  T   2077 not ok
#
# Q 802+317+320 -   1439  T   1439 ok
#
# Q 997+854+596 -   2440  T   2447 not ok
#
# Q 854+139+986 -   1985  T   1979 not ok
#
#
# --------------------------------------------------
# Iteration 60
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 292us/step - loss: 0.4048 - acc: 0.8441 - val_loss: 0.3927 - val_acc: 0.8449
# Examples:
# (10, 13, 15)
# Q 358+677+986 -   2017  T   2021 not ok
#
# Q 540+572+265 -   1371  T   1377 not ok
#
# Q 525+176+712 -   1411  T   1413 not ok
#
# Q 352+178+435 -    961  T    965 not ok
#
# Q 810+618+147 -   1578  T   1575 not ok
#
# Q 845+157+245 -   1249  T   1247 not ok
#
# Q 171+158+278 -    608  T    607 not ok
#
# Q 199+180+609 -    986  T    988 not ok
#
# Q 216+326+972 -   1519  T   1514 not ok
#
# Q 738+277+650 -   1668  T   1665 not ok
#
#
# --------------------------------------------------
# Iteration 61
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 303us/step - loss: 0.3948 - acc: 0.8481 - val_loss: 0.4203 - val_acc: 0.8341
# Examples:
# (10, 13, 15)
# Q 254+102+932 -   1283  T   1288 not ok
#
# Q 819+493+516 -   1822  T   1828 not ok
#
# Q 148+675+940 -   1763  T   1763 ok
#
# Q 549+506+227 -   1284  T   1282 not ok
#
# Q 616+533+405 -   1559  T   1554 not ok
#
# Q 283+378+842 -   1504  T   1503 not ok
#
# Q 743+177+935 -   1853  T   1855 not ok
#
# Q 851+864+740 -   2452  T   2455 not ok
#
# Q 533+244+909 -   1683  T   1686 not ok
#
# Q 825+928+323 -   2073  T   2076 not ok
#
#
# --------------------------------------------------
# Iteration 62
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 292us/step - loss: 0.3899 - acc: 0.8499 - val_loss: 0.3839 - val_acc: 0.8515
# Examples:
# (10, 13, 15)
# Q 188+832+600 -   1618  T   1620 not ok
#
# Q 839+974+904 -   2715  T   2717 not ok
#
# Q 671+362+387 -   1425  T   1420 not ok
#
# Q 445+137+589 -   1174  T   1171 not ok
#
# Q 886+294+798 -   1966  T   1978 not ok
#
# Q 570+353+566 -   1494  T   1489 not ok
#
# Q 323+942+774 -   2039  T   2039 ok
#
# Q 708+310+357 -   1379  T   1375 not ok
#
# Q 202+825+772 -   1894  T   1799 not ok
#
# Q 199+764+634 -   1595  T   1597 not ok
#
#
# --------------------------------------------------
# Iteration 63
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 300us/step - loss: 0.3889 - acc: 0.8504 - val_loss: 0.3800 - val_acc: 0.8528
# Examples:
# (10, 13, 15)
# Q 236+895+123 -   1257  T   1254 not ok
#
# Q 186+414+274 -    875  T    874 not ok
#
# Q 167+675+782 -   1621  T   1624 not ok
#
# Q 154+971+399 -   1521  T   1524 not ok
#
# Q 463+644+520 -   1626  T   1627 not ok
#
# Q 397+723+587 -   1701  T   1707 not ok
#
# Q 434+405+635 -   1473  T   1474 not ok
#
# Q 488+991+489 -   1966  T   1968 not ok
#
# Q 770+153+851 -   1771  T   1774 not ok
#
# Q 764+908+791 -   2467  T   2463 not ok
#
#
# --------------------------------------------------
# Iteration 64
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 296us/step - loss: 0.3896 - acc: 0.8501 - val_loss: 0.3884 - val_acc: 0.8462
# Examples:
# (10, 13, 15)
# Q 942+766+190 -   1892  T   1898 not ok
#
# Q 965+439+303 -   1705  T   1707 not ok
#
# Q 480+960+292 -   1737  T   1732 not ok
#
# Q 886+537+829 -   2251  T   2252 not ok
#
# Q 872+117+461 -   1451  T   1450 not ok
#
# Q 892+290+754 -   1935  T   1936 not ok
#
# Q 302+332+485 -   1112  T   1119 not ok
#
# Q 845+495+190 -   1537  T   1530 not ok
#
# Q 955+666+362 -   1981  T   1983 not ok
#
# Q 900+196+243 -   1338  T   1339 not ok
#
#
# --------------------------------------------------
# Iteration 65
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 300us/step - loss: 0.3870 - acc: 0.8507 - val_loss: 0.4111 - val_acc: 0.8399
# Examples:
# (10, 13, 15)
# Q 116+793+861 -   1779  T   1770 not ok
#
# Q 784+820+876 -   2479  T   2480 not ok
#
# Q 627+729+681 -   2038  T   2037 not ok
#
# Q 419+626+370 -   1412  T   1415 not ok
#
# Q 560+181+454 -   1192  T   1195 not ok
#
# Q 240+667+734 -   1648  T   1641 not ok
#
# Q 738+533+622 -   1892  T   1893 not ok
#
# Q 688+660+918 -   2269  T   2266 not ok
#
# Q 880+397+535 -   1812  T   1812 ok
#
# Q 856+594+581 -   2027  T   2031 not ok
#
#
# --------------------------------------------------
# Iteration 66
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 306us/step - loss: 0.3962 - acc: 0.8483 - val_loss: 0.3926 - val_acc: 0.8498
# Examples:
# (10, 13, 15)
# Q 378+353+311 -   1047  T   1042 not ok
#
# Q 371+124+771 -   1265  T   1266 not ok
#
# Q 286+995+140 -   1424  T   1421 not ok
#
# Q 112+123+326 -    554  T    561 not ok
#
# Q 802+317+320 -   1430  T   1439 not ok
#
# Q 855+534+378 -   1765  T   1767 not ok
#
# Q 444+199+522 -   1167  T   1165 not ok
#
# Q 222+833+230 -   1284  T   1285 not ok
#
# Q 232+866+381 -   1484  T   1479 not ok
#
# Q 363+317+947 -   1624  T   1627 not ok
#
#
# --------------------------------------------------
# Iteration 67
# ...
# Examples:
# (10, 13, 15)
# Q 107+545+983 -   1635  T   1635 ok
#
# Q 491+406+304 -   1200  T   1201 not ok
#
# Q 678+916+206 -   1899  T   1800 not ok
#
# Q 119+396+996 -   1512  T   1511 not ok
#
# Q 339+661+524 -   1523  T   1524 not ok
#
# Q 526+923+205 -   1656  T   1654 not ok
#
# Q 876+856+345 -   2078  T   2077 not ok
#
# Q 943+636+799 -   2379  T   2378 not ok
#
# Q 218+443+985 -   1646  T   1646 ok
#
# Q 214+625+952 -   1791  T   1791 ok
#
#
# --------------------------------------------------
# Iteration 277
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 298us/step - loss: 0.2247 - acc: 0.9060 - val_loss: 0.2375 - val_acc: 0.8898
# Examples:
# (10, 13, 15)
# Q 567+566+312 -   1444  T   1445 not ok
#
# Q 431+805+451 -   1687  T   1687 ok
#
# Q 215+704+154 -   1073  T   1073 ok
#
# Q 577+356+535 -   1468  T   1468 ok
#
# Q 474+294+797 -   1569  T   1565 not ok
#
# Q 675+434+555 -   1662  T   1664 not ok
#
# Q 847+837+991 -   2674  T   2675 not ok
#
# Q 974+235+376 -   1584  T   1585 not ok
#
# Q 822+915+892 -   2628  T   2629 not ok
#
# Q 310+387+319 -   1016  T   1016 ok
#
#
# --------------------------------------------------
# Iteration 278
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 292us/step - loss: 0.2118 - acc: 0.9103 - val_loss: 0.1810 - val_acc: 0.9306
# Examples:
# (10, 13, 15)
# Q 590+573+961 -   2125  T   2124 not ok
#
# Q 686+971+894 -   2553  T   2551 not ok
#
# Q 290+914+517 -   1722  T   1721 not ok
#
# Q 860+654+423 -   1937  T   1937 ok
#
# Q 172+859+515 -   1546  T   1546 ok
#
# Q 228+747+903 -   1876  T   1878 not ok
#
# Q 367+802+327 -   1496  T   1496 ok
#
# Q 927+472+369 -   1769  T   1768 not ok
#
# Q 320+987+501 -   1808  T   1808 ok
#
# Q 817+963+199 -   1979  T   1979 ok
#
#
# --------------------------------------------------
# Iteration 279
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 289us/step - loss: 0.2093 - acc: 0.9112 - val_loss: 0.1762 - val_acc: 0.9350
# Examples:
# (10, 13, 15)
# Q 916+994+527 -   2437  T   2437 ok
#
# Q 595+246+926 -   1767  T   1767 ok
#
# Q 153+764+871 -   1788  T   1788 ok
#
# Q 355+942+142 -   1439  T   1439 ok
#
# Q 534+407+791 -   1732  T   1732 ok
#
# Q 332+680+279 -   1291  T   1291 ok
#
# Q 856+594+581 -   2032  T   2031 not ok
#
# Q 314+101+845 -   1260  T   1260 ok
#
# Q 651+132+453 -   1235  T   1236 not ok
#
# Q 590+857+456 -   1903  T   1903 ok
#
#
# --------------------------------------------------
# Iteration 280
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 296us/step - loss: 0.2161 - acc: 0.9088 - val_loss: 0.2344 - val_acc: 0.8996
# Examples:
# (10, 13, 15)
# Q 855+939+364 -   2158  T   2158 ok
#
# Q 379+520+851 -   1751  T   1750 not ok
#
# Q 771+479+199 -   1457  T   1449 not ok
#
# Q 756+430+716 -   1901  T   1902 not ok
#
# Q 326+559+882 -   1767  T   1767 ok
#
# Q 503+992+225 -   1720  T   1720 ok
#
# Q 880+100+816 -   1794  T   1796 not ok
#
# Q 615+826+645 -   2084  T   2086 not ok
#
# Q 519+179+756 -   1455  T   1454 not ok
#
# Q 936+236+626 -   1797  T   1798 not ok
#
#
# --------------------------------------------------
# Iteration 281
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 292us/step - loss: 0.2074 - acc: 0.9118 - val_loss: 0.1678 - val_acc: 0.9348
# Examples:
# (10, 13, 15)
# Q 953+725+512 -   2192  T   2190 not ok
#
# Q 958+447+225 -   1630  T   1630 ok
#
# Q 435+656+700 -   1792  T   1791 not ok
#
# Q 342+692+979 -   2013  T   2013 ok
#
# Q 576+219+301 -   1097  T   1096 not ok
#
# Q 476+323+169 -    969  T    968 not ok
#
# Q 802+912+948 -   2662  T   2662 ok
#
# Q 662+695+930 -   2287  T   2287 ok
#
# Q 964+116+446 -   1526  T   1526 ok
#
# Q 126+200+940 -   1267  T   1266 not ok
#
#
# --------------------------------------------------
# Iteration 282
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 9s 328us/step - loss: 0.2078 - acc: 0.9117 - val_loss: 0.1584 - val_acc: 0.9421
# Examples:
# (10, 13, 15)
# Q 702+763+671 -   2136  T   2136 ok
#
# Q 253+472+849 -   1574  T   1574 ok
#
# Q 555+824+932 -   2311  T   2311 ok
#
# Q 699+581+767 -   2048  T   2047 not ok
#
# Q 121+470+961 -   1553  T   1552 not ok
#
# Q 749+105+782 -   1636  T   1636 ok
#
# Q 266+718+244 -   1228  T   1228 ok
#
# Q 698+657+418 -   1773  T   1773 ok
#
# Q 286+414+916 -   1616  T   1616 ok
#
# Q 959+660+127 -   1746  T   1746 ok
#
#
# --------------------------------------------------
# Iteration 283
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 9s 334us/step - loss: 0.2005 - acc: 0.9162 - val_loss: 0.2490 - val_acc: 0.8893
# Examples:
# (10, 13, 15)
# Q 403+716+828 -   1947  T   1947 ok
#
# Q 173+447+932 -   1553  T   1552 not ok
#
# Q 761+402+383 -   1548  T   1546 not ok
#
# Q 326+795+671 -   1792  T   1792 ok
#
# Q 373+979+259 -   1610  T   1611 not ok
#
# Q 866+190+536 -   1593  T   1592 not ok
#
# Q 817+926+199 -   1942  T   1942 ok
#
# Q 394+635+580 -   1608  T   1609 not ok
#
# Q 384+377+897 -   1659  T   1658 not ok
#
# Q 779+424+867 -   2072  T   2070 not ok
#
#
# --------------------------------------------------
# Iteration 284
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 9s 346us/step - loss: 0.2124 - acc: 0.9135 - val_loss: 0.1764 - val_acc: 0.9298
# Examples:
# (10, 13, 15)
# Q 983+819+555 -   2357  T   2357 ok
#
# Q 329+799+759 -   1886  T   1887 not ok
#
# Q 843+700+573 -   2116  T   2116 ok
#
# Q 174+490+530 -   1194  T   1194 ok
#
# Q 705+982+508 -   2195  T   2195 ok
#
# Q 360+498+476 -   1334  T   1334 ok
#
# Q 847+499+577 -   1923  T   1923 ok
#
# Q 578+279+196 -   1054  T   1053 not ok
#
# Q 645+524+189 -   1357  T   1358 not ok
#
# Q 932+355+893 -   2180  T   2180 ok
#
#
# --------------------------------------------------
# Iteration 285
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 298us/step - loss: 0.2129 - acc: 0.9113 - val_loss: 0.1759 - val_acc: 0.9308
# Examples:
# (10, 13, 15)
# Q 534+407+791 -   1732  T   1732 ok
#
# Q 423+758+106 -   1287  T   1287 ok
#
# Q 964+116+446 -   1526  T   1526 ok
#
# Q 198+640+954 -   1792  T   1792 ok
#
# Q 947+517+404 -   1868  T   1868 ok
#
# Q 340+625+493 -   1457  T   1458 not ok
#
# Q 937+824+284 -   2045  T   2045 ok
#
# Q 330+668+797 -   1795  T   1795 ok
#
# Q 675+233+478 -   1385  T   1386 not ok
#
# Q 111+778+217 -   1106  T   1106 ok
#
#
# --------------------------------------------------
# Iteration 286
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 292us/step - loss: 0.2048 - acc: 0.9136 - val_loss: 0.1729 - val_acc: 0.9296
# Examples:
# (10, 13, 15)
# Q 451+908+400 -   1760  T   1759 not ok
#
# Q 896+599+925 -   2420  T   2420 ok
#
# Q 793+230+761 -   1783  T   1784 not ok
#
# Q 590+125+644 -   1359  T   1359 ok
#
# Q 297+104+288 -    689  T    689 ok
#
# Q 953+725+512 -   2199  T   2190 not ok
#
# Q 899+782+500 -   2189  T   2181 not ok
#
# Q 393+897+643 -   1934  T   1933 not ok
#
# Q 485+106+995 -   1585  T   1586 not ok
#
# Q 533+177+725 -   1436  T   1435 not ok
#
#
# --------------------------------------------------
# Iteration 287
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 308us/step - loss: 0.2001 - acc: 0.9161 - val_loss: 0.1917 - val_acc: 0.9215
# Examples:
# (10, 13, 15)
# Q 716+895+925 -   2537  T   2536 not ok
#
# Q 335+144+125 -    603  T    604 not ok
#
# Q 781+853+937 -   2571  T   2571 ok
#
# Q 880+374+963 -   2217  T   2217 ok
#
# Q 153+948+763 -   1864  T   1864 ok
#
# Q 251+788+719 -   1758  T   1758 ok
#
# Q 440+574+291 -   1305  T   1305 ok
#
# Q 796+424+879 -   2190  T   2099 not ok
#
# Q 384+377+897 -   1667  T   1658 not ok
#
# Q 170+305+890 -   1365  T   1365 ok
#
#
# --------------------------------------------------
# Iteration 288
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 302us/step - loss: 0.1971 - acc: 0.9170 - val_loss: 0.1622 - val_acc: 0.9375
# Examples:
# (10, 13, 15)
# Q 261+232+296 -    789  T    789 ok
#
# Q 574+105+603 -   1282  T   1282 ok
#
# Q 114+629+913 -   1657  T   1656 not ok
#
# Q 427+432+421 -   1280  T   1280 ok
#
# Q 721+726+594 -   2042  T   2041 not ok
#
# Q 460+702+267 -   1429  T   1429 ok
#
# Q 763+502+317 -   1582  T   1582 ok
#
# Q 925+598+995 -   2518  T   2518 ok
#
# Q 499+810+126 -   1436  T   1435 not ok
#
# Q 572+945+984 -   2500  T   2501 not ok
#
#
# --------------------------------------------------
# Iteration 289
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 303us/step - loss: 0.2062 - acc: 0.9132 - val_loss: 0.1743 - val_acc: 0.9350
# Examples:
# (10, 13, 15)
# Q 555+348+847 -   1751  T   1750 not ok
#
# Q 834+662+829 -   2325  T   2325 ok
#
# Q 310+555+829 -   1694  T   1694 ok
#
# Q 534+479+810 -   1824  T   1823 not ok
#
# Q 448+552+339 -   1339  T   1339 ok
#
# Q 886+294+798 -   1976  T   1978 not ok
#
# Q 738+533+622 -   1893  T   1893 ok
#
# Q 992+471+728 -   2191  T   2191 ok
#
# Q 781+853+937 -   2571  T   2571 ok
#
# Q 359+452+685 -   1496  T   1496 ok
#
#
# --------------------------------------------------
# Iteration 290
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 306us/step - loss: 0.2081 - acc: 0.9115 - val_loss: 0.1670 - val_acc: 0.9370
# Examples:
# (10, 13, 15)
# Q 107+112+803 -   1022  T   1022 ok
#
# Q 692+580+411 -   1682  T   1683 not ok
#
# Q 839+224+511 -   1574  T   1574 ok
#
# Q 359+374+850 -   1584  T   1583 not ok
#
# Q 588+812+792 -   2192  T   2192 ok
#
# Q 385+347+247 -    979  T    979 ok
#
# Q 666+921+683 -   2270  T   2270 ok
#
# Q 519+179+756 -   1454  T   1454 ok
#
# Q 516+793+642 -   1952  T   1951 not ok
#
# Q 967+619+934 -   2520  T   2520 ok
#
#
# --------------------------------------------------
# Iteration 291
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 307us/step - loss: 0.1939 - acc: 0.9186 - val_loss: 0.1699 - val_acc: 0.9270
# Examples:
# (10, 13, 15)
# Q 858+670+774 -   2302  T   2302 ok
#
# Q 726+974+859 -   2550  T   2559 not ok
#
# Q 943+820+892 -   2655  T   2655 ok
#
# Q 199+245+999 -   1443  T   1443 ok
#
# Q 248+912+795 -   1954  T   1955 not ok
#
# Q 871+580+125 -   1577  T   1576 not ok
#
# Q 626+420+560 -   1606  T   1606 ok
#
# Q 415+181+504 -   1009  T   1100 not ok
#
# Q 944+862+340 -   2145  T   2146 not ok
#
# Q 121+578+812 -   1511  T   1511 ok
#
#
# --------------------------------------------------
# Iteration 292
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 302us/step - loss: 0.2103 - acc: 0.9122 - val_loss: 0.1835 - val_acc: 0.9174
# Examples:
# (10, 13, 15)
# Q 817+926+199 -   1942  T   1942 ok
#
# Q 854+200+810 -   1863  T   1864 not ok
#
# Q 590+823+162 -   1574  T   1575 not ok
#
# Q 538+667+555 -   1759  T   1760 not ok
#
# Q 449+853+927 -   2228  T   2229 not ok
#
# Q 911+550+788 -   2249  T   2249 ok
#
# Q 506+350+675 -   1531  T   1531 ok
#
# Q 323+418+217 -    958  T    958 ok
#
# Q 103+191+509 -    803  T    803 ok
#
# Q 708+310+357 -   1375  T   1375 ok
#
#
# --------------------------------------------------
# Iteration 293
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 301us/step - loss: 0.2099 - acc: 0.9129 - val_loss: 0.1718 - val_acc: 0.9402
# Examples:
# (10, 13, 15)
# Q 312+931+352 -   1597  T   1595 not ok
#
# Q 935+790+118 -   1843  T   1843 ok
#
# Q 975+638+777 -   2380  T   2390 not ok
#
# Q 701+908+715 -   2323  T   2324 not ok
#
# Q 920+149+521 -   1590  T   1590 ok
#
# Q 758+640+352 -   1750  T   1750 ok
#
# Q 473+451+802 -   1726  T   1726 ok
#
# Q 942+623+853 -   2418  T   2418 ok
#
# Q 517+886+326 -   1729  T   1729 ok
#
# Q 363+750+670 -   1783  T   1783 ok
#
#
# --------------------------------------------------
# Iteration 294
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 302us/step - loss: 0.2170 - acc: 0.9100 - val_loss: 0.1893 - val_acc: 0.9242
# Examples:
# (10, 13, 15)
# Q 217+566+820 -   1603  T   1603 ok
#
# Q 503+992+225 -   1720  T   1720 ok
#
# Q 447+823+311 -   1582  T   1581 not ok
#
# Q 909+437+218 -   1565  T   1564 not ok
#
# Q 675+434+555 -   1664  T   1664 ok
#
# Q 386+636+391 -   1413  T   1413 ok
#
# Q 531+547+291 -   1369  T   1369 ok
#
# Q 884+223+184 -   1290  T   1291 not ok
#
# Q 653+654+910 -   2217  T   2217 ok
#
# Q 322+985+870 -   2177  T   2177 ok
#
#
# --------------------------------------------------
# Iteration 295
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 305us/step - loss: 0.2091 - acc: 0.9119 - val_loss: 0.2676 - val_acc: 0.8870
# Examples:
# (10, 13, 15)
# Q 344+276+897 -   1517  T   1517 ok
#
# Q 466+424+541 -   1431  T   1431 ok
#
# Q 974+772+989 -   2735  T   2735 ok
#
# Q 361+311+610 -   1282  T   1282 ok
#
# Q 752+258+221 -   1231  T   1231 ok
#
# Q 928+283+189 -   1400  T   1400 ok
#
# Q 583+349+692 -   1624  T   1624 ok
#
# Q 355+942+142 -   1438  T   1439 not ok
#
# Q 504+804+681 -   1991  T   1989 not ok
#
# Q 547+238+672 -   1455  T   1457 not ok
#
#
# --------------------------------------------------
# Iteration 296
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 298us/step - loss: 0.2041 - acc: 0.9137 - val_loss: 0.1835 - val_acc: 0.9152
# Examples:
# (10, 13, 15)
# Q 184+667+930 -   1780  T   1781 not ok
#
# Q 804+699+808 -   2311  T   2311 ok
#
# Q 789+582+866 -   2238  T   2237 not ok
#
# Q 498+822+169 -   1489  T   1489 ok
#
# Q 729+468+421 -   1618  T   1618 ok
#
# Q 978+335+542 -   1854  T   1855 not ok
#
# Q 458+864+667 -   1989  T   1989 ok
#
# Q 155+802+100 -   1058  T   1057 not ok
#
# Q 734+462+871 -   2066  T   2067 not ok
#
# Q 612+808+467 -   1886  T   1887 not ok
#
#
# --------------------------------------------------
# Iteration 297
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 300us/step - loss: 0.1987 - acc: 0.9165 - val_loss: 0.2139 - val_acc: 0.9112
# Examples:
# (10, 13, 15)
# Q 854+785+533 -   2173  T   2172 not ok
#
# Q 125+519+527 -   1172  T   1171 not ok
#
# Q 681+112+145 -    939  T    938 not ok
#
# Q 367+161+180 -    707  T    708 not ok
#
# Q 917+479+368 -   1764  T   1764 ok
#
# Q 986+757+413 -   2156  T   2156 ok
#
# Q 741+402+977 -   2120  T   2120 ok
#
# Q 346+532+750 -   1629  T   1628 not ok
#
# Q 412+602+648 -   1662  T   1662 ok
#
# Q 336+478+831 -   1645  T   1645 ok
#
#
# --------------------------------------------------
# Iteration 298
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 298us/step - loss: 0.2130 - acc: 0.9103 - val_loss: 0.2667 - val_acc: 0.9076
# Examples:
# (10, 13, 15)
# Q 146+764+266 -   1176  T   1176 ok
#
# Q 460+482+479 -   1521  T   1421 not ok
#
# Q 641+315+497 -   1553  T   1453 not ok
#
# Q 360+237+815 -   1513  T   1412 not ok
#
# Q 190+930+455 -   1575  T   1575 ok
#
# Q 628+805+860 -   2293  T   2293 ok
#
# Q 454+502+904 -   1862  T   1860 not ok
#
# Q 905+220+366 -   1492  T   1491 not ok
#
# Q 431+883+134 -   1548  T   1448 not ok
#
# Q 238+773+530 -   1541  T   1541 ok
#
#
# --------------------------------------------------
# Iteration 299
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 300us/step - loss: 0.2215 - acc: 0.9095 - val_loss: 0.1601 - val_acc: 0.9390
# Examples:
# (10, 13, 15)
# Q 967+999+754 -   2721  T   2720 not ok
#
# Q 860+771+579 -   2210  T   2210 ok
#
# Q 901+676+179 -   1756  T   1756 ok
#
# Q 584+560+615 -   1759  T   1759 ok
#
# Q 475+458+823 -   1756  T   1756 ok
#
# Q 499+264+663 -   1426  T   1426 ok
#
# Q 899+782+500 -   2180  T   2181 not ok
#
# Q 781+879+100 -   1760  T   1760 ok
#
# Q 945+332+646 -   1922  T   1923 not ok
#
# Q 898+789+734 -   2421  T   2421 ok

# %% [markdown]
# Test data with three digits sum and get train dataset accuracy 0.9095 and valid data accuracy 0.9390

# %%
def generate_equations_random_digit(max_count=None):
        number_permutations=itertools.permutations(range(10,1000),2)
        if max_count is not None:
            number_permutations=itertools.islice(number_permutations,max_count)
        number_permutations=list(number_permutations)
        random.shuffle(number_permutations)
        for x,y in number_permutations:
            p=random.randint(1,2)
            if p==1:
                if x>y:
                    yield'{}-{}'.format(x,y)
                else:
                    yield'{}-{}'.format(y,x)
            if p==2:
                    yield'{}+{}'.format(x,y)
            if p==3 or p==4:
                    yield'{}*{}'.format(x,y)

# %%
from keras.models import Sequential
from keras.layers import LSTM,RepeatVector,Dense,Activation,Dropout
from keras.layers.wrappers import TimeDistributed,Bidirectional
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.models import load_model

import itertools
import numpy as np
import random

CHARS = [str(n) for n in range(10)] + ['*','+','-', ' ', '\0']
CHAR_TO_INDEX = {i: c for c, i in enumerate(CHARS)}
INDEX_TO_CHAR = {c: i for c, i in enumerate(CHARS)}
          
MIN_NUMBER = 10
MAX_NUMBER = 999

MAX_N_EXAMPLES = (MAX_NUMBER - MIN_NUMBER) ** 2
N_EXAMPLES = 30000
N_FEATURES = len(CHARS)
MAX_NUMBER_LENGTH_LEFT_SIDE = len(str(MAX_NUMBER))
MAX_NUMBER_LENGTH_RIGHT_SIDE = MAX_NUMBER_LENGTH_LEFT_SIDE *2
MAX_EQUATION_LENGTH = (MAX_NUMBER_LENGTH_LEFT_SIDE * 2) + 4
MAX_RESULT_LENGTH = MAX_NUMBER_LENGTH_RIGHT_SIDE + 1

SPLIT = .1
EPOCHS = 500
LEARNING_RATE = 0.001
BATCH_SIZE = 256
HIDDEN_SIZE = 128
ENCODER_DEPTH = 1
DECODER_DEPTH = 1
DROPOUT = 0
BATCH_NORM = True

# %%
def generate_equations(max_count=None):
        number_permutations=itertools.permutations(range(100,1000),2)
        if max_count is not None:
            number_permutations=itertools.islice(number_permutations,max_count)
        number_permutations=list(number_permutations)
        random.shuffle(number_permutations)
        for x,y in number_permutations:
            p=random.randint(1,2)
            if p==1:
                if x>y:
                    yield'{}-{}'.format(x,y)
                else:
                    yield'{}-{}'.format(y,x)
            if p==2:
                    yield'{}+{}'.format(x,y)
            if p==3 or p==4:
                    yield'{}*{}'.format(x,y)
 

def one_hot_to_index(vector):
    if not np.any(vector):
        return -1
    return np.argmax(vector)

def one_hot_to_char(vector):
    index=one_hot_to_index(vector)
    if index==-1:
        return''
    return INDEX_TO_CHAR[index]

def one_hot_to_string(matrix):
    return ''.join(one_hot_to_char(vector) for vector in matrix)              
                
def equations_to_x_y(equations,n):
     x=np.zeros((n,MAX_EQUATION_LENGTH,N_FEATURES),dtype=np.bool)
     y=np.zeros((n,MAX_RESULT_LENGTH,N_FEATURES),dtype=np.bool)             
     for i,equation in enumerate(itertools.islice(equations,n)):
         result=str(eval(equation))
         result=' ' *(MAX_RESULT_LENGTH-1-len(result))+result
         
         equation +='\0'
         result   +='\0'
         for t,char in enumerate(equation):
            x[i,t,CHAR_TO_INDEX[char]]=1
         for t,char in enumerate(result):
            y[i,t,CHAR_TO_INDEX[char]]=1
     return x,y
     
def build_dataset():
    generator=generate_equations_random_digit(max_count=1000000)
    n_test=round(SPLIT*N_EXAMPLES)
    n_train=N_EXAMPLES-n_test
    
    x_test,y_test=equations_to_x_y(generator,n_test)
    x_train,y_train=equations_to_x_y(generator,n_train)
    
    return x_test,y_test,x_train,y_train

def print_example_prediction(count,model,x_test,y_test):
    print('Examples:')
    prediction_indices=np.random.choice(x_test.shape[0],size=count,replace=False)
    print(np.array(x_test[prediction_indices,:]).shape)
    predictions=model.predict(x_test[prediction_indices,:])
    for i in range(count): 
        correct=one_hot_to_string(y_test[prediction_indices[i]])
        guess=one_hot_to_string(predictions[i])
        
        print('Q {} - {} '.format(one_hot_to_string(x_test[prediction_indices[i]]),one_hot_to_string(predictions[i])),end=' ')
        print('T', correct, end=' ')  
        if correct == guess:
            print( 'ok',end=' ')
        else:
            print( 'not ok',end=' ')
        print('\n')

# %%
def build_model():
    """
    Builds and returns the model based on the global config.
    """
    input_shape = (MAX_EQUATION_LENGTH, N_FEATURES)

    model = Sequential()

    # Encoder:
    model.add(Bidirectional(LSTM(20), input_shape=input_shape))
    model.add(BatchNormalization())

    # The RepeatVector-layer repeats the input n times
    model.add(RepeatVector(MAX_RESULT_LENGTH))

    # Decoder:
    model.add(Bidirectional(LSTM(20, return_sequences=True)))
    model.add(BatchNormalization())

    model.add(TimeDistributed(Dense(N_FEATURES)))
    model.add(Activation('softmax'))

    model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(lr=0.01),
        metrics=['accuracy'],
    )

    return model

# %%
def main3():
     
    
    
    model=build_model()
    model.summary()
    print()    
    
    x_test,y_test,x_train,y_train=build_dataset()
    
    print()
    print_example_prediction(5,model,x_test,y_test)
    print()
    
    for iteration in range(100):
        print()
        print('-'*50)
        print('Iteration',iteration)
        model.fit(x_train, y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(x_test, y_test))
        print_example_prediction(10,model,x_test,y_test)

# %%
main3()
##第三个实验测试不同位数的加减法。得到了不错的结果
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_9 (Bidirection (None, 40)                5760
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 40)                160
# _________________________________________________________________
# repeat_vector_5 (RepeatVecto (None, 7, 40)             0
# _________________________________________________________________
# bidirectional_10 (Bidirectio (None, 7, 40)             9760
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 7, 40)             160
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 7, 15)             615
# _________________________________________________________________
# activation_5 (Activation)    (None, 7, 15)             0
# =================================================================
# Total params: 16,455
# Trainable params: 16,295
# Non-trainable params: 160
# _________________________________________________________________
#
#
# Examples:
# (5, 10, 15)
# Q 146+944 - 1188222  T   1090 not ok
#
# Q 377-308 - 8888888  T     69 not ok
#
# Q 683-27 - 1111111  T    656 not ok
#
# Q 576-204 - 5577777  T    372 not ok
#
# Q 897-60 - -    22  T    837 not ok
#
#
#
# --------------------------------------------------
# Iteration 0
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 6s 225us/step - loss: 1.2252 - acc: 0.5737 - val_loss: 2.0235 - val_acc: 0.3652
# Examples:
# (10, 10, 15)
# Q 987-850 -   14444  T    137 not ok
#
# Q 979-127 -   14444  T    852 not ok
#
# Q 666+630 -   14444  T   1296 not ok
#
# Q 13+411 -   14444  T    424 not ok
#
# Q 796+614 -   14444  T   1410 not ok
#
# Q 283+873 -   14444  T   1156 not ok
#
# Q 544-512 -   14444  T     32 not ok
#
# Q 498+588 -   14444  T   1086 not ok
#
# Q 816-241 -   14444  T    575 not ok
#
# Q 637-438 -   14444  T    199 not ok
#
#
# --------------------------------------------------
# Iteration 1
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 105us/step - loss: 0.9703 - acc: 0.6294 - val_loss: 1.5272 - val_acc: 0.5110
# Examples:
# (10, 10, 15)
# Q 949+415 -    7844  T   1364 not ok
#
# Q 897+228 -    774  T   1125 not ok
#
# Q 692-636 -    554  T     56 not ok
#
# Q 744+583 -    5844  T   1327 not ok
#
# Q 368+554 -    584  T    922 not ok
#
# Q 979-976 -    5744  T      3 not ok
#
# Q 390+170 -    554  T    560 not ok
#
# Q 419+764 -    584  T   1183 not ok
#
# Q 140+876 -    584  T   1016 not ok
#
# Q 52+732 -    554  T    784 not ok
#
#
# --------------------------------------------------
# Iteration 2
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 105us/step - loss: 0.8916 - acc: 0.6654 - val_loss: 1.3139 - val_acc: 0.5848
# Examples:
# (10, 10, 15)
# Q 21+225 -    567  T    246 not ok
#
# Q 322+589 -    672  T    911 not ok
#
# Q 324-218 -    572  T    106 not ok
#
# Q 563+778 -    872  T   1341 not ok
#
# Q 821-634 -    572  T    187 not ok
#
# Q 850-123 -    572  T    727 not ok
#
# Q 371+891 -    772  T   1262 not ok
#
# Q 930-136 -    572  T    794 not ok
#
# Q 493-71 -    572  T    422 not ok
#
# Q 121+757 -    672  T    878 not ok
#
#
# --------------------------------------------------
# Iteration 3
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 105us/step - loss: 0.8385 - acc: 0.6838 - val_loss: 1.2510 - val_acc: 0.6106
# Examples:
# (10, 10, 15)
# Q 849-650 -    522  T    199 not ok
#
# Q 984-83 -    552  T    901 not ok
#
# Q 831+451 -   1021  T   1282 not ok
#
# Q 928-172 -    542  T    756 not ok
#
# Q 603-429 -    582  T    174 not ok
#
# Q 918+800 -   1221  T   1718 not ok
#
# Q 229+83 -    552  T    312 not ok
#
# Q 768-279 -    572  T    489 not ok
#
# Q 43+559 -    672  T    602 not ok
#
# Q 134+755 -    672  T    889 not ok
#
#
# --------------------------------------------------
# Iteration 4
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 106us/step - loss: 0.7966 - acc: 0.7002 - val_loss: 1.0947 - val_acc: 0.6391
# Examples:
# (10, 10, 15)
# Q 371-291 -    122  T     80 not ok
#
# Q 920-886 -    122  T     34 not ok
#
# Q 407-382 -    122  T     25 not ok
#
# Q 820-419 -    321  T    401 not ok
#
# Q 775-56 -    521  T    719 not ok
#
# Q 148+198 -    532  T    346 not ok
#
# Q 304-135 -    262  T    169 not ok
#
# Q 413-102 -    322  T    311 not ok
#
# Q 772+990 -   1382  T   1762 not ok
#
# Q 297-264 -    122  T     33 not ok
#
#
# --------------------------------------------------
# Iteration 5
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 106us/step - loss: 0.7452 - acc: 0.7215 - val_loss: 0.8678 - val_acc: 0.6863
# Examples:
# (10, 10, 15)
# Q 900-564 -    343  T    336 not ok
#
# Q 962-129 -     11  T    833 not ok
#
# Q 157+534 -    510  T    691 not ok
#
# Q 485+545 -    999  T   1030 not ok
#
# Q 763+271 -    944  T   1034 not ok
#
# Q 860-114 -    610  T    746 not ok
#
# Q 230+928 -    011  T   1158 not ok
#
# Q 657-88 -    411  T    569 not ok
#
# Q 536+326 -    899  T    862 not ok
#
# Q 851+774 -   1544  T   1625 not ok
#
#
# --------------------------------------------------
# Iteration 6
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 117us/step - loss: 0.6174 - acc: 0.7637 - val_loss: 0.6537 - val_acc: 0.7606
# Examples:
# (10, 10, 15)
# Q 363+438 -    891  T    801 not ok
#
# Q 87-75 -    822  T     12 not ok
#
# Q 314-236 -     58  T     78 not ok
#
# Q 188+157 -    491  T    345 not ok
#
# Q 506+896 -   1336  T   1402 not ok
#
# Q 700-464 -    236  T    236 ok
#
# Q 635-24 -    631  T    611 not ok
#
# Q 469+390 -    999  T    859 not ok
#
# Q 276+498 -    894  T    774 not ok
#
# Q 63+880 -    953  T    943 not ok
#
#
# --------------------------------------------------
# Iteration 7
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 127us/step - loss: 0.5076 - acc: 0.8091 - val_loss: 0.5070 - val_acc: 0.8114
# Examples:
# (10, 10, 15)
# Q 350-160 -    190  T    190 ok
#
# Q 841+443 -   1354  T   1284 not ok
#
# Q 375-342 -     93  T     33 not ok
#
# Q 253+632 -    955  T    885 not ok
#
# Q 453-159 -    294  T    294 ok
#
# Q 951-595 -    396  T    356 not ok
#
# Q 648+798 -   1596  T   1446 not ok
#
# Q 243+244 -    577  T    487 not ok
#
# Q 672-420 -    292  T    252 not ok
#
# Q 948-213 -    775  T    735 not ok
#
#
# --------------------------------------------------
# Iteration 8
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 123us/step - loss: 0.4501 - acc: 0.8297 - val_loss: 0.4986 - val_acc: 0.8091
# Examples:
# (10, 10, 15)
# Q 175+828 -    993  T   1003 not ok
#
# Q 125+504 -    589  T    629 not ok
#
# Q 199+522 -    761  T    721 not ok
#
# Q 639+111 -    790  T    750 not ok
#
# Q 626-313 -    393  T    313 not ok
#
# Q 873-70 -    893  T    803 not ok
#
# Q 845+380 -   1245  T   1225 not ok
#
# Q 933+94 -   1998  T   1027 not ok
#
# Q 710-404 -    346  T    306 not ok
#
# Q 557-56 -    541  T    501 not ok
#
#
# --------------------------------------------------
# Iteration 9
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 125us/step - loss: 0.4346 - acc: 0.8335 - val_loss: 0.4918 - val_acc: 0.8118
# Examples:
# (10, 10, 15)
# Q 955-416 -    539  T    539 ok
#
# Q 250+339 -    549  T    589 not ok
#
# Q 485-446 -     30  T     39 not ok
#
# Q 422+97 -    559  T    519 not ok
#
# Q 305+573 -    838  T    878 not ok
#
# Q 979+32 -    921  T   1011 not ok
#
# Q 777+982 -   1799  T   1759 not ok
#
# Q 856-689 -    157  T    167 not ok
#
# Q 765+120 -    875  T    885 not ok
#
# Q 849-768 -     51  T     81 not ok
#
#
# --------------------------------------------------
# Iteration 10
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 124us/step - loss: 0.4216 - acc: 0.8392 - val_loss: 0.4574 - val_acc: 0.8185
# Examples:
# (10, 10, 15)
# Q 686-675 -      1  T     11 not ok
#
# Q 19+227 -    226  T    246 not ok
#
# Q 706+372 -    008  T   1078 not ok
#
# Q 617-448 -    189  T    169 not ok
#
# Q 679-237 -    432  T    442 not ok
#
# Q 972-598 -    304  T    374 not ok
#
# Q 750+395 -   1105  T   1145 not ok
#
# Q 161+492 -    643  T    653 not ok
#
# Q 66+531 -    567  T    597 not ok
#
# Q 973-795 -    188  T    178 not ok
#
#
# --------------------------------------------------
# Iteration 11
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 123us/step - loss: 0.4186 - acc: 0.8406 - val_loss: 0.4197 - val_acc: 0.8339
# Examples:
# (10, 10, 15)
# Q 855+548 -   1363  T   1403 not ok
#
# Q 896-287 -    659  T    609 not ok
#
# Q 311+774 -   1015  T   1085 not ok
#
# Q 659+185 -    884  T    844 not ok
#
# Q 635-24 -    661  T    611 not ok
#
# Q 819-109 -    650  T    710 not ok
#
# Q 563+778 -   1351  T   1341 not ok
#
# Q 710-635 -     15  T     75 not ok
#
# Q 645+969 -   1564  T   1614 not ok
#
# Q 145+797 -    932  T    942 not ok
#
#
# --------------------------------------------------
# Iteration 12
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 119us/step - loss: 0.4118 - acc: 0.8427 - val_loss: 0.4745 - val_acc: 0.8130
# Examples:
# (10, 10, 15)
# Q 488+793 -   1351  T   1281 not ok
#
# Q 812+736 -   1578  T   1548 not ok
#
# Q 683-27 -    656  T    656 ok
#
# Q 730-630 -    150  T    100 not ok
#
# Q 235-10 -    295  T    225 not ok
#
# Q 426-246 -    270  T    180 not ok
#
# Q 458-11 -    457  T    447 not ok
#
# Q 829-179 -    750  T    650 not ok
#
# Q 993-23 -    920  T    970 not ok
#
# Q 250-22 -    258  T    228 not ok
#
#
# --------------------------------------------------
# Iteration 13
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 121us/step - loss: 0.4070 - acc: 0.8447 - val_loss: 0.4193 - val_acc: 0.8412
# Examples:
# (10, 10, 15)
# Q 797-658 -    139  T    139 ok
#
# Q 605+289 -    814  T    894 not ok
#
# Q 416+540 -    916  T    956 not ok
#
# Q 33+504 -    527  T    537 not ok
#
# Q 518-342 -    116  T    176 not ok
#
# Q 12+425 -    297  T    437 not ok
#
# Q 883-119 -    774  T    764 not ok
#
# Q 92+397 -    464  T    489 not ok
#
# Q 727+766 -   1463  T   1493 not ok
#
# Q 527-481 -     16  T     46 not ok
#
#
# --------------------------------------------------
# Iteration 14
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 122us/step - loss: 0.3886 - acc: 0.8506 - val_loss: 0.4441 - val_acc: 0.8327
# Examples:
# (10, 10, 15)
# Q 453-159 -    294  T    294 ok
#
# Q 711-33 -    658  T    678 not ok
#
# Q 932+881 -   1853  T   1813 not ok
#
# Q 985+396 -   1461  T   1381 not ok
#
# Q 954-338 -    626  T    616 not ok
#
# Q 488+593 -   1151  T   1081 not ok
#
# Q 816-241 -    554  T    575 not ok
#
# Q 418+969 -   1347  T   1387 not ok
#
# Q 712+673 -   1455  T   1385 not ok
#
# Q 911-867 -     44  T     44 ok
#
#
# --------------------------------------------------
# Iteration 15
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 126us/step - loss: 0.3395 - acc: 0.8648 - val_loss: 0.3828 - val_acc: 0.8484
# Examples:
# (10, 10, 15)
# Q 798-790 -     18  T      8 not ok
#
# Q 633+122 -    755  T    755 ok
#
# Q 923+95 -    908  T   1018 not ok
#
# Q 438-413 -    125  T     25 not ok
#
# Q 846-32 -    894  T    814 not ok
#
# Q 16+394 -    220  T    410 not ok
#
# Q 771+160 -    831  T    931 not ok
#
# Q 709-367 -    352  T    342 not ok
#
# Q 932-82 -    820  T    850 not ok
#
# Q 568-200 -    358  T    368 not ok
#
#
# --------------------------------------------------
# Iteration 16
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 138us/step - loss: 0.3162 - acc: 0.8719 - val_loss: 0.3788 - val_acc: 0.8500
# Examples:
# (10, 10, 15)
# Q 387-287 -    180  T    100 not ok
#
# Q 327+421 -    738  T    748 not ok
#
# Q 476+808 -   1274  T   1284 not ok
#
# Q 265-249 -     16  T     16 ok
#
# Q 435-83 -    332  T    352 not ok
#
# Q 719-667 -     52  T     52 ok
#
# Q 215+483 -    618  T    698 not ok
#
# Q 262+388 -    660  T    650 not ok
#
# Q 867-317 -    560  T    550 not ok
#
# Q 666+997 -   1653  T   1663 not ok
#
#
# --------------------------------------------------
# Iteration 17
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 126us/step - loss: 0.3018 - acc: 0.8767 - val_loss: 0.3381 - val_acc: 0.8655
# Examples:
# (10, 10, 15)
# Q 119+173 -    232  T    292 not ok
#
# Q 487+514 -    971  T   1001 not ok
#
# Q 689-193 -    486  T    496 not ok
#
# Q 941+749 -   1690  T   1690 ok
#
# Q 390+170 -    530  T    560 not ok
#
# Q 832+822 -   1614  T   1654 not ok
#
# Q 538+469 -    987  T   1007 not ok
#
# Q 517-165 -    352  T    352 ok
#
# Q 84+905 -    079  T    989 not ok
#
# Q 814-640 -    154  T    174 not ok
#
#
# --------------------------------------------------
# Iteration 18
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 127us/step - loss: 0.2742 - acc: 0.8866 - val_loss: 0.3033 - val_acc: 0.8722
# Examples:
# (10, 10, 15)
# Q 882-64 -    918  T    818 not ok
#
# Q 14+128 -    192  T    142 not ok
#
# Q 906-220 -    796  T    686 not ok
#
# Q 300-77 -    133  T    223 not ok
#
# Q 963+394 -   1367  T   1357 not ok
#
# Q 274-193 -     71  T     81 not ok
#
# Q 885-735 -    150  T    150 ok
#
# Q 416+182 -    608  T    598 not ok
#
# Q 806-426 -    380  T    380 ok
#
# Q 133-15 -     58  T    118 not ok
#
#
# --------------------------------------------------
# Iteration 19
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 126us/step - loss: 0.2121 - acc: 0.9115 - val_loss: 0.2406 - val_acc: 0.9024
# Examples:
# (10, 10, 15)
# Q 281+685 -    966  T    966 ok
#
# Q 827+127 -    954  T    954 ok
#
# Q 155+163 -    308  T    318 not ok
#
# Q 241+116 -    367  T    357 not ok
#
# Q 974-880 -     84  T     94 not ok
#
# Q 536+803 -   1349  T   1339 not ok
#
# Q 63+648 -    651  T    711 not ok
#
# Q 653+221 -    884  T    874 not ok
#
# Q 92-77 -     45  T     15 not ok
#
# Q 412+776 -   1187  T   1188 not ok
#
#
# --------------------------------------------------
# Iteration 20
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 129us/step - loss: 0.1760 - acc: 0.9281 - val_loss: 0.1846 - val_acc: 0.9242
# Examples:
# (10, 10, 15)
# Q 941+521 -   1472  T   1462 not ok
#
# Q 334+114 -    448  T    448 ok
#
# Q 536-487 -     49  T     49 ok
#
# Q 634-307 -    327  T    327 ok
#
# Q 549+858 -   1407  T   1407 ok
#
# Q 636-330 -    316  T    306 not ok
#
# Q 373-312 -     61  T     61 ok
#
# Q 21+225 -    256  T    246 not ok
#
# Q 572+839 -   1301  T   1411 not ok
#
# Q 215+890 -   1105  T   1105 ok
#
#
# --------------------------------------------------
# Iteration 21
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 132us/step - loss: 0.1324 - acc: 0.9495 - val_loss: 0.2180 - val_acc: 0.9134
# Examples:
# (10, 10, 15)
# Q 570-73 -    497  T    497 ok
#
# Q 476+131 -    507  T    607 not ok
#
# Q 855+548 -   1303  T   1403 not ok
#
# Q 787-453 -    334  T    334 ok
#
# Q 615+975 -   1580  T   1590 not ok
#
# Q 854+615 -   1369  T   1469 not ok
#
# Q 711-20 -    691  T    691 ok
#
# Q 434+365 -    709  T    799 not ok
#
# Q 457-351 -    106  T    106 ok
#
# Q 182+735 -    917  T    917 ok
#
#
# --------------------------------------------------
# Iteration 22
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 129us/step - loss: 0.1153 - acc: 0.9565 - val_loss: 0.2149 - val_acc: 0.9193
# Examples:
# (10, 10, 15)
# Q 330+684 -   1014  T   1014 ok
#
# Q 586-399 -     87  T    187 not ok
#
# Q 137+571 -    708  T    708 ok
#
# Q 451+266 -    717  T    717 ok
#
# Q 721+525 -   1246  T   1246 ok
#
# Q 635-24 -    611  T    611 ok
#
# Q 79+518 -    497  T    597 not ok
#
# Q 290+512 -    702  T    802 not ok
#
# Q 985-20 -    955  T    965 not ok
#
# Q 434+365 -    709  T    799 not ok
#
#
# --------------------------------------------------
# Iteration 23
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 126us/step - loss: 0.1005 - acc: 0.9637 - val_loss: 0.2352 - val_acc: 0.9301
# Examples:
# (10, 10, 15)
# Q 520-271 -    249  T    249 ok
#
# Q 265-249 -     16  T     16 ok
#
# Q 850-744 -    106  T    106 ok
#
# Q 261+567 -    728  T    828 not ok
#
# Q 670+640 -   1210  T   1310 not ok
#
# Q 644-140 -    504  T    504 ok
#
# Q 530+421 -    851  T    951 not ok
#
# Q 874-456 -    418  T    418 ok
#
# Q 809-685 -    124  T    124 ok
#
# Q 665-363 -    302  T    302 ok
#
#
# --------------------------------------------------
# Iteration 24
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 129us/step - loss: 0.0879 - acc: 0.9679 - val_loss: 0.1031 - val_acc: 0.9621
# Examples:
# (10, 10, 15)
# Q 295+280 -    575  T    575 ok
#
# Q 900-786 -    118  T    114 not ok
#
# Q 739-315 -    424  T    424 ok
#
# Q 721+313 -   1024  T   1034 not ok
#
# Q 943-853 -     80  T     90 not ok
#
# Q 970-419 -    551  T    551 ok
#
# Q 209-173 -     36  T     36 ok
#
# Q 65+154 -    229  T    219 not ok
#
# Q 959-487 -    472  T    472 ok
#
# Q 193+188 -    381  T    381 ok
#
#
# --------------------------------------------------
# Iteration 25
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 132us/step - loss: 0.0655 - acc: 0.9770 - val_loss: 0.1145 - val_acc: 0.9577
# Examples:
# (10, 10, 15)
# Q 770-680 -    190  T     90 not ok
#
# Q 939+793 -   1732  T   1732 ok
#
# Q 341+589 -    830  T    930 not ok
#
# Q 221+527 -    748  T    748 ok
#
# Q 52+832 -    874  T    884 not ok
#
# Q 674-449 -    225  T    225 ok
#
# Q 981-742 -    239  T    239 ok
#
# Q 912-169 -    743  T    743 ok
#
# Q 968+667 -   1635  T   1635 ok
#
# Q 671-45 -    626  T    626 ok
#
#
# --------------------------------------------------
# Iteration 26
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 130us/step - loss: 0.0578 - acc: 0.9802 - val_loss: 0.0555 - val_acc: 0.9793
# Examples:
# (10, 10, 15)
# Q 984-83 -    901  T    901 ok
#
# Q 716+591 -   1307  T   1307 ok
#
# Q 488+593 -   1081  T   1081 ok
#
# Q 726-498 -    228  T    228 ok
#
# Q 527+260 -    787  T    787 ok
#
# Q 624-529 -     95  T     95 ok
#
# Q 810+940 -   1750  T   1750 ok
#
# Q 880-444 -    436  T    436 ok
#
# Q 918-889 -     39  T     29 not ok
#
# Q 66+450 -    526  T    516 not ok
#
#
# --------------------------------------------------
# Iteration 27
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 134us/step - loss: 0.0557 - acc: 0.9808 - val_loss: 0.0625 - val_acc: 0.9770
# Examples:
# (10, 10, 15)
# Q 932+881 -   1813  T   1813 ok
#
# Q 626-313 -    313  T    313 ok
#
# Q 401+112 -    513  T    513 ok
#
# Q 939-814 -    125  T    125 ok
#
# Q 543-368 -    175  T    175 ok
#
# Q 124-93 -     31  T     31 ok
#
# Q 284+113 -    397  T    397 ok
#
# Q 876-634 -    242  T    242 ok
#
# Q 544-512 -     32  T     32 ok
#
# Q 250+339 -    589  T    589 ok
#
#
# --------------------------------------------------
# Iteration 28
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 139us/step - loss: 0.0582 - acc: 0.9794 - val_loss: 0.0611 - val_acc: 0.9777
# Examples:
# (10, 10, 15)
# Q 415+766 -   1181  T   1181 ok
#
# Q 519-57 -    462  T    462 ok
#
# Q 991-368 -    623  T    623 ok
#
# Q 770-760 -     10  T     10 ok
#
# Q 130+409 -    539  T    539 ok
#
# Q 940+749 -   1689  T   1689 ok
#
# Q 989-203 -    786  T    786 ok
#
# Q 440-307 -    133  T    133 ok
#
# Q 133-15 -    118  T    118 ok
#
# Q 24+170 -    194  T    194 ok
#
#
# --------------------------------------------------
# Iteration 29
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 136us/step - loss: 0.0501 - acc: 0.9827 - val_loss: 0.0443 - val_acc: 0.9835
# Examples:
# (10, 10, 15)
# Q 835-565 -    270  T    270 ok
#
# Q 650+942 -   1592  T   1592 ok
#
# Q 91+133 -    234  T    224 not ok
#
# Q 404-140 -    164  T    264 not ok
#
# Q 813+562 -   1375  T   1375 ok
#
# Q 203+163 -    366  T    366 ok
#
# Q 117+261 -    378  T    378 ok
#
# Q 81-68 -     23  T     13 not ok
#
# Q 427-133 -    294  T    294 ok
#
# Q 314-275 -     39  T     39 ok
#
#
# --------------------------------------------------
# Iteration 30
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 127us/step - loss: 0.0441 - acc: 0.9846 - val_loss: 0.0449 - val_acc: 0.9841
# Examples:
# (10, 10, 15)
# Q 656-315 -    341  T    341 ok
#
# Q 953+965 -   1918  T   1918 ok
#
# Q 979-976 -      3  T      3 ok
#
# Q 839-613 -    226  T    226 ok
#
# Q 943-789 -    154  T    154 ok
#
# Q 756-181 -    575  T    575 ok
#
# Q 842+288 -   1130  T   1130 ok
#
# Q 920-207 -    713  T    713 ok
#
# Q 461-120 -    341  T    341 ok
#
# Q 947-78 -    879  T    869 not ok
#
#
# --------------------------------------------------
# Iteration 31
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 138us/step - loss: 0.0397 - acc: 0.9863 - val_loss: 0.0584 - val_acc: 0.9802
# Examples:
# (10, 10, 15)
# Q 680+539 -   1219  T   1219 ok
#
# Q 802-379 -    423  T    423 ok
#
# Q 600-567 -     33  T     33 ok
#
# Q 511+176 -    687  T    687 ok
#
# Q 959-487 -    472  T    472 ok
#
# Q 679-23 -    656  T    656 ok
#
# Q 376-232 -     44  T    144 not ok
#
# Q 435+271 -    706  T    706 ok
#
# Q 672-375 -    297  T    297 ok
#
# Q 611+18 -    639  T    629 not ok
#
#
# --------------------------------------------------
# Iteration 32
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0460 - acc: 0.9844 - val_loss: 0.0955 - val_acc: 0.9667
# Examples:
# (10, 10, 15)
# Q 557-56 -    401  T    501 not ok
#
# Q 597-101 -    496  T    496 ok
#
# Q 533-403 -    130  T    130 ok
#
# Q 798-790 -      8  T      8 ok
#
# Q 637-365 -    272  T    272 ok
#
# Q 939-490 -    449  T    449 ok
#
# Q 34+311 -    345  T    345 ok
#
# Q 344+265 -    609  T    609 ok
#
# Q 802-108 -    694  T    694 ok
#
# Q 435+983 -   1418  T   1418 ok
#
#
# --------------------------------------------------
# Iteration 33
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 139us/step - loss: 0.0405 - acc: 0.9862 - val_loss: 0.1356 - val_acc: 0.9553
# Examples:
# (10, 10, 15)
# Q 776+770 -   1446  T   1546 not ok
#
# Q 282+471 -    753  T    753 ok
#
# Q 873-489 -    384  T    384 ok
#
# Q 168+85 -    253  T    253 ok
#
# Q 580+194 -    774  T    774 ok
#
# Q 514-139 -    375  T    375 ok
#
# Q 241+116 -    357  T    357 ok
#
# Q 479-437 -     42  T     42 ok
#
# Q 143+44 -    187  T    187 ok
#
# Q 431+354 -    785  T    785 ok
#
#
# --------------------------------------------------
# Iteration 34
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 137us/step - loss: 0.0330 - acc: 0.9889 - val_loss: 0.0293 - val_acc: 0.9899
# Examples:
# (10, 10, 15)
# Q 999-694 -    305  T    305 ok
#
# Q 364+239 -    603  T    603 ok
#
# Q 712-202 -    510  T    510 ok
#
# Q 370+582 -    952  T    952 ok
#
# Q 939-490 -    449  T    449 ok
#
# Q 630-327 -    303  T    303 ok
#
# Q 135+745 -    880  T    880 ok
#
# Q 604-472 -    132  T    132 ok
#
# Q 686-299 -    387  T    387 ok
#
# Q 864-347 -    517  T    517 ok
#
#
# --------------------------------------------------
# Iteration 35
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 136us/step - loss: 0.0311 - acc: 0.9895 - val_loss: 0.0322 - val_acc: 0.9884
# Examples:
# (10, 10, 15)
# Q 900-564 -    336  T    336 ok
#
# Q 946+873 -   1819  T   1819 ok
#
# Q 598-370 -    228  T    228 ok
#
# Q 259-55 -    204  T    204 ok
#
# Q 859-564 -    295  T    295 ok
#
# Q 327+373 -    700  T    700 ok
#
# Q 928-172 -    756  T    756 ok
#
# Q 405+514 -    919  T    919 ok
#
# Q 850-744 -    106  T    106 ok
#
# Q 137-63 -     84  T     74 not ok
#
#
# --------------------------------------------------
# Iteration 36
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 139us/step - loss: 0.0235 - acc: 0.9921 - val_loss: 0.0295 - val_acc: 0.9909
# Examples:
# (10, 10, 15)
# Q 519-57 -    462  T    462 ok
#
# Q 726+731 -   1457  T   1457 ok
#
# Q 503+629 -   1132  T   1132 ok
#
# Q 314-228 -     86  T     86 ok
#
# Q 582+977 -   1559  T   1559 ok
#
# Q 340-111 -    229  T    229 ok
#
# Q 496-94 -    302  T    402 not ok
#
# Q 999+384 -   1383  T   1383 ok
#
# Q 928-172 -    856  T    756 not ok
#
# Q 586+823 -   1409  T   1409 ok
#
#
# --------------------------------------------------
# Iteration 37
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 128us/step - loss: 0.0267 - acc: 0.9910 - val_loss: 0.0658 - val_acc: 0.9782
# Examples:
# (10, 10, 15)
# Q 137+683 -    820  T    820 ok
#
# Q 427-133 -    294  T    294 ok
#
# Q 620+39 -    659  T    659 ok
#
# Q 726+942 -   1668  T   1668 ok
#
# Q 853-408 -    445  T    445 ok
#
# Q 176-54 -    122  T    122 ok
#
# Q 794-423 -    371  T    371 ok
#
# Q 146+944 -   1090  T   1090 ok
#
# Q 946+873 -   1819  T   1819 ok
#
# Q 475+35 -    510  T    510 ok
#
#
# --------------------------------------------------
# Iteration 38
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 128us/step - loss: 0.0206 - acc: 0.9932 - val_loss: 0.0152 - val_acc: 0.9955
# Examples:
# (10, 10, 15)
# Q 173-92 -     81  T     81 ok
#
# Q 582+830 -   1412  T   1412 ok
#
# Q 431+919 -   1350  T   1350 ok
#
# Q 452+580 -   1032  T   1032 ok
#
# Q 788+201 -    989  T    989 ok
#
# Q 760-110 -    650  T    650 ok
#
# Q 938-397 -    541  T    541 ok
#
# Q 137+299 -    436  T    436 ok
#
# Q 787+419 -   1206  T   1206 ok
#
# Q 392-58 -    334  T    334 ok
#
#
# --------------------------------------------------
# Iteration 39
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 131us/step - loss: 0.0352 - acc: 0.9882 - val_loss: 0.0947 - val_acc: 0.9707
# Examples:
# (10, 10, 15)
# Q 708+729 -   1537  T   1437 not ok
#
# Q 60+87 -    147  T    147 ok
#
# Q 972-724 -    248  T    248 ok
#
# Q 922+39 -    961  T    961 ok
#
# Q 685+855 -   1540  T   1540 ok
#
# Q 125+828 -   1953  T    953 not ok
#
# Q 900-564 -    436  T    336 not ok
#
# Q 312-33 -    289  T    279 not ok
#
# Q 839-295 -    544  T    544 ok
#
# Q 534+895 -   1529  T   1429 not ok
#
#
# --------------------------------------------------
# Iteration 40
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 3s 127us/step - loss: 0.0321 - acc: 0.9886 - val_loss: 0.0336 - val_acc: 0.9874
# Examples:
# (10, 10, 15)
# Q 290-197 -     93  T     93 ok
#
# Q 694+981 -   1575  T   1675 not ok
#
# Q 954-877 -     77  T     77 ok
#
# Q 237-128 -    109  T    109 ok
#
# Q 457-351 -    106  T    106 ok
#
# Q 981-250 -    731  T    731 ok
#
# Q 468+894 -   1362  T   1362 ok
#
# Q 749-291 -    458  T    458 ok
#
# Q 598+778 -   1376  T   1376 ok
#
# Q 362+190 -    552  T    552 ok
#
#
# --------------------------------------------------
# Iteration 41
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 136us/step - loss: 0.0275 - acc: 0.9908 - val_loss: 0.0148 - val_acc: 0.9949
# Examples:
# (10, 10, 15)
# Q 768+914 -   1682  T   1682 ok
#
# Q 835+977 -   1812  T   1812 ok
#
# Q 305+573 -    878  T    878 ok
#
# Q 751-317 -    434  T    434 ok
#
# Q 100+180 -    280  T    280 ok
#
# Q 920-454 -    466  T    466 ok
#
# Q 673+515 -   1088  T   1188 not ok
#
# Q 145-121 -     24  T     24 ok
#
# Q 570-15 -    555  T    555 ok
#
# Q 916-480 -    436  T    436 ok
#
#
# --------------------------------------------------
# Iteration 42
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 136us/step - loss: 0.0157 - acc: 0.9951 - val_loss: 0.0190 - val_acc: 0.9935
# Examples:
# (10, 10, 15)
# Q 536+803 -   1339  T   1339 ok
#
# Q 412+34 -    446  T    446 ok
#
# Q 768-477 -    291  T    291 ok
#
# Q 487+904 -   1391  T   1391 ok
#
# Q 773-719 -     54  T     54 ok
#
# Q 757-225 -    532  T    532 ok
#
# Q 570-15 -    555  T    555 ok
#
# Q 391-358 -     33  T     33 ok
#
# Q 681+995 -   1676  T   1676 ok
#
# Q 278+814 -   1192  T   1092 not ok
#
#
# --------------------------------------------------
# Iteration 43
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 132us/step - loss: 0.0202 - acc: 0.9934 - val_loss: 0.0387 - val_acc: 0.9852
# Examples:
# (10, 10, 15)
# Q 690+919 -   1609  T   1609 ok
#
# Q 109+212 -    321  T    321 ok
#
# Q 75+820 -    895  T    895 ok
#
# Q 978-973 -      5  T      5 ok
#
# Q 408+158 -    566  T    566 ok
#
# Q 981-742 -    239  T    239 ok
#
# Q 94+777 -    871  T    871 ok
#
# Q 876-719 -    157  T    157 ok
#
# Q 323+387 -    710  T    710 ok
#
# Q 453+843 -   1296  T   1296 ok
#
#
# --------------------------------------------------
# Iteration 44
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 132us/step - loss: 0.0236 - acc: 0.9919 - val_loss: 0.0343 - val_acc: 0.9871
# Examples:
# (10, 10, 15)
# Q 604-472 -    132  T    132 ok
#
# Q 639-104 -    535  T    535 ok
#
# Q 719-30 -    689  T    689 ok
#
# Q 534+502 -   1036  T   1036 ok
#
# Q 531-330 -    201  T    201 ok
#
# Q 841-61 -    780  T    780 ok
#
# Q 913+95 -   1908  T   1008 not ok
#
# Q 229-199 -     30  T     30 ok
#
# Q 445+804 -   1249  T   1249 ok
#
# Q 689-193 -    496  T    496 ok
#
#
# --------------------------------------------------
# Iteration 45
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 132us/step - loss: 0.0244 - acc: 0.9919 - val_loss: 0.0153 - val_acc: 0.9948
# Examples:
# (10, 10, 15)
# Q 679-237 -    442  T    442 ok
#
# Q 171+465 -    636  T    636 ok
#
# Q 468+561 -   1029  T   1029 ok
#
# Q 95+507 -    602  T    602 ok
#
# Q 203+503 -    706  T    706 ok
#
# Q 912-449 -    463  T    463 ok
#
# Q 502+522 -   1024  T   1024 ok
#
# Q 73+390 -    463  T    463 ok
#
# Q 862-179 -    683  T    683 ok
#
# Q 830-77 -    753  T    753 ok
#
#
# --------------------------------------------------
# Iteration 46
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 137us/step - loss: 0.0236 - acc: 0.9922 - val_loss: 0.0248 - val_acc: 0.9908
# Examples:
# (10, 10, 15)
# Q 938-397 -    541  T    541 ok
#
# Q 648-500 -    148  T    148 ok
#
# Q 718-557 -    161  T    161 ok
#
# Q 905+771 -   1676  T   1676 ok
#
# Q 422-357 -     65  T     65 ok
#
# Q 245-167 -     78  T     78 ok
#
# Q 986-803 -    183  T    183 ok
#
# Q 517-247 -    260  T    270 not ok
#
# Q 304-143 -    161  T    161 ok
#
# Q 307-260 -     47  T     47 ok
#
#
# --------------------------------------------------
# Iteration 47
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 150us/step - loss: 0.0256 - acc: 0.9910 - val_loss: 0.0621 - val_acc: 0.9808
# Examples:
# (10, 10, 15)
# Q 806-426 -    380  T    380 ok
#
# Q 493-209 -    284  T    284 ok
#
# Q 397+662 -   1059  T   1059 ok
#
# Q 367+165 -    532  T    532 ok
#
# Q 943+216 -   1159  T   1159 ok
#
# Q 43+317 -    360  T    360 ok
#
# Q 457-351 -    1 6  T    106 not ok
#
# Q 129-17 -    112  T    112 ok
#
# Q 677-55 -    622  T    622 ok
#
# Q 62+929 -   0991  T    991 not ok
#
#
# --------------------------------------------------
# Iteration 48
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 146us/step - loss: 0.0245 - acc: 0.9919 - val_loss: 0.0160 - val_acc: 0.9947
# Examples:
# (10, 10, 15)
# Q 953-806 -    147  T    147 ok
#
# Q 527+508 -   1035  T   1035 ok
#
# Q 259-55 -    204  T    204 ok
#
# Q 427+413 -    840  T    840 ok
#
# Q 372+299 -    671  T    671 ok
#
# Q 725-350 -    375  T    375 ok
#
# Q 27+45 -     72  T     72 ok
#
# Q 884+21 -    905  T    905 ok
#
# Q 724-155 -    569  T    569 ok
#
# Q 988-811 -    177  T    177 ok
#
#
# --------------------------------------------------
# Iteration 49
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 148us/step - loss: 0.0225 - acc: 0.9928 - val_loss: 0.0745 - val_acc: 0.9766
# Examples:
# (10, 10, 15)
# Q 765-361 -    304  T    404 not ok
#
# Q 370+855 -   1225  T   1225 ok
#
# Q 52+832 -    884  T    884 ok
#
# Q 821+273 -   1094  T   1094 ok
#
# Q 327-319 -      8  T      8 ok
#
# Q 998+750 -   1648  T   1748 not ok
#
# Q 614-203 -    311  T    411 not ok
#
# Q 847+281 -   1128  T   1128 ok
#
# Q 952+781 -   1633  T   1733 not ok
#
# Q 534+502 -   1036  T   1036 ok
#
#
# --------------------------------------------------
# Iteration 50
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 143us/step - loss: 0.0169 - acc: 0.9946 - val_loss: 0.0157 - val_acc: 0.9944
# Examples:
# (10, 10, 15)
# Q 391-105 -    286  T    286 ok
#
# Q 835+977 -   1812  T   1812 ok
#
# Q 686-675 -     11  T     11 ok
#
# Q 430+408 -    838  T    838 ok
#
# Q 832+822 -   1654  T   1654 ok
#
# Q 985+396 -   1381  T   1381 ok
#
# Q 231+629 -    860  T    860 ok
#
# Q 687-387 -    300  T    300 ok
#
# Q 97+145 -    242  T    242 ok
#
# Q 885-735 -    150  T    150 ok
#
#
# --------------------------------------------------
# Iteration 51
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0103 - acc: 0.9969 - val_loss: 0.0137 - val_acc: 0.9953
# Examples:
# (10, 10, 15)
# Q 239-90 -    149  T    149 ok
#
# Q 48+262 -    300  T    310 not ok
#
# Q 463-394 -     69  T     69 ok
#
# Q 488+593 -   1081  T   1081 ok
#
# Q 731-145 -    586  T    586 ok
#
# Q 765+23 -    788  T    788 ok
#
# Q 300-77 -    223  T    223 ok
#
# Q 715-31 -    684  T    684 ok
#
# Q 43+317 -    360  T    360 ok
#
# Q 976-882 -     94  T     94 ok
#
#
# --------------------------------------------------
# Iteration 52
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0135 - acc: 0.9956 - val_loss: 0.0113 - val_acc: 0.9972
# Examples:
# (10, 10, 15)
# Q 834-658 -    176  T    176 ok
#
# Q 526+235 -    761  T    761 ok
#
# Q 944-502 -    442  T    442 ok
#
# Q 19+437 -    456  T    456 ok
#
# Q 838-558 -    280  T    280 ok
#
# Q 650-42 -    608  T    608 ok
#
# Q 592+235 -    827  T    827 ok
#
# Q 886-342 -    544  T    544 ok
#
# Q 119-18 -    101  T    101 ok
#
# Q 486-49 -    436  T    437 not ok
#
#
# --------------------------------------------------
# Iteration 53
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 147us/step - loss: 0.0247 - acc: 0.9921 - val_loss: 0.0497 - val_acc: 0.9849
# Examples:
# (10, 10, 15)
# Q 660-361 -    299  T    299 ok
#
# Q 692-367 -    325  T    325 ok
#
# Q 197+670 -    867  T    867 ok
#
# Q 250+339 -    589  T    589 ok
#
# Q 828-601 -    227  T    227 ok
#
# Q 628+41 -    669  T    669 ok
#
# Q 566+818 -   1384  T   1384 ok
#
# Q 894-548 -    346  T    346 ok
#
# Q 81-68 -     13  T     13 ok
#
# Q 840+635 -   1575  T   1475 not ok
#
#
# --------------------------------------------------
# Iteration 54
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 148us/step - loss: 0.0235 - acc: 0.9920 - val_loss: 0.0868 - val_acc: 0.9741
# Examples:
# (10, 10, 15)
# Q 858-137 -    821  T    721 not ok
#
# Q 821-634 -    187  T    187 ok
#
# Q 118+133 -    251  T    251 ok
#
# Q 890-486 -    404  T    404 ok
#
# Q 617-448 -    169  T    169 ok
#
# Q 600-567 -     33  T     33 ok
#
# Q 828+557 -   1385  T   1385 ok
#
# Q 682+755 -   1437  T   1437 ok
#
# Q 842-213 -    729  T    629 not ok
#
# Q 979+872 -   1951  T   1851 not ok
#
#
# --------------------------------------------------
# Iteration 55
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 146us/step - loss: 0.0132 - acc: 0.9958 - val_loss: 0.0097 - val_acc: 0.9970
# Examples:
# (10, 10, 15)
# Q 949+415 -   1364  T   1364 ok
#
# Q 881+320 -   1201  T   1201 ok
#
# Q 890-486 -    404  T    404 ok
#
# Q 590-270 -    320  T    320 ok
#
# Q 366-195 -    171  T    171 ok
#
# Q 899-716 -    183  T    183 ok
#
# Q 576-441 -    135  T    135 ok
#
# Q 70+294 -    364  T    364 ok
#
# Q 939-814 -    125  T    125 ok
#
# Q 794+526 -   1320  T   1320 ok
#
#
# --------------------------------------------------
# Iteration 56
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 139us/step - loss: 0.0123 - acc: 0.9962 - val_loss: 0.0226 - val_acc: 0.9927
# Examples:
# (10, 10, 15)
# Q 438-399 -     39  T     39 ok
#
# Q 229-199 -     30  T     30 ok
#
# Q 656-250 -    406  T    406 ok
#
# Q 634-230 -    404  T    404 ok
#
# Q 175+236 -    311  T    411 not ok
#
# Q 352+38 -    390  T    390 ok
#
# Q 949-504 -    545  T    445 not ok
#
# Q 711-431 -    280  T    280 ok
#
# Q 842+255 -   1097  T   1097 ok
#
# Q 153+978 -   1131  T   1131 ok
#
#
# --------------------------------------------------
# Iteration 57
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 138us/step - loss: 0.0146 - acc: 0.9950 - val_loss: 0.0155 - val_acc: 0.9953
# Examples:
# (10, 10, 15)
# Q 517+998 -   1515  T   1515 ok
#
# Q 630-68 -    562  T    562 ok
#
# Q 299-66 -    233  T    233 ok
#
# Q 530-528 -      2  T      2 ok
#
# Q 677-576 -    101  T    101 ok
#
# Q 973-418 -    555  T    555 ok
#
# Q 749-291 -    458  T    458 ok
#
# Q 782-141 -    641  T    641 ok
#
# Q 695+706 -   1401  T   1401 ok
#
# Q 791+945 -   1736  T   1736 ok
#
#
# --------------------------------------------------
# Iteration 58
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 137us/step - loss: 0.0123 - acc: 0.9961 - val_loss: 0.0096 - val_acc: 0.9968
# Examples:
# (10, 10, 15)
# Q 87+822 -    909  T    909 ok
#
# Q 344+130 -    474  T    474 ok
#
# Q 193-20 -    173  T    173 ok
#
# Q 920-397 -    523  T    523 ok
#
# Q 808-364 -    444  T    444 ok
#
# Q 13+434 -    447  T    447 ok
#
# Q 672-375 -    297  T    297 ok
#
# Q 498+210 -    708  T    708 ok
#
# Q 508-72 -    436  T    436 ok
#
# Q 942+708 -   1650  T   1650 ok
#
#
# --------------------------------------------------
# Iteration 59
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 139us/step - loss: 0.0172 - acc: 0.9945 - val_loss: 0.0113 - val_acc: 0.9967
# Examples:
# (10, 10, 15)
# Q 87-28 -     59  T     59 ok
#
# Q 569+406 -    975  T    975 ok
#
# Q 704+238 -    942  T    942 ok
#
# Q 455+824 -   1279  T   1279 ok
#
# Q 773-719 -     54  T     54 ok
#
# Q 979-976 -      3  T      3 ok
#
# Q 191-117 -     74  T     74 ok
#
# Q 784+370 -   1154  T   1154 ok
#
# Q 539+373 -    912  T    912 ok
#
# Q 633-531 -    102  T    102 ok
#
#
# --------------------------------------------------
# Iteration 60
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0165 - acc: 0.9948 - val_loss: 0.0175 - val_acc: 0.9943
# Examples:
# (10, 10, 15)
# Q 947-109 -    838  T    838 ok
#
# Q 832+143 -    975  T    975 ok
#
# Q 751-438 -    313  T    313 ok
#
# Q 196+600 -    796  T    796 ok
#
# Q 807-364 -    443  T    443 ok
#
# Q 642+818 -   1460  T   1460 ok
#
# Q 978+236 -   1214  T   1214 ok
#
# Q 783-301 -    482  T    482 ok
#
# Q 963+624 -   1587  T   1587 ok
#
# Q 525+924 -   1449  T   1449 ok
#
#
# --------------------------------------------------
# Iteration 61
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 138us/step - loss: 0.0216 - acc: 0.9931 - val_loss: 0.0388 - val_acc: 0.9870
# Examples:
# (10, 10, 15)
# Q 952-68 -    884  T    884 ok
#
# Q 904-525 -    379  T    379 ok
#
# Q 766-720 -     46  T     46 ok
#
# Q 631-267 -    364  T    364 ok
#
# Q 782-141 -    641  T    641 ok
#
# Q 27+45 -     72  T     72 ok
#
# Q 538-277 -    261  T    261 ok
#
# Q 927-324 -    603  T    603 ok
#
# Q 884-604 -    280  T    280 ok
#
# Q 949+292 -   1231  T   1241 not ok
#
#
# --------------------------------------------------
# Iteration 62
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 135us/step - loss: 0.0164 - acc: 0.9944 - val_loss: 0.0100 - val_acc: 0.9972
# Examples:
# (10, 10, 15)
# Q 777-639 -    138  T    138 ok
#
# Q 122+97 -    219  T    219 ok
#
# Q 941-682 -    259  T    259 ok
#
# Q 166-112 -     54  T     54 ok
#
# Q 294+18 -    312  T    312 ok
#
# Q 825-334 -    491  T    491 ok
#
# Q 78+612 -    790  T    690 not ok
#
# Q 369+977 -   1346  T   1346 ok
#
# Q 918-440 -    478  T    478 ok
#
# Q 878+61 -    939  T    939 ok
#
#
# --------------------------------------------------
# Iteration 63
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 152us/step - loss: 0.0205 - acc: 0.9931 - val_loss: 0.0085 - val_acc: 0.9978
# Examples:
# (10, 10, 15)
# Q 798-79 -    719  T    719 ok
#
# Q 745-141 -    604  T    604 ok
#
# Q 334+114 -    448  T    448 ok
#
# Q 575-436 -    139  T    139 ok
#
# Q 862-179 -    683  T    683 ok
#
# Q 366-195 -    171  T    171 ok
#
# Q 969+348 -   1317  T   1317 ok
#
# Q 914-221 -    693  T    693 ok
#
# Q 831+451 -   1282  T   1282 ok
#
# Q 574+500 -   1074  T   1074 ok
#
#
# --------------------------------------------------
# Iteration 64
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 145us/step - loss: 0.0085 - acc: 0.9974 - val_loss: 0.0049 - val_acc: 0.9987
# Examples:
# (10, 10, 15)
# Q 556-165 -    391  T    391 ok
#
# Q 269-215 -     54  T     54 ok
#
# Q 845-207 -    638  T    638 ok
#
# Q 827-484 -    343  T    343 ok
#
# Q 19+227 -    246  T    246 ok
#
# Q 998-783 -    215  T    215 ok
#
# Q 731-145 -    586  T    586 ok
#
# Q 63+569 -    632  T    632 ok
#
# Q 925+27 -    952  T    952 ok
#
# Q 659-480 -    179  T    179 ok
#
#
# --------------------------------------------------
# Iteration 65
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0065 - acc: 0.9979 - val_loss: 0.0064 - val_acc: 0.9980
# Examples:
# (10, 10, 15)
# Q 418+969 -   1387  T   1387 ok
#
# Q 314-236 -     78  T     78 ok
#
# Q 297+593 -    890  T    890 ok
#
# Q 528-273 -    255  T    255 ok
#
# Q 449+817 -   1266  T   1266 ok
#
# Q 810+940 -   1750  T   1750 ok
#
# Q 52-22 -     30  T     30 ok
#
# Q 854-234 -    620  T    620 ok
#
# Q 955+204 -   1159  T   1159 ok
#
# Q 788+202 -    990  T    990 ok
#
#
# --------------------------------------------------
# Iteration 66
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 135us/step - loss: 0.0071 - acc: 0.9978 - val_loss: 0.0059 - val_acc: 0.9981
# Examples:
# (10, 10, 15)
# Q 354-236 -    118  T    118 ok
#
# Q 306-245 -     61  T     61 ok
#
# Q 766-612 -    154  T    154 ok
#
# Q 613-206 -    407  T    407 ok
#
# Q 708-422 -    286  T    286 ok
#
# Q 542+490 -   1032  T   1032 ok
#
# Q 731+649 -   1380  T   1380 ok
#
# Q 966+211 -   1177  T   1177 ok
#
# Q 979+18 -    997  T    997 ok
#
# Q 800+507 -   1307  T   1307 ok
#
#
# --------------------------------------------------
# Iteration 67
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0152 - acc: 0.9950 - val_loss: 0.0240 - val_acc: 0.9914
# Examples:
# (10, 10, 15)
# Q 189+581 -    670  T    770 not ok
#
# Q 416+182 -    598  T    598 ok
#
# Q 235-10 -    225  T    225 ok
#
# Q 458-11 -    447  T    447 ok
#
# Q 490+235 -    725  T    725 ok
#
# Q 449+817 -   1266  T   1266 ok
#
# Q 613+975 -   1588  T   1588 ok
#
# Q 962-327 -    635  T    635 ok
#
# Q 65+527 -    592  T    592 ok
#
# Q 820-419 -    401  T    401 ok
#
#
# --------------------------------------------------
# Iteration 68
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0173 - acc: 0.9943 - val_loss: 0.0331 - val_acc: 0.9917
# Examples:
# (10, 10, 15)
# Q 371+891 -   1262  T   1262 ok
#
# Q 717+768 -   1485  T   1485 ok
#
# Q 880-453 -    427  T    427 ok
#
# Q 238+711 -    949  T    949 ok
#
# Q 816-567 -    249  T    249 ok
#
# Q 607-536 -     71  T     71 ok
#
# Q 423-373 -     50  T     50 ok
#
# Q 70+722 -    792  T    792 ok
#
# Q 944-502 -    442  T    442 ok
#
# Q 892-218 -    674  T    674 ok
#
#
# --------------------------------------------------
# Iteration 69
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 137us/step - loss: 0.0168 - acc: 0.9948 - val_loss: 0.0190 - val_acc: 0.9934
# Examples:
# (10, 10, 15)
# Q 276+905 -   1181  T   1181 ok
#
# Q 705-40 -    665  T    665 ok
#
# Q 858-137 -    721  T    721 ok
#
# Q 605-175 -    430  T    430 ok
#
# Q 154+220 -    374  T    374 ok
#
# Q 415+199 -    614  T    614 ok
#
# Q 856+410 -   1266  T   1266 ok
#
# Q 630-327 -    303  T    303 ok
#
# Q 873-38 -    735  T    835 not ok
#
# Q 715-642 -     73  T     73 ok
#
#
# --------------------------------------------------
# Iteration 70
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0279 - acc: 0.9909 - val_loss: 0.0157 - val_acc: 0.9941
# Examples:
# (10, 10, 15)
# Q 539+974 -   1513  T   1513 ok
#
# Q 970-419 -    551  T    551 ok
#
# Q 893-90 -    803  T    803 ok
#
# Q 297+418 -    715  T    715 ok
#
# Q 562-481 -     81  T     81 ok
#
# Q 646+936 -   1582  T   1582 ok
#
# Q 410+89 -    599  T    499 not ok
#
# Q 586-399 -    187  T    187 ok
#
# Q 718-263 -    455  T    455 ok
#
# Q 613-592 -     21  T     21 ok
#
#
# --------------------------------------------------
# Iteration 71
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 139us/step - loss: 0.0124 - acc: 0.9965 - val_loss: 0.0087 - val_acc: 0.9973
# Examples:
# (10, 10, 15)
# Q 357-311 -     46  T     46 ok
#
# Q 849-169 -    680  T    680 ok
#
# Q 455-346 -    109  T    109 ok
#
# Q 948-411 -    537  T    537 ok
#
# Q 488+264 -    752  T    752 ok
#
# Q 973-616 -    357  T    357 ok
#
# Q 993+181 -   1174  T   1174 ok
#
# Q 435-44 -    391  T    391 ok
#
# Q 935-295 -    640  T    640 ok
#
# Q 145+507 -    652  T    652 ok
#
#
# --------------------------------------------------
# Iteration 72
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 138us/step - loss: 0.0070 - acc: 0.9978 - val_loss: 0.0036 - val_acc: 0.9991
# Examples:
# (10, 10, 15)
# Q 289+758 -   1047  T   1047 ok
#
# Q 405+778 -   1183  T   1183 ok
#
# Q 942-48 -    894  T    894 ok
#
# Q 751-317 -    434  T    434 ok
#
# Q 952-848 -    104  T    104 ok
#
# Q 941-538 -    403  T    403 ok
#
# Q 981-742 -    239  T    239 ok
#
# Q 620+39 -    659  T    659 ok
#
# Q 409+640 -   1049  T   1049 ok
#
# Q 434+390 -    824  T    824 ok
#
#
# --------------------------------------------------
# Iteration 73
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 136us/step - loss: 0.0081 - acc: 0.9973 - val_loss: 0.0310 - val_acc: 0.9908
# Examples:
# (10, 10, 15)
# Q 756-181 -    575  T    575 ok
#
# Q 438-399 -     39  T     39 ok
#
# Q 307+932 -   1239  T   1239 ok
#
# Q 660+742 -   1402  T   1402 ok
#
# Q 197+488 -    585  T    685 not ok
#
# Q 822-182 -    640  T    640 ok
#
# Q 642+156 -    798  T    798 ok
#
# Q 949-504 -    445  T    445 ok
#
# Q 893-344 -    549  T    549 ok
#
# Q 962-742 -    220  T    220 ok
#
#
# --------------------------------------------------
# Iteration 74
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 142us/step - loss: 0.0130 - acc: 0.9957 - val_loss: 0.0177 - val_acc: 0.9936
# Examples:
# (10, 10, 15)
# Q 948+339 -   1287  T   1287 ok
#
# Q 745+763 -   1508  T   1508 ok
#
# Q 542+387 -    929  T    929 ok
#
# Q 307+932 -   1239  T   1239 ok
#
# Q 638-445 -    193  T    193 ok
#
# Q 845+380 -   1225  T   1225 ok
#
# Q 940+749 -   1689  T   1689 ok
#
# Q 985-567 -    418  T    418 ok
#
# Q 784-209 -    575  T    575 ok
#
# Q 916+176 -   1092  T   1092 ok
#
#
# --------------------------------------------------
# Iteration 75
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 140us/step - loss: 0.0159 - acc: 0.9948 - val_loss: 0.0183 - val_acc: 0.9947
# Examples:
# (10, 10, 15)
# Q 986-803 -    183  T    183 ok
#
# Q 925+413 -   1338  T   1338 ok
#
# Q 585+700 -   1285  T   1285 ok
#
# Q 897-60 -    837  T    837 ok
#
# Q 124-93 -     31  T     31 ok
#
# Q 719+822 -   1541  T   1541 ok
#
# Q 527+508 -   1035  T   1035 ok
#
# Q 628+41 -    669  T    669 ok
#
# Q 880-453 -    427  T    427 ok
#
# Q 467-50 -    417  T    417 ok
#
#
# --------------------------------------------------
# Iteration 76
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 143us/step - loss: 0.0106 - acc: 0.9967 - val_loss: 0.0071 - val_acc: 0.9974
# Examples:
# (10, 10, 15)
# Q 539+974 -   1513  T   1513 ok
#
# Q 390-306 -     84  T     84 ok
#
# Q 622-271 -    351  T    351 ok
#
# Q 849-768 -     81  T     81 ok
#
# Q 797-658 -    139  T    139 ok
#
# Q 626+486 -   1112  T   1112 ok
#
# Q 127+152 -    279  T    279 ok
#
# Q 406-40 -    366  T    366 ok
#
# Q 538+616 -   1154  T   1154 ok
#
# Q 840-698 -    142  T    142 ok
#
#
# --------------------------------------------------
# Iteration 77
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 140us/step - loss: 0.0103 - acc: 0.9966 - val_loss: 0.0157 - val_acc: 0.9946
# Examples:
# (10, 10, 15)
# Q 563-123 -    440  T    440 ok
#
# Q 758+546 -   1304  T   1304 ok
#
# Q 22+680 -    602  T    702 not ok
#
# Q 175+236 -    411  T    411 ok
#
# Q 410+89 -    499  T    499 ok
#
# Q 154+220 -    374  T    374 ok
#
# Q 613+975 -   1588  T   1588 ok
#
# Q 95+507 -    502  T    602 not ok
#
# Q 603-429 -    174  T    174 ok
#
# Q 943+507 -   1450  T   1450 ok
#
#
# --------------------------------------------------
# Iteration 78
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 135us/step - loss: 0.0121 - acc: 0.9963 - val_loss: 0.0125 - val_acc: 0.9963
# Examples:
# (10, 10, 15)
# Q 711-431 -    280  T    280 ok
#
# Q 511-416 -     95  T     95 ok
#
# Q 311+774 -   1085  T   1085 ok
#
# Q 404-68 -    336  T    336 ok
#
# Q 231+684 -    915  T    915 ok
#
# Q 654+783 -   1437  T   1437 ok
#
# Q 569-418 -    151  T    151 ok
#
# Q 270-202 -     68  T     68 ok
#
# Q 821+262 -   1083  T   1083 ok
#
# Q 283-94 -    189  T    189 ok
#
#
# --------------------------------------------------
# Iteration 79
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 148us/step - loss: 0.0106 - acc: 0.9966 - val_loss: 0.0039 - val_acc: 0.9991
# Examples:
# (10, 10, 15)
# Q 884-247 -    637  T    637 ok
#
# Q 703-419 -    284  T    284 ok
#
# Q 705-340 -    365  T    365 ok
#
# Q 933-94 -    839  T    839 ok
#
# Q 780-285 -    495  T    495 ok
#
# Q 412+758 -   1170  T   1170 ok
#
# Q 884+21 -    905  T    905 ok
#
# Q 545+338 -    883  T    883 ok
#
# Q 124+614 -    738  T    738 ok
#
# Q 50+88 -    138  T    138 ok
#
#
# --------------------------------------------------
# Iteration 80
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 139us/step - loss: 0.0152 - acc: 0.9956 - val_loss: 0.0414 - val_acc: 0.9878
# Examples:
# (10, 10, 15)
# Q 767-743 -     24  T     24 ok
#
# Q 203+163 -    376  T    366 not ok
#
# Q 92+869 -    961  T    961 ok
#
# Q 516+294 -    810  T    810 ok
#
# Q 621-169 -    452  T    452 ok
#
# Q 78+700 -    778  T    778 ok
#
# Q 116+595 -    711  T    711 ok
#
# Q 659+185 -    844  T    844 ok
#
# Q 835+977 -   1812  T   1812 ok
#
# Q 969-235 -    734  T    734 ok
#
#
# --------------------------------------------------
# Iteration 81
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0139 - acc: 0.9958 - val_loss: 0.0137 - val_acc: 0.9963
# Examples:
# (10, 10, 15)
# Q 122+20 -    142  T    142 ok
#
# Q 518-33 -    485  T    485 ok
#
# Q 125+941 -   1066  T   1066 ok
#
# Q 784+88 -    872  T    872 ok
#
# Q 632+946 -   1578  T   1578 ok
#
# Q 197-70 -    127  T    127 ok
#
# Q 830+106 -    936  T    936 ok
#
# Q 698-378 -    320  T    320 ok
#
# Q 369-318 -     51  T     51 ok
#
# Q 68+379 -    447  T    447 ok
#
#
# --------------------------------------------------
# Iteration 82
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 134us/step - loss: 0.0075 - acc: 0.9976 - val_loss: 0.0057 - val_acc: 0.9982
# Examples:
# (10, 10, 15)
# Q 924-768 -    156  T    156 ok
#
# Q 14+128 -    142  T    142 ok
#
# Q 539+210 -    749  T    749 ok
#
# Q 440-105 -    335  T    335 ok
#
# Q 680-261 -    419  T    419 ok
#
# Q 468+753 -   1221  T   1221 ok
#
# Q 497+987 -   1484  T   1484 ok
#
# Q 145+797 -    942  T    942 ok
#
# Q 815-339 -    476  T    476 ok
#
# Q 636-395 -    241  T    241 ok
#
#
# --------------------------------------------------
# Iteration 83
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 139us/step - loss: 0.0170 - acc: 0.9947 - val_loss: 0.1834 - val_acc: 0.9502
# Examples:
# (10, 10, 15)
# Q 999+865 -   1864  T   1864 ok
#
# Q 140-29 -    111  T    111 ok
#
# Q 890-184 -    706  T    706 ok
#
# Q 625+690 -   1315  T   1315 ok
#
# Q 69+331 -    500  T    400 not ok
#
# Q 406-214 -    292  T    192 not ok
#
# Q 964+181 -   1145  T   1145 ok
#
# Q 683-27 -    656  T    656 ok
#
# Q 52+832 -    884  T    884 ok
#
# Q 396+685 -   1091  T   1081 not ok
#
#
# --------------------------------------------------
# Iteration 84
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0120 - acc: 0.9960 - val_loss: 0.0086 - val_acc: 0.9980
# Examples:
# (10, 10, 15)
# Q 775-566 -    209  T    209 ok
#
# Q 511-416 -     95  T     95 ok
#
# Q 690-336 -    354  T    354 ok
#
# Q 78+612 -    690  T    690 ok
#
# Q 809-529 -    280  T    280 ok
#
# Q 848-305 -    543  T    543 ok
#
# Q 502+522 -   1024  T   1024 ok
#
# Q 866+986 -   1852  T   1852 ok
#
# Q 593-377 -    216  T    216 ok
#
# Q 10+443 -    453  T    453 ok
#
#
# --------------------------------------------------
# Iteration 85
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 142us/step - loss: 0.0174 - acc: 0.9944 - val_loss: 0.0407 - val_acc: 0.9872
# Examples:
# (10, 10, 15)
# Q 248-40 -    208  T    208 ok
#
# Q 500-297 -    203  T    203 ok
#
# Q 90+779 -    869  T    869 ok
#
# Q 212+26 -    238  T    238 ok
#
# Q 466+138 -    604  T    604 ok
#
# Q 907+799 -   1706  T   1706 ok
#
# Q 538-277 -    261  T    261 ok
#
# Q 890+369 -   1359  T   1259 not ok
#
# Q 630-103 -    527  T    527 ok
#
# Q 267-199 -     68  T     68 ok
#
#
# --------------------------------------------------
# Iteration 86
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 147us/step - loss: 0.0215 - acc: 0.9933 - val_loss: 0.0040 - val_acc: 0.9988
# Examples:
# (10, 10, 15)
# Q 264-72 -    192  T    192 ok
#
# Q 762-155 -    607  T    607 ok
#
# Q 989+379 -   1368  T   1368 ok
#
# Q 305+573 -    878  T    878 ok
#
# Q 867+534 -   1401  T   1401 ok
#
# Q 763-262 -    501  T    501 ok
#
# Q 313+606 -    919  T    919 ok
#
# Q 567-345 -    222  T    222 ok
#
# Q 471+415 -    886  T    886 ok
#
# Q 502+522 -   1024  T   1024 ok
#
#
# --------------------------------------------------
# Iteration 87
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 148us/step - loss: 0.0039 - acc: 0.9989 - val_loss: 0.0018 - val_acc: 0.9996
# Examples:
# (10, 10, 15)
# Q 356-17 -    339  T    339 ok
#
# Q 457-351 -    106  T    106 ok
#
# Q 792-661 -    131  T    131 ok
#
# Q 65+527 -    592  T    592 ok
#
# Q 379-75 -    304  T    304 ok
#
# Q 756-589 -    167  T    167 ok
#
# Q 237-128 -    109  T    109 ok
#
# Q 829+783 -   1612  T   1612 ok
#
# Q 560-231 -    329  T    329 ok
#
# Q 154-129 -     25  T     25 ok
#
#
# --------------------------------------------------
# Iteration 88
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0030 - acc: 0.9992 - val_loss: 0.0020 - val_acc: 0.9996
# Examples:
# (10, 10, 15)
# Q 973+431 -   1404  T   1404 ok
#
# Q 970+96 -   1066  T   1066 ok
#
# Q 199+24 -    223  T    223 ok
#
# Q 646+487 -   1133  T   1133 ok
#
# Q 791-630 -    161  T    161 ok
#
# Q 945-295 -    650  T    650 ok
#
# Q 847+281 -   1128  T   1128 ok
#
# Q 834-658 -    176  T    176 ok
#
# Q 864+122 -    986  T    986 ok
#
# Q 396+841 -   1237  T   1237 ok
#
#
# --------------------------------------------------
# Iteration 89
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 147us/step - loss: 0.0046 - acc: 0.9985 - val_loss: 0.0023 - val_acc: 0.9991
# Examples:
# (10, 10, 15)
# Q 614+463 -   1077  T   1077 ok
#
# Q 942+488 -   1430  T   1430 ok
#
# Q 900-564 -    336  T    336 ok
#
# Q 454+557 -   1011  T   1011 ok
#
# Q 669+376 -   1045  T   1045 ok
#
# Q 271-267 -      4  T      4 ok
#
# Q 986-861 -    125  T    125 ok
#
# Q 801-583 -    218  T    218 ok
#
# Q 712-242 -    470  T    470 ok
#
# Q 709-367 -    342  T    342 ok
#
#
# --------------------------------------------------
# Iteration 90
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0103 - acc: 0.9969 - val_loss: 0.0283 - val_acc: 0.9921
# Examples:
# (10, 10, 15)
# Q 803+660 -   1463  T   1463 ok
#
# Q 719+575 -   1294  T   1294 ok
#
# Q 874+33 -    907  T    907 ok
#
# Q 710-77 -    633  T    633 ok
#
# Q 790-396 -    394  T    394 ok
#
# Q 52+580 -    632  T    632 ok
#
# Q 990-738 -    252  T    252 ok
#
# Q 394+876 -   1270  T   1270 ok
#
# Q 262+388 -    650  T    650 ok
#
# Q 146+944 -   1090  T   1090 ok
#
#
# --------------------------------------------------
# Iteration 91
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0130 - acc: 0.9958 - val_loss: 0.0180 - val_acc: 0.9949
# Examples:
# (10, 10, 15)
# Q 569+634 -   1203  T   1203 ok
#
# Q 43-25 -     18  T     18 ok
#
# Q 585+367 -    952  T    952 ok
#
# Q 304-135 -    169  T    169 ok
#
# Q 78+700 -    778  T    778 ok
#
# Q 690+919 -   1609  T   1609 ok
#
# Q 468+753 -   1221  T   1221 ok
#
# Q 448+685 -   1133  T   1133 ok
#
# Q 508-174 -    334  T    334 ok
#
# Q 806-31 -    775  T    775 ok
#
#
# --------------------------------------------------
# Iteration 92
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 142us/step - loss: 0.0129 - acc: 0.9957 - val_loss: 0.0051 - val_acc: 0.9989
# Examples:
# (10, 10, 15)
# Q 121+757 -    878  T    878 ok
#
# Q 134+755 -    889  T    889 ok
#
# Q 396+841 -   1237  T   1237 ok
#
# Q 683-345 -    338  T    338 ok
#
# Q 750-463 -    287  T    287 ok
#
# Q 738-656 -     82  T     82 ok
#
# Q 863-862 -      1  T      1 ok
#
# Q 813-592 -    221  T    221 ok
#
# Q 745-49 -    696  T    696 ok
#
# Q 766-612 -    154  T    154 ok
#
#
# --------------------------------------------------
# Iteration 93
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0079 - acc: 0.9979 - val_loss: 0.0223 - val_acc: 0.9945
# Examples:
# (10, 10, 15)
# Q 633+563 -   1196  T   1196 ok
#
# Q 397-347 -     50  T     50 ok
#
# Q 959-80 -    879  T    879 ok
#
# Q 81+137 -    218  T    218 ok
#
# Q 390+32 -    422  T    422 ok
#
# Q 728-570 -    158  T    158 ok
#
# Q 703-372 -    331  T    331 ok
#
# Q 392-58 -    334  T    334 ok
#
# Q 953+71 -   1024  T   1024 ok
#
# Q 89+703 -    792  T    792 ok
#
#
# --------------------------------------------------
# Iteration 94
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0129 - acc: 0.9960 - val_loss: 0.0078 - val_acc: 0.9971
# Examples:
# (10, 10, 15)
# Q 127+152 -    279  T    279 ok
#
# Q 927-648 -    279  T    279 ok
#
# Q 119+173 -    292  T    292 ok
#
# Q 846-32 -    814  T    814 ok
#
# Q 825+526 -   1351  T   1351 ok
#
# Q 548-440 -    108  T    108 ok
#
# Q 849-650 -    199  T    199 ok
#
# Q 787-276 -    511  T    511 ok
#
# Q 984-468 -    516  T    516 ok
#
# Q 262+715 -    977  T    977 ok
#
#
# --------------------------------------------------
# Iteration 95
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 140us/step - loss: 0.0211 - acc: 0.9933 - val_loss: 0.0324 - val_acc: 0.9870
# Examples:
# (10, 10, 15)
# Q 727+602 -   1329  T   1329 ok
#
# Q 822+911 -   1733  T   1733 ok
#
# Q 962-319 -    643  T    643 ok
#
# Q 582+995 -   1577  T   1577 ok
#
# Q 578-254 -    324  T    324 ok
#
# Q 125+941 -   1056  T   1066 not ok
#
# Q 756-181 -    565  T    575 not ok
#
# Q 918-889 -     29  T     29 ok
#
# Q 761-594 -    167  T    167 ok
#
# Q 601+938 -   1549  T   1539 not ok
#
#
# --------------------------------------------------
# Iteration 96
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 137us/step - loss: 0.0094 - acc: 0.9968 - val_loss: 0.0045 - val_acc: 0.9986
# Examples:
# (10, 10, 15)
# Q 13+434 -    447  T    447 ok
#
# Q 478-472 -      6  T      6 ok
#
# Q 901-834 -     67  T     67 ok
#
# Q 654-42 -    612  T    612 ok
#
# Q 261-111 -    150  T    150 ok
#
# Q 797+771 -   1568  T   1568 ok
#
# Q 435-44 -    391  T    391 ok
#
# Q 843-172 -    671  T    671 ok
#
# Q 982-165 -    817  T    817 ok
#
# Q 465+985 -   1450  T   1450 ok
#
#
# --------------------------------------------------
# Iteration 97
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 140us/step - loss: 0.0063 - acc: 0.9981 - val_loss: 0.0067 - val_acc: 0.9979
# Examples:
# (10, 10, 15)
# Q 667+630 -   1297  T   1297 ok
#
# Q 766-720 -     46  T     46 ok
#
# Q 745-49 -    696  T    696 ok
#
# Q 940+873 -   1813  T   1813 ok
#
# Q 669-443 -    226  T    226 ok
#
# Q 833-244 -    589  T    589 ok
#
# Q 912+629 -   1541  T   1541 ok
#
# Q 783-230 -    553  T    553 ok
#
# Q 826+694 -   1520  T   1520 ok
#
# Q 23+562 -    585  T    585 ok
#
#
# --------------------------------------------------
# Iteration 98
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 141us/step - loss: 0.0089 - acc: 0.9973 - val_loss: 0.0298 - val_acc: 0.9930
# Examples:
# (10, 10, 15)
# Q 69+331 -    400  T    400 ok
#
# Q 828-601 -    227  T    227 ok
#
# Q 755+369 -   1124  T   1124 ok
#
# Q 795-481 -    314  T    314 ok
#
# Q 173-92 -     81  T     81 ok
#
# Q 614-310 -    304  T    304 ok
#
# Q 583-21 -    562  T    562 ok
#
# Q 904+499 -   1403  T   1403 ok
#
# Q 895+17 -    912  T    912 ok
#
# Q 490+158 -    648  T    648 ok
#
#
# --------------------------------------------------
# Iteration 99
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 4s 144us/step - loss: 0.0133 - acc: 0.9956 - val_loss: 0.0069 - val_acc: 0.9975
# Examples:
# (10, 10, 15)
# Q 400+109 -    509  T    509 ok
#
# Q 592+224 -    816  T    816 ok
#
# Q 663-463 -    200  T    200 ok
#
# Q 382-39 -    343  T    343 ok
#
# Q 463-217 -    246  T    246 ok
#
# Q 406-331 -     75  T     75 ok
#
# Q 284+113 -    397  T    397 ok
#
# Q 955-416 -    539  T    539 ok
#
# Q 734+30 -    764  T    764 ok
#
# Q 525+756 -   1281  T   1281 ok

# %%
import itertools
import numpy as np
import random

from keras.models import Sequential
from keras.layers import LSTM,RepeatVector,Dense,Activation,Dropout
from keras.layers.wrappers import TimeDistributed,Bidirectional
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.models import load_model

CHARS = [str(n) for n in range(10)] + ['*','+','-', ' ', '\0']
CHAR_TO_INDEX = {i: c for c, i in enumerate(CHARS)}
INDEX_TO_CHAR = {c: i for c, i in enumerate(CHARS)}
          
MIN_NUMBER = 1
MAX_NUMBER = 100

MAX_N_EXAMPLES = (MAX_NUMBER - MIN_NUMBER) ** 2
N_EXAMPLES = 30000
N_FEATURES = len(CHARS)
MAX_NUMBER_LENGTH_LEFT_SIDE = len(str(MAX_NUMBER))
MAX_NUMBER_LENGTH_RIGHT_SIDE = MAX_NUMBER_LENGTH_LEFT_SIDE *2
MAX_EQUATION_LENGTH = (MAX_NUMBER_LENGTH_LEFT_SIDE * 2) + 4
MAX_RESULT_LENGTH = MAX_NUMBER_LENGTH_RIGHT_SIDE + 1

SPLIT = .1
EPOCHS = 500
LEARNING_RATE = 0.001
BATCH_SIZE = 256
HIDDEN_SIZE = 128
ENCODER_DEPTH = 1
DECODER_DEPTH = 1
DROPOUT = 0
BATCH_NORM = True
# Out:
# D:\Anaconda3-4.2.0\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# D:\Anaconda3-4.2.0\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def generate_equations(max_count=None):
        number_permutations=itertools.permutations(range(1,100),2)
        if max_count is not None:
            number_permutations=itertools.islice(number_permutations,max_count)
        number_permutations=list(number_permutations)
        random.shuffle(number_permutations)
        for x,y in number_permutations:
            p=random.randint(3,4)
            if p==1:
                if x>y:
                    yield'{}-{}'.format(x,y)
                else:
                    yield'{}-{}'.format(y,x)
            if p==2:
                    yield'{}+{}'.format(x,y)
            if p==3 or p==4:
                    yield'{}*{}'.format(x,y)

# %%
def one_hot_to_index(vector):
    if not np.any(vector):
        return -1
    return np.argmax(vector)

def one_hot_to_char(vector):
    index=one_hot_to_index(vector)
    if index==-1:
        return''
    return INDEX_TO_CHAR[index]

def one_hot_to_string(matrix):
    return ''.join(one_hot_to_char(vector) for vector in matrix)              
                
def equations_to_x_y(equations,n):
     x=np.zeros((n,MAX_EQUATION_LENGTH,N_FEATURES),dtype=np.bool)
     y=np.zeros((n,MAX_RESULT_LENGTH,N_FEATURES),dtype=np.bool)             
     for i,equation in enumerate(itertools.islice(equations,n)):
         result=str(eval(equation))
         result=' ' *(MAX_RESULT_LENGTH-1-len(result))+result
         
         equation +='\0'
         result   +='\0'
         for t,char in enumerate(equation):
            x[i,t,CHAR_TO_INDEX[char]]=1
         for t,char in enumerate(result):
            y[i,t,CHAR_TO_INDEX[char]]=1
     return x,y

# %%
def build_dataset():
    generator=generate_equations(max_count=1000000)
    n_test=round(SPLIT*N_EXAMPLES)
    n_train=N_EXAMPLES-n_test
    
    x_test,y_test=equations_to_x_y(generator,n_test)
    x_train,y_train=equations_to_x_y(generator,n_train)
  
    
    return x_test,y_test,x_train,y_train
    
def print_example_prediction(count,model,x_test,y_test):
    print('Examples:')
    prediction_indices=np.random.choice(x_test.shape[0],size=count,replace=False)
    print(np.array(x_test[prediction_indices,:]).shape)
    predictions=model.predict(x_test[prediction_indices,:])
    for i in range(count): 
        correct=one_hot_to_string(y_test[prediction_indices[i]])
        guess=one_hot_to_string(predictions[i])
        
        print('Q {} - {} '.format(one_hot_to_string(x_test[prediction_indices[i]]),one_hot_to_string(predictions[i])),end=' ')
        print('T', correct, end=' ')  
        if correct == guess:
            print( 'ok',end=' ')
        else:
            print( 'not ok',end=' ')
        print('\n')
      
        
def build_model():
    """
    Builds and returns the model based on the global config.
    """
    input_shape = (MAX_EQUATION_LENGTH, N_FEATURES)

    model = Sequential()

    # Encoder:
    model.add(Bidirectional(LSTM(20), input_shape=input_shape))
    model.add(BatchNormalization())

    # The RepeatVector-layer repeats the input n times
    model.add(RepeatVector(MAX_RESULT_LENGTH))

    # Decoder:
    model.add(Bidirectional(LSTM(20, return_sequences=True)))
    model.add(BatchNormalization())

    model.add(TimeDistributed(Dense(N_FEATURES)))
    model.add(Activation('softmax'))

    model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(lr=0.01),
        metrics=['accuracy'],
    )

    return model

# %%
def main():
     
    
    
    model=build_model()
    model.summary()
    print()    
    
    x_test,y_test,x_train,y_train=build_dataset()
    
    print()
    print_example_prediction(5,model,x_test,y_test)
    print()
    
    for iteration in range(100):
        print()
        print('-'*50)
        print('Iteration',iteration)
        model.fit(x_train, y_train,batch_size=BATCH_SIZE,epochs=1,validation_data=(x_test, y_test))
        print_example_prediction(10,model,x_test,y_test)

# %%
main()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 40)                5760
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40)                160
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 7, 40)             0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 7, 40)             9760
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 7, 40)             160
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 7, 15)             615
# _________________________________________________________________
# activation_1 (Activation)    (None, 7, 15)             0
# =================================================================
# Total params: 16,455
# Trainable params: 16,295
# Non-trainable params: 160
# _________________________________________________________________
#
#
# Examples:
# (5, 10, 15)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 40)                5760
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 40)                160
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 7, 40)             0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 7, 40)             9760
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 7, 40)             160
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 7, 15)             615
# _________________________________________________________________
# activation_1 (Activation)    (None, 7, 15)             0
# =================================================================
# Total params: 16,455
# Trainable params: 16,295
# Non-trainable params: 160
# _________________________________________________________________
#
#
# Examples:
# (5, 10, 15)
# Q 52*56 - 8877777  T   2912 not ok
#
# Q 61*33 - 2222222  T   2013 not ok
#
# Q 96*29 - 9999222  T   2784 not ok
#
# Q 9*3 - ++++++9  T     27 not ok
#
# Q 76*51 - +++++++  T   3876 not ok
#
#
#
# --------------------------------------------------
# Iteration 0
# Q 52*56 - 8877777  T   2912 not ok
#
# Q 61*33 - 2222222  T   2013 not ok
#
# Q 96*29 - 9999222  T   2784 not ok
#
# Q 9*3 - ++++++9  T     27 not ok
#
# Q 76*51 - +++++++  T   3876 not ok
#
#
#
# --------------------------------------------------
# Iteration 0
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 9s 346us/step - loss: 0.3338 - acc: 0.1398 - val_loss: 1.6197 - val_acc: 0.5146
# 27000/27000 [==============================] - 9s 346us/step - loss: 0.3338 - acc: 0.1398 - val_loss: 1.6197 - val_acc: 0.5146
# Examples:
# (10, 10, 15)
# Q 47*19 -     18  T    893 not ok
#
# Q 42*37 -     18  T   1554 not ok
#
# Q 93*32 -     18  T   2976 not ok
#
# Q 68*14 -     18  T    952 not ok
#
# Q 90*34 -     18  T   3060 not ok
#
# Q 73*66 -     18  T   4818 not ok
#
# Q 16*49 -     18  T    784 not ok
#
# Q 72*68 -     18  T   4896 not ok
#
# Q 1*76 -     18  T     76 not ok
#
# Q 11*60 -     18  T    660 not ok
#
#
# --------------------------------------------------
# Iteration 1
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.3758 - acc: 0.1769Examples:
# (10, 10, 15)
# Q 47*19 -     18  T    893 not ok
#
# Q 42*37 -     18  T   1554 not ok
#
# Q 93*32 -     18  T   2976 not ok
#
# Q 68*14 -     18  T    952 not ok
#
# Q 90*34 -     18  T   3060 not ok
#
# Q 73*66 -     18  T   4818 not ok
#
# Q 16*49 -     18  T    784 not ok
#
# Q 72*68 -     18  T   4896 not ok
#
# Q 1*76 -     18  T     76 not ok
#
# Q 11*60 -     18  T    660 not ok
#
#
# --------------------------------------------------
# Iteration 1
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 243us/step - loss: 0.2599 - acc: 0.1491 - val_loss: 1.5826 - val_acc: 0.5174
# 27000/27000 [==============================] - 7s 243us/step - loss: 0.2599 - acc: 0.1491 - val_loss: 1.5826 - val_acc: 0.5174
# Examples:
# (10, 10, 15)
# Q 37*67 -     78  T   2479 not ok
#
# Q 44*86 -     78  T   3784 not ok
#
# Q 90*47 -    178  T   4230 not ok
#
# Q 54*45 -     78  T   2430 not ok
#
# Q 54*18 -     18  T    972 not ok
#
# Q 33*69 -     18  T   2277 not ok
#
# Q 6*2 -     1  T     12 not ok
#
# Q 56*54 -     78  T   3024 not ok
#
# Q 70*68 -     78  T   4760 not ok
#
# Q 80*71 -     78  T   5680 not ok
#
#
# --------------------------------------------------
# Iteration 2
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.2422 - acc: 0.1367Examples:
# (10, 10, 15)
# Q 37*67 -     78  T   2479 not ok
#
# Q 44*86 -     78  T   3784 not ok
#
# Q 90*47 -    178  T   4230 not ok
#
# Q 54*45 -     78  T   2430 not ok
#
# Q 54*18 -     18  T    972 not ok
#
# Q 33*69 -     18  T   2277 not ok
#
# Q 6*2 -     1  T     12 not ok
#
# Q 56*54 -     78  T   3024 not ok
#
# Q 70*68 -     78  T   4760 not ok
#
# Q 80*71 -     78  T   5680 not ok
#
#
# --------------------------------------------------
# Iteration 2
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 242us/step - loss: 0.2373 - acc: 0.1547 - val_loss: 1.5965 - val_acc: 0.5130
# 27000/27000 [==============================] - 7s 242us/step - loss: 0.2373 - acc: 0.1547 - val_loss: 1.5965 - val_acc: 0.5130
# Examples:
# (10, 10, 15)
# Q 31*25 -    177  T    775 not ok
#
# Q 54*83 -    177  T   4482 not ok
#
# Q 43*89 -    177  T   3827 not ok
#
# Q 39*11 -    177  T    429 not ok
#
# Q 32*74 -    177  T   2368 not ok
#
# Q 91*92 -    177  T   8372 not ok
#
# Q 10*21 -    177  T    210 not ok
#
# Q 33*39 -    177  T   1287 not ok
#
# Q 25*20 -    175  T    500 not ok
#
# Q 19*6 -    177  T    114 not ok
#
#
# --------------------------------------------------
# Iteration 3
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 5s - loss: 0.2231 - acc: 0.1590Examples:
# (10, 10, 15)
# Q 31*25 -    177  T    775 not ok
#
# Q 54*83 -    177  T   4482 not ok
#
# Q 43*89 -    177  T   3827 not ok
#
# Q 39*11 -    177  T    429 not ok
#
# Q 32*74 -    177  T   2368 not ok
#
# Q 91*92 -    177  T   8372 not ok
#
# Q 10*21 -    177  T    210 not ok
#
# Q 33*39 -    177  T   1287 not ok
#
# Q 25*20 -    175  T    500 not ok
#
# Q 19*6 -    177  T    114 not ok
#
#
# --------------------------------------------------
# Iteration 3
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 250us/step - loss: 0.2153 - acc: 0.1609 - val_loss: 1.3944 - val_acc: 0.5550
# 27000/27000 [==============================] - 7s 250us/step - loss: 0.2153 - acc: 0.1609 - val_loss: 1.3944 - val_acc: 0.5550
# Examples:
# (10, 10, 15)
# Q 12*87 -    246  T   1044 not ok
#
# Q 44*73 -    246  T   3212 not ok
#
# Q 20*30 -    240  T    600 not ok
#
# Q 62*95 -    446  T   5890 not ok
#
# Q 26*36 -    346  T    936 not ok
#
# Q 76*39 -    346  T   2964 not ok
#
# Q 47*76 -    246  T   3572 not ok
#
# Q 53*76 -    244  T   4028 not ok
#
# Q 81*70 -    237  T   5670 not ok
#
# Q 6*2 -     46  T     12 not ok
#
#
# --------------------------------------------------
# Iteration 4
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.2263 - acc: 0.1897Examples:
# (10, 10, 15)
# Q 12*87 -    246  T   1044 not ok
#
# Q 44*73 -    246  T   3212 not ok
#
# Q 20*30 -    240  T    600 not ok
#
# Q 62*95 -    446  T   5890 not ok
#
# Q 26*36 -    346  T    936 not ok
#
# Q 76*39 -    346  T   2964 not ok
#
# Q 47*76 -    246  T   3572 not ok
#
# Q 53*76 -    244  T   4028 not ok
#
# Q 81*70 -    237  T   5670 not ok
#
# Q 6*2 -     46  T     12 not ok
#
#
# --------------------------------------------------
# Iteration 4
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 258us/step - loss: 0.2016 - acc: 0.1656 - val_loss: 1.0636 - val_acc: 0.5800
# 27000/27000 [==============================] - 7s 258us/step - loss: 0.2016 - acc: 0.1656 - val_loss: 1.0636 - val_acc: 0.5800
# Examples:
# (10, 10, 15)
# Q 88*50 -   4480  T   4400 not ok
#
# Q 10*44 -    440  T    440 ok
#
# Q 55*90 -   3455  T   4950 not ok
#
# Q 17*2 -    333  T     34 not ok
#
# Q 82*30 -   1440  T   2460 not ok
#
# Q 74*89 -   4483  T   6586 not ok
#
# Q 62*59 -   3488  T   3658 not ok
#
# Q 79*71 -   4483  T   5609 not ok
#
# Q 31*12 -    333  T    372 not ok
#
# Q 5*72 -    285  T    360 not ok
#
#
# --------------------------------------------------
# Iteration 5
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 7s - loss: 0.1777 - acc: 0.1557Examples:
# (10, 10, 15)
# Q 88*50 -   4480  T   4400 not ok
#
# Q 10*44 -    440  T    440 ok
#
# Q 55*90 -   3455  T   4950 not ok
#
# Q 17*2 -    333  T     34 not ok
#
# Q 82*30 -   1440  T   2460 not ok
#
# Q 74*89 -   4483  T   6586 not ok
#
# Q 62*59 -   3488  T   3658 not ok
#
# Q 79*71 -   4483  T   5609 not ok
#
# Q 31*12 -    333  T    372 not ok
#
# Q 5*72 -    285  T    360 not ok
#
#
# --------------------------------------------------
# Iteration 5
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 258us/step - loss: 0.1929 - acc: 0.1696 - val_loss: 0.8638 - val_acc: 0.6495
# 27000/27000 [==============================] - 7s 258us/step - loss: 0.1929 - acc: 0.1696 - val_loss: 0.8638 - val_acc: 0.6495
# Examples:
# (10, 10, 15)
# Q 62*18 -    782  T   1116 not ok
#
# Q 29*20 -    320  T    580 not ok
#
# Q 69*47 -   3277  T   3243 not ok
#
# Q 16*79 -   1772  T   1264 not ok
#
# Q 87*75 -   5275  T   6525 not ok
#
# Q 51*34 -   1272  T   1734 not ok
#
# Q 6*39 -    272  T    234 not ok
#
# Q 12*23 -    330  T    276 not ok
#
# Q 15*1 -     75  T     15 not ok
#
# Q 55*82 -   3270  T   4510 not ok
#
#
# --------------------------------------------------
# Iteration 6
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 5s - loss: 0.1903 - acc: 0.1735Examples:
# (10, 10, 15)
# Q 62*18 -    782  T   1116 not ok
#
# Q 29*20 -    320  T    580 not ok
#
# Q 69*47 -   3277  T   3243 not ok
#
# Q 16*79 -   1772  T   1264 not ok
#
# Q 87*75 -   5275  T   6525 not ok
#
# Q 51*34 -   1272  T   1734 not ok
#
# Q 6*39 -    272  T    234 not ok
#
# Q 12*23 -    330  T    276 not ok
#
# Q 15*1 -     75  T     15 not ok
#
# Q 55*82 -   3270  T   4510 not ok
#
#
# --------------------------------------------------
# Iteration 6
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 264us/step - loss: 0.1859 - acc: 0.1724 - val_loss: 0.8338 - val_acc: 0.6658
# 27000/27000 [==============================] - 7s 264us/step - loss: 0.1859 - acc: 0.1724 - val_loss: 0.8338 - val_acc: 0.6658
# Examples:
# (10, 10, 15)
# Q 94*59 -   4222  T   5546 not ok
#
# Q 86*91 -   6688  T   7826 not ok
#
# Q 99*88 -   7222  T   8712 not ok
#
# Q 86*15 -   1980  T   1290 not ok
#
# Q 50*14 -    500  T    700 not ok
#
# Q 1*71 -     17  T     71 not ok
#
# Q 57*98 -   5288  T   5586 not ok
#
# Q 26*18 -    288  T    468 not ok
#
# Q 68*93 -   5288  T   6324 not ok
#
# Q 95*3 -    225  T    285 not ok
#
#
# --------------------------------------------------
# Iteration 7
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 5s - loss: 0.1884 - acc: 0.1797Examples:
# (10, 10, 15)
# Q 94*59 -   4222  T   5546 not ok
#
# Q 86*91 -   6688  T   7826 not ok
#
# Q 99*88 -   7222  T   8712 not ok
#
# Q 86*15 -   1980  T   1290 not ok
#
# Q 50*14 -    500  T    700 not ok
#
# Q 1*71 -     17  T     71 not ok
#
# Q 57*98 -   5288  T   5586 not ok
#
# Q 26*18 -    288  T    468 not ok
#
# Q 68*93 -   5288  T   6324 not ok
#
# Q 95*3 -    225  T    285 not ok
#
#
# --------------------------------------------------
# Iteration 7
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 274us/step - loss: 0.1824 - acc: 0.1753 - val_loss: 0.8787 - val_acc: 0.6728
# 27000/27000 [==============================] - 7s 274us/step - loss: 0.1824 - acc: 0.1753 - val_loss: 0.8787 - val_acc: 0.6728
# Examples:
# (10, 10, 15)
# Q 51*25 -   1525  T   1275 not ok
#
# Q 3*72 -    108  T    216 not ok
#
# Q 71*28 -   1008  T   1988 not ok
#
# Q 90*14 -   1220  T   1260 not ok
#
# Q 3*90 -    220  T    270 not ok
#
# Q 12*58 -    558  T    696 not ok
#
# Q 64*72 -   4028  T   4608 not ok
#
# Q 4*97 -    322  T    388 not ok
#
# Q 9*98 -    812  T    882 not ok
#
# Q 58*73 -   3208  T   4234 not ok
#
#
# --------------------------------------------------
# Iteration 8
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1690 - acc: 0.1590Examples:
# (10, 10, 15)
# Q 51*25 -   1525  T   1275 not ok
#
# Q 3*72 -    108  T    216 not ok
#
# Q 71*28 -   1008  T   1988 not ok
#
# Q 90*14 -   1220  T   1260 not ok
#
# Q 3*90 -    220  T    270 not ok
#
# Q 12*58 -    558  T    696 not ok
#
# Q 64*72 -   4028  T   4608 not ok
#
# Q 4*97 -    322  T    388 not ok
#
# Q 9*98 -    812  T    882 not ok
#
# Q 58*73 -   3208  T   4234 not ok
#
#
# --------------------------------------------------
# Iteration 8
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 272us/step - loss: 0.1745 - acc: 0.1785 - val_loss: 0.7787 - val_acc: 0.6936
# 27000/27000 [==============================] - 7s 272us/step - loss: 0.1745 - acc: 0.1785 - val_loss: 0.7787 - val_acc: 0.6936
# Examples:
# (10, 10, 15)
# Q 35*42 -   1110  T   1470 not ok
#
# Q 52*45 -   2420  T   2340 not ok
#
# Q 4*75 -    220  T    300 not ok
#
# Q 61*56 -   3426  T   3416 not ok
#
# Q 9*69 -    646  T    621 not ok
#
# Q 15*20 -    200  T    300 not ok
#
# Q 42*25 -   1120  T   1050 not ok
#
# Q 61*93 -   5843  T   5673 not ok
#
# Q 83*40 -   3820  T   3320 not ok
#
# Q 5*27 -    115  T    135 not ok
#
#
# --------------------------------------------------
# Iteration 9
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 4s - loss: 0.1542 - acc: 0.1719Examples:
# (10, 10, 15)
# Q 35*42 -   1110  T   1470 not ok
#
# Q 52*45 -   2420  T   2340 not ok
#
# Q 4*75 -    220  T    300 not ok
#
# Q 61*56 -   3426  T   3416 not ok
#
# Q 9*69 -    646  T    621 not ok
#
# Q 15*20 -    200  T    300 not ok
#
# Q 42*25 -   1120  T   1050 not ok
#
# Q 61*93 -   5843  T   5673 not ok
#
# Q 83*40 -   3820  T   3320 not ok
#
# Q 5*27 -    115  T    135 not ok
#
#
# --------------------------------------------------
# Iteration 9
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 256us/step - loss: 0.1678 - acc: 0.1823 - val_loss: 0.8374 - val_acc: 0.6862
# 27000/27000 [==============================] - 7s 256us/step - loss: 0.1678 - acc: 0.1823 - val_loss: 0.8374 - val_acc: 0.6862
# Examples:
# (10, 10, 15)
# Q 23*98 -   1114  T   2254 not ok
#
# Q 48*49 -   1362  T   2352 not ok
#
# Q 30*16 -    580  T    480 not ok
#
# Q 66*80 -   5840  T   5280 not ok
#
# Q 53*27 -   1117  T   1431 not ok
#
# Q 91*98 -   8888  T   8918 not ok
#
# Q 85*60 -   4100  T   5100 not ok
#
# Q 65*85 -   4710  T   5525 not ok
#
# Q 45*43 -   1215  T   1935 not ok
#
# Q 85*44 -   3760  T   3740 not ok
#
#
# --------------------------------------------------
# Iteration 10
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 8s - loss: 0.1591 - acc: 0.1724Examples:
# (10, 10, 15)
# Q 23*98 -   1114  T   2254 not ok
#
# Q 48*49 -   1362  T   2352 not ok
#
# Q 30*16 -    580  T    480 not ok
#
# Q 66*80 -   5840  T   5280 not ok
#
# Q 53*27 -   1117  T   1431 not ok
#
# Q 91*98 -   8888  T   8918 not ok
#
# Q 85*60 -   4100  T   5100 not ok
#
# Q 65*85 -   4710  T   5525 not ok
#
# Q 45*43 -   1215  T   1935 not ok
#
# Q 85*44 -   3760  T   3740 not ok
#
#
# --------------------------------------------------
# Iteration 10
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 271us/step - loss: 0.1580 - acc: 0.1876 - val_loss: 0.6486 - val_acc: 0.7520
# 27000/27000 [==============================] - 7s 271us/step - loss: 0.1580 - acc: 0.1876 - val_loss: 0.6486 - val_acc: 0.7520
# Examples:
# (10, 10, 15)
# Q 94*84 -   7536  T   7896 not ok
#
# Q 88*90 -   7620  T   7920 not ok
#
# Q 63*8 -    484  T    504 not ok
#
# Q 97*58 -   5792  T   5626 not ok
#
# Q 90*5 -    450  T    450 ok
#
# Q 30*29 -    970  T    870 not ok
#
# Q 87*72 -   6894  T   6264 not ok
#
# Q 28*85 -   2720  T   2380 not ok
#
# Q 36*74 -   2284  T   2664 not ok
#
# Q 75*45 -   3275  T   3375 not ok
#
#
# --------------------------------------------------
# Iteration 11
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 8s - loss: 0.1647 - acc: 0.2076Examples:
# (10, 10, 15)
# Q 94*84 -   7536  T   7896 not ok
#
# Q 88*90 -   7620  T   7920 not ok
#
# Q 63*8 -    484  T    504 not ok
#
# Q 97*58 -   5792  T   5626 not ok
#
# Q 90*5 -    450  T    450 ok
#
# Q 30*29 -    970  T    870 not ok
#
# Q 87*72 -   6894  T   6264 not ok
#
# Q 28*85 -   2720  T   2380 not ok
#
# Q 36*74 -   2284  T   2664 not ok
#
# Q 75*45 -   3275  T   3375 not ok
#
#
# --------------------------------------------------
# Iteration 11
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 261us/step - loss: 0.1491 - acc: 0.1919 - val_loss: 0.7504 - val_acc: 0.7152
# 27000/27000 [==============================] - 7s 261us/step - loss: 0.1491 - acc: 0.1919 - val_loss: 0.7504 - val_acc: 0.7152
# Examples:
# (10, 10, 15)
# Q 59*37 -   2871  T   2183 not ok
#
# Q 99*96 -   8074  T   9504 not ok
#
# Q 98*49 -   4772  T   4802 not ok
#
# Q 3*45 -    175  T    135 not ok
#
# Q 29*2 -     46  T     58 not ok
#
# Q 29*67 -   2451  T   1943 not ok
#
# Q 57*86 -   4384  T   4902 not ok
#
# Q 88*68 -   5772  T   5984 not ok
#
# Q 82*49 -   4778  T   4018 not ok
#
# Q 71*4 -    374  T    284 not ok
#
#
# --------------------------------------------------
# Iteration 12
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1129 - acc: 0.1484Examples:
# (10, 10, 15)
# Q 59*37 -   2871  T   2183 not ok
#
# Q 99*96 -   8074  T   9504 not ok
#
# Q 98*49 -   4772  T   4802 not ok
#
# Q 3*45 -    175  T    135 not ok
#
# Q 29*2 -     46  T     58 not ok
#
# Q 29*67 -   2451  T   1943 not ok
#
# Q 57*86 -   4384  T   4902 not ok
#
# Q 88*68 -   5772  T   5984 not ok
#
# Q 82*49 -   4778  T   4018 not ok
#
# Q 71*4 -    374  T    284 not ok
#
#
# --------------------------------------------------
# Iteration 12
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 265us/step - loss: 0.1420 - acc: 0.1944 - val_loss: 0.6734 - val_acc: 0.7560
# 27000/27000 [==============================] - 7s 265us/step - loss: 0.1420 - acc: 0.1944 - val_loss: 0.6734 - val_acc: 0.7560
# Examples:
# (10, 10, 15)
# Q 73*69 -   4227  T   5037 not ok
#
# Q 41*22 -    682  T    902 not ok
#
# Q 19*83 -   1457  T   1577 not ok
#
# Q 2*61 -     82  T    122 not ok
#
# Q 75*91 -   6255  T   6825 not ok
#
# Q 1*86 -     86  T     86 ok
#
# Q 10*36 -    460  T    360 not ok
#
# Q 70*32 -   2340  T   2240 not ok
#
# Q 73*93 -   6229  T   6789 not ok
#
# Q 22*3 -     66  T     66 ok
#
#
# --------------------------------------------------
# Iteration 13
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1228 - acc: 0.1981Examples:
# (10, 10, 15)
# Q 73*69 -   4227  T   5037 not ok
#
# Q 41*22 -    682  T    902 not ok
#
# Q 19*83 -   1457  T   1577 not ok
#
# Q 2*61 -     82  T    122 not ok
#
# Q 75*91 -   6255  T   6825 not ok
#
# Q 1*86 -     86  T     86 ok
#
# Q 10*36 -    460  T    360 not ok
#
# Q 70*32 -   2340  T   2240 not ok
#
# Q 73*93 -   6229  T   6789 not ok
#
# Q 22*3 -     66  T     66 ok
#
#
# --------------------------------------------------
# Iteration 13
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 255us/step - loss: 0.1363 - acc: 0.1964 - val_loss: 0.7695 - val_acc: 0.7450
# 27000/27000 [==============================] - 7s 255us/step - loss: 0.1363 - acc: 0.1964 - val_loss: 0.7695 - val_acc: 0.7450
# Examples:
# (10, 10, 15)
# Q 74*10 -    840  T    740 not ok
#
# Q 73*86 -   6222  T   6278 not ok
#
# Q 58*82 -   4312  T   4756 not ok
#
# Q 14*45 -    740  T    630 not ok
#
# Q 94*32 -   2068  T   3008 not ok
#
# Q 53*94 -   4222  T   4982 not ok
#
# Q 53*76 -   4248  T   4028 not ok
#
# Q 31*12 -    302  T    372 not ok
#
# Q 45*94 -   4240  T   4230 not ok
#
# Q 27*25 -    810  T    675 not ok
#
#
# --------------------------------------------------
# Iteration 14
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1466 - acc: 0.2087Examples:
# (10, 10, 15)
# Q 74*10 -    840  T    740 not ok
#
# Q 73*86 -   6222  T   6278 not ok
#
# Q 58*82 -   4312  T   4756 not ok
#
# Q 14*45 -    740  T    630 not ok
#
# Q 94*32 -   2068  T   3008 not ok
#
# Q 53*94 -   4222  T   4982 not ok
#
# Q 53*76 -   4248  T   4028 not ok
#
# Q 31*12 -    302  T    372 not ok
#
# Q 45*94 -   4240  T   4230 not ok
#
# Q 27*25 -    810  T    675 not ok
#
#
# --------------------------------------------------
# Iteration 14
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 268us/step - loss: 0.1308 - acc: 0.1978 - val_loss: 0.5906 - val_acc: 0.7777
# 27000/27000 [==============================] - 7s 268us/step - loss: 0.1308 - acc: 0.1978 - val_loss: 0.5906 - val_acc: 0.7777
# Examples:
# (10, 10, 15)
# Q 25*70 -   1550  T   1750 not ok
#
# Q 49*9 -    331  T    441 not ok
#
# Q 72*10 -     20  T    720 not ok
#
# Q 80*68 -   5240  T   5440 not ok
#
# Q 33*2 -     66  T     66 ok
#
# Q 83*81 -   6513  T   6723 not ok
#
# Q 73*66 -   5418  T   4818 not ok
#
# Q 48*87 -   3296  T   4176 not ok
#
# Q 56*8 -    448  T    448 ok
#
# Q 19*6 -    114  T    114 ok
#
#
# --------------------------------------------------
# Iteration 15
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1303 - acc: 0.1948Examples:
# (10, 10, 15)
# Q 25*70 -   1550  T   1750 not ok
#
# Q 49*9 -    331  T    441 not ok
#
# Q 72*10 -     20  T    720 not ok
#
# Q 80*68 -   5240  T   5440 not ok
#
# Q 33*2 -     66  T     66 ok
#
# Q 83*81 -   6513  T   6723 not ok
#
# Q 73*66 -   5418  T   4818 not ok
#
# Q 48*87 -   3296  T   4176 not ok
#
# Q 56*8 -    448  T    448 ok
#
# Q 19*6 -    114  T    114 ok
#
#
# --------------------------------------------------
# Iteration 15
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 270us/step - loss: 0.1296 - acc: 0.1984 - val_loss: 0.5622 - val_acc: 0.7836
# 27000/27000 [==============================] - 7s 270us/step - loss: 0.1296 - acc: 0.1984 - val_loss: 0.5622 - val_acc: 0.7836
# Examples:
# (10, 10, 15)
# Q 46*72 -   3192  T   3312 not ok
#
# Q 39*57 -   2283  T   2223 not ok
#
# Q 1*7 -      7  T      7 ok
#
# Q 50*13 -    550  T    650 not ok
#
# Q 88*9 -    794  T    792 not ok
#
# Q 57*27 -   1519  T   1539 not ok
#
# Q 41*97 -   3417  T   3977 not ok
#
# Q 10*13 -    130  T    130 ok
#
# Q 84*99 -   7796  T   8316 not ok
#
# Q 3*72 -    214  T    216 not ok
#
#
# --------------------------------------------------
# Iteration 16
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 5s - loss: 0.1352 - acc: 0.1953Examples:
# (10, 10, 15)
# Q 46*72 -   3192  T   3312 not ok
#
# Q 39*57 -   2283  T   2223 not ok
#
# Q 1*7 -      7  T      7 ok
#
# Q 50*13 -    550  T    650 not ok
#
# Q 88*9 -    794  T    792 not ok
#
# Q 57*27 -   1519  T   1539 not ok
#
# Q 41*97 -   3417  T   3977 not ok
#
# Q 10*13 -    130  T    130 ok
#
# Q 84*99 -   7796  T   8316 not ok
#
# Q 3*72 -    214  T    216 not ok
#
#
# --------------------------------------------------
# Iteration 16
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 261us/step - loss: 0.1283 - acc: 0.1983 - val_loss: 0.6607 - val_acc: 0.7631
# 27000/27000 [==============================] - 7s 261us/step - loss: 0.1283 - acc: 0.1983 - val_loss: 0.6607 - val_acc: 0.7631
# Examples:
# (10, 10, 15)
# Q 57*27 -   1439  T   1539 not ok
#
# Q 83*79 -   6427  T   6557 not ok
#
# Q 61*2 -    182  T    122 not ok
#
# Q 83*10 -    830  T    830 ok
#
# Q 80*61 -   4840  T   4880 not ok
#
# Q 50*97 -   4750  T   4850 not ok
#
# Q 28*3 -     64  T     84 not ok
#
# Q 78*49 -   3772  T   3822 not ok
#
# Q 66*34 -   2244  T   2244 ok
#
# Q 53*84 -   4742  T   4452 not ok
#
#
# --------------------------------------------------
# Iteration 17
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 4s - loss: 0.1462 - acc: 0.2489Examples:
# (10, 10, 15)
# Q 57*27 -   1439  T   1539 not ok
#
# Q 83*79 -   6427  T   6557 not ok
#
# Q 61*2 -    182  T    122 not ok
#
# Q 83*10 -    830  T    830 ok
#
# Q 80*61 -   4840  T   4880 not ok
#
# Q 50*97 -   4750  T   4850 not ok
#
# Q 28*3 -     64  T     84 not ok
#
# Q 78*49 -   3772  T   3822 not ok
#
# Q 66*34 -   2244  T   2244 ok
#
# Q 53*84 -   4742  T   4452 not ok
#
#
# --------------------------------------------------
# Iteration 17
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 267us/step - loss: 0.1273 - acc: 0.1987 - val_loss: 0.5022 - val_acc: 0.7981
# 27000/27000 [==============================] - 7s 267us/step - loss: 0.1273 - acc: 0.1987 - val_loss: 0.5022 - val_acc: 0.7981
# Examples:
# (10, 10, 15)
# Q 1*40 -     40  T     40 ok
#
# Q 84*46 -   3244  T   3864 not ok
#
# Q 25*20 -    500  T    500 ok
#
# Q 30*31 -    830  T    930 not ok
#
# Q 50*38 -   1500  T   1900 not ok
#
# Q 49*3 -    177  T    147 not ok
#
# Q 71*55 -   3725  T   3905 not ok
#
# Q 47*96 -   4362  T   4512 not ok
#
# Q 90*73 -   7770  T   6570 not ok
#
# Q 63*76 -   4208  T   4788 not ok
#
#
# --------------------------------------------------
# Iteration 18
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1276 - acc: 0.2204Examples:
# (10, 10, 15)
# Q 1*40 -     40  T     40 ok
#
# Q 84*46 -   3244  T   3864 not ok
#
# Q 25*20 -    500  T    500 ok
#
# Q 30*31 -    830  T    930 not ok
#
# Q 50*38 -   1500  T   1900 not ok
#
# Q 49*3 -    177  T    147 not ok
#
# Q 71*55 -   3725  T   3905 not ok
#
# Q 47*96 -   4362  T   4512 not ok
#
# Q 90*73 -   7770  T   6570 not ok
#
# Q 63*76 -   4208  T   4788 not ok
#
#
# --------------------------------------------------
# Iteration 18
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 264us/step - loss: 0.1202 - acc: 0.2011 - val_loss: 0.4991 - val_acc: 0.8010
# 27000/27000 [==============================] - 7s 264us/step - loss: 0.1202 - acc: 0.2011 - val_loss: 0.4991 - val_acc: 0.8010
# Examples:
# (10, 10, 15)
# Q 2*56 -    112  T    112 ok
#
# Q 45*32 -   1400  T   1440 not ok
#
# Q 45*7 -    265  T    315 not ok
#
# Q 30*77 -   2410  T   2310 not ok
#
# Q 86*41 -   3846  T   3526 not ok
#
# Q 33*9 -    287  T    297 not ok
#
# Q 49*90 -   4810  T   4410 not ok
#
# Q 31*84 -   2944  T   2604 not ok
#
# Q 19*88 -   1552  T   1672 not ok
#
# Q 38*72 -   2556  T   2736 not ok
#
#
# --------------------------------------------------
# Iteration 19
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 8s - loss: 0.1185 - acc: 0.2015Examples:
# (10, 10, 15)
# Q 2*56 -    112  T    112 ok
#
# Q 45*32 -   1400  T   1440 not ok
#
# Q 45*7 -    265  T    315 not ok
#
# Q 30*77 -   2410  T   2310 not ok
#
# Q 86*41 -   3846  T   3526 not ok
#
# Q 33*9 -    287  T    297 not ok
#
# Q 49*90 -   4810  T   4410 not ok
#
# Q 31*84 -   2944  T   2604 not ok
#
# Q 19*88 -   1552  T   1672 not ok
#
# Q 38*72 -   2556  T   2736 not ok
#
#
# --------------------------------------------------
# Iteration 19
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 264us/step - loss: 0.1170 - acc: 0.2020 - val_loss: 0.5379 - val_acc: 0.7900
# 27000/27000 [==============================] - 7s 264us/step - loss: 0.1170 - acc: 0.2020 - val_loss: 0.5379 - val_acc: 0.7900
# Examples:
# (10, 10, 15)
# Q 41*31 -   1211  T   1271 not ok
#
# Q 43*44 -   2292  T   1892 not ok
#
# Q 86*28 -   2648  T   2408 not ok
#
# Q 82*98 -   7996  T   8036 not ok
#
# Q 57*41 -   2997  T   2337 not ok
#
# Q 73*78 -   5914  T   5694 not ok
#
# Q 45*12 -    530  T    540 not ok
#
# Q 62*59 -   3278  T   3658 not ok
#
# Q 67*1 -     77  T     67 not ok
#
# Q 49*25 -   1275  T   1225 not ok
#
#
# --------------------------------------------------
# Iteration 20
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1024 - acc: 0.1786Examples:
# (10, 10, 15)
# Q 41*31 -   1211  T   1271 not ok
#
# Q 43*44 -   2292  T   1892 not ok
#
# Q 86*28 -   2648  T   2408 not ok
#
# Q 82*98 -   7996  T   8036 not ok
#
# Q 57*41 -   2997  T   2337 not ok
#
# Q 73*78 -   5914  T   5694 not ok
#
# Q 45*12 -    530  T    540 not ok
#
# Q 62*59 -   3278  T   3658 not ok
#
# Q 67*1 -     77  T     67 not ok
#
# Q 49*25 -   1275  T   1225 not ok
#
#
# --------------------------------------------------
# Iteration 20
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 263us/step - loss: 0.1177 - acc: 0.2010 - val_loss: 0.5182 - val_acc: 0.7930
# 27000/27000 [==============================] - 7s 263us/step - loss: 0.1177 - acc: 0.2010 - val_loss: 0.5182 - val_acc: 0.7930
# Examples:
# (10, 10, 15)
# Q 38*63 -   2514  T   2394 not ok
#
# Q 39*71 -   2889  T   2769 not ok
#
# Q 73*95 -   6325  T   6935 not ok
#
# Q 31*60 -   1860  T   1860 ok
#
# Q 32*62 -   1564  T   1984 not ok
#
# Q 26*32 -    872  T    832 not ok
#
# Q 36*19 -    744  T    684 not ok
#
# Q 77*87 -   6631  T   6699 not ok
#
# Q 63*68 -   4544  T   4284 not ok
#
# Q 47*40 -   2680  T   1880 not ok
#
#
# --------------------------------------------------
# Iteration 21
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1267 - acc: 0.2294Examples:
# (10, 10, 15)
# Q 38*63 -   2514  T   2394 not ok
#
# Q 39*71 -   2889  T   2769 not ok
#
# Q 73*95 -   6325  T   6935 not ok
#
# Q 31*60 -   1860  T   1860 ok
#
# Q 32*62 -   1564  T   1984 not ok
#
# Q 26*32 -    872  T    832 not ok
#
# Q 36*19 -    744  T    684 not ok
#
# Q 77*87 -   6631  T   6699 not ok
#
# Q 63*68 -   4544  T   4284 not ok
#
# Q 47*40 -   2680  T   1880 not ok
#
#
# --------------------------------------------------
# Iteration 21
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 264us/step - loss: 0.1138 - acc: 0.2027 - val_loss: 0.4826 - val_acc: 0.8074
# 27000/27000 [==============================] - 7s 264us/step - loss: 0.1138 - acc: 0.2027 - val_loss: 0.4826 - val_acc: 0.8074
# Examples:
# (10, 10, 15)
# Q 80*71 -   5680  T   5680 ok
#
# Q 62*97 -   6494  T   6014 not ok
#
# Q 32*46 -   1452  T   1472 not ok
#
# Q 44*86 -   3244  T   3784 not ok
#
# Q 50*36 -   2800  T   1800 not ok
#
# Q 57*41 -   2857  T   2337 not ok
#
# Q 27*20 -    540  T    540 ok
#
# Q 42*13 -    546  T    546 ok
#
# Q 13*98 -   1154  T   1274 not ok
#
# Q 58*17 -    086  T    986 not ok
#
#
# --------------------------------------------------
# Iteration 22
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.0898 - acc: 0.2015Examples:
# (10, 10, 15)
# Q 80*71 -   5680  T   5680 ok
#
# Q 62*97 -   6494  T   6014 not ok
#
# Q 32*46 -   1452  T   1472 not ok
#
# Q 44*86 -   3244  T   3784 not ok
#
# Q 50*36 -   2800  T   1800 not ok
#
# Q 57*41 -   2857  T   2337 not ok
#
# Q 27*20 -    540  T    540 ok
#
# Q 42*13 -    546  T    546 ok
#
# Q 13*98 -   1154  T   1274 not ok
#
# Q 58*17 -    086  T    986 not ok
#
#
# --------------------------------------------------
# Iteration 22
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 271us/step - loss: 0.1199 - acc: 0.2013 - val_loss: 0.5251 - val_acc: 0.7909
# 27000/27000 [==============================] - 7s 271us/step - loss: 0.1199 - acc: 0.2013 - val_loss: 0.5251 - val_acc: 0.7909
# Examples:
# (10, 10, 15)
# Q 47*57 -   2339  T   2679 not ok
#
# Q 27*19 -    433  T    513 not ok
#
# Q 47*76 -   3352  T   3572 not ok
#
# Q 85*88 -   7660  T   7480 not ok
#
# Q 6*55 -    370  T    330 not ok
#
# Q 4*91 -    354  T    364 not ok
#
# Q 52*9 -    468  T    468 ok
#
# Q 76*57 -   4232  T   4332 not ok
#
# Q 17*52 -    854  T    884 not ok
#
# Q 92*70 -   6040  T   6440 not ok
#
#
# --------------------------------------------------
# Iteration 23
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1128 - acc: 0.1881Examples:
# (10, 10, 15)
# Q 47*57 -   2339  T   2679 not ok
#
# Q 27*19 -    433  T    513 not ok
#
# Q 47*76 -   3352  T   3572 not ok
#
# Q 85*88 -   7660  T   7480 not ok
#
# Q 6*55 -    370  T    330 not ok
#
# Q 4*91 -    354  T    364 not ok
#
# Q 52*9 -    468  T    468 ok
#
# Q 76*57 -   4232  T   4332 not ok
#
# Q 17*52 -    854  T    884 not ok
#
# Q 92*70 -   6040  T   6440 not ok
#
#
# --------------------------------------------------
# Iteration 23
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 263us/step - loss: 0.1147 - acc: 0.2023 - val_loss: 0.7034 - val_acc: 0.7560
# 27000/27000 [==============================] - 7s 263us/step - loss: 0.1147 - acc: 0.2023 - val_loss: 0.7034 - val_acc: 0.7560
# Examples:
# (10, 10, 15)
# Q 73*57 -   4451  T   4161 not ok
#
# Q 52*97 -   5414  T   5044 not ok
#
# Q 17*36 -    652  T    612 not ok
#
# Q 64*14 -    316  T    896 not ok
#
# Q 90*75 -   6550  T   6750 not ok
#
# Q 48*15 -    840  T    720 not ok
#
# Q 71*81 -   5291  T   5751 not ok
#
# Q 12*40 -    480  T    480 ok
#
# Q 51*22 -   1202  T   1122 not ok
#
# Q 62*60 -   4920  T   3720 not ok
#
#
# --------------------------------------------------
# Iteration 24
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 5s - loss: 0.1119 - acc: 0.1970Examples:
# (10, 10, 15)
# Q 73*57 -   4451  T   4161 not ok
#
# Q 52*97 -   5414  T   5044 not ok
#
# Q 17*36 -    652  T    612 not ok
#
# Q 64*14 -    316  T    896 not ok
#
# Q 90*75 -   6550  T   6750 not ok
#
# Q 48*15 -    840  T    720 not ok
#
# Q 71*81 -   5291  T   5751 not ok
#
# Q 12*40 -    480  T    480 ok
#
# Q 51*22 -   1202  T   1122 not ok
#
# Q 62*60 -   4920  T   3720 not ok
#
#
# --------------------------------------------------
# Iteration 24
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 269us/step - loss: 0.1104 - acc: 0.2039 - val_loss: 0.5257 - val_acc: 0.7890
# 27000/27000 [==============================] - 7s 269us/step - loss: 0.1104 - acc: 0.2039 - val_loss: 0.5257 - val_acc: 0.7890
# Examples:
# (10, 10, 15)
# Q 77*23 -   1051  T   1771 not ok
#
# Q 26*32 -    992  T    832 not ok
#
# Q 97*49 -   4653  T   4753 not ok
#
# Q 96*9 -    864  T    864 ok
#
# Q 8*25 -    200  T    200 ok
#
# Q 28*80 -   2240  T   2240 ok
#
# Q 38*49 -   1662  T   1862 not ok
#
# Q 45*32 -   1460  T   1440 not ok
#
# Q 80*41 -   3880  T   3280 not ok
#
# Q 1*95 -     95  T     95 ok
#
#
# --------------------------------------------------
# Iteration 25
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1025 - acc: 0.1931Examples:
# (10, 10, 15)
# Q 77*23 -   1051  T   1771 not ok
#
# Q 26*32 -    992  T    832 not ok
#
# Q 97*49 -   4653  T   4753 not ok
#
# Q 96*9 -    864  T    864 ok
#
# Q 8*25 -    200  T    200 ok
#
# Q 28*80 -   2240  T   2240 ok
#
# Q 38*49 -   1662  T   1862 not ok
#
# Q 45*32 -   1460  T   1440 not ok
#
# Q 80*41 -   3880  T   3280 not ok
#
# Q 1*95 -     95  T     95 ok
#
#
# --------------------------------------------------
# Iteration 25
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 264us/step - loss: 0.1079 - acc: 0.2042 - val_loss: 0.5097 - val_acc: 0.7981
# 27000/27000 [==============================] - 7s 264us/step - loss: 0.1079 - acc: 0.2042 - val_loss: 0.5097 - val_acc: 0.7981
# Examples:
# (10, 10, 15)
# Q 52*56 -   3292  T   2912 not ok
#
# Q 11*83 -    953  T    913 not ok
#
# Q 42*59 -   2498  T   2478 not ok
#
# Q 42*15 -    670  T    630 not ok
#
# Q 99*80 -   7920  T   7920 ok
#
# Q 37*33 -   1241  T   1221 not ok
#
# Q 57*97 -   5499  T   5529 not ok
#
# Q 85*87 -   7435  T   7395 not ok
#
# Q 93*75 -   7425  T   6975 not ok
#
# Q 48*87 -   4776  T   4176 not ok
#
#
# --------------------------------------------------
# Iteration 26
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.0957 - acc: 0.1936Examples:
# (10, 10, 15)
# Q 52*56 -   3292  T   2912 not ok
#
# Q 11*83 -    953  T    913 not ok
#
# Q 42*59 -   2498  T   2478 not ok
#
# Q 42*15 -    670  T    630 not ok
#
# Q 99*80 -   7920  T   7920 ok
#
# Q 37*33 -   1241  T   1221 not ok
#
# Q 57*97 -   5499  T   5529 not ok
#
# Q 85*87 -   7435  T   7395 not ok
#
# Q 93*75 -   7425  T   6975 not ok
#
# Q 48*87 -   4776  T   4176 not ok
#
#
# --------------------------------------------------
# Iteration 26
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 256us/step - loss: 0.1058 - acc: 0.2047 - val_loss: 0.4530 - val_acc: 0.8119
# 27000/27000 [==============================] - 7s 256us/step - loss: 0.1058 - acc: 0.2047 - val_loss: 0.4530 - val_acc: 0.8119
# Examples:
# (10, 10, 15)
# Q 51*19 -   1089  T    969 not ok
#
# Q 45*90 -   4750  T   4050 not ok
#
# Q 94*64 -   6056  T   6016 not ok
#
# Q 56*8 -    488  T    448 not ok
#
# Q 66*72 -   4032  T   4752 not ok
#
# Q 72*82 -   6084  T   5904 not ok
#
# Q 83*17 -   1531  T   1411 not ok
#
# Q 13*69 -    037  T    897 not ok
#
# Q 50*82 -   4700  T   4100 not ok
#
# Q 58*59 -   3882  T   3422 not ok
#
#
# --------------------------------------------------
# Iteration 27
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1014 - acc: 0.2070Examples:
# (10, 10, 15)
# Q 51*19 -   1089  T    969 not ok
#
# Q 45*90 -   4750  T   4050 not ok
#
# Q 94*64 -   6056  T   6016 not ok
#
# Q 56*8 -    488  T    448 not ok
#
# Q 66*72 -   4032  T   4752 not ok
#
# Q 72*82 -   6084  T   5904 not ok
#
# Q 83*17 -   1531  T   1411 not ok
#
# Q 13*69 -    037  T    897 not ok
#
# Q 50*82 -   4700  T   4100 not ok
#
# Q 58*59 -   3882  T   3422 not ok
#
#
# --------------------------------------------------
# Iteration 27
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 290us/step - loss: 0.1060 - acc: 0.2048 - val_loss: 0.4865 - val_acc: 0.8012
# 27000/27000 [==============================] - 8s 290us/step - loss: 0.1060 - acc: 0.2048 - val_loss: 0.4865 - val_acc: 0.8012
# Examples:
# (10, 10, 15)
# Q 33*21 -    693  T    693 ok
#
# Q 13*81 -    013  T   1053 not ok
#
# Q 58*8 -    404  T    464 not ok
#
# Q 82*80 -   6760  T   6560 not ok
#
# Q 16*18 -    368  T    288 not ok
#
# Q 74*85 -   6110  T   6290 not ok
#
# Q 75*32 -   2000  T   2400 not ok
#
# Q 48*17 -    936  T    816 not ok
#
# Q 86*23 -   2098  T   1978 not ok
#
# Q 74*70 -   5280  T   5180 not ok
#
#
# --------------------------------------------------
# Iteration 28
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 5s - loss: 0.0914 - acc: 0.1886Examples:
# (10, 10, 15)
# Q 33*21 -    693  T    693 ok
#
# Q 13*81 -    013  T   1053 not ok
#
# Q 58*8 -    404  T    464 not ok
#
# Q 82*80 -   6760  T   6560 not ok
#
# Q 16*18 -    368  T    288 not ok
#
# Q 74*85 -   6110  T   6290 not ok
#
# Q 75*32 -   2000  T   2400 not ok
#
# Q 48*17 -    936  T    816 not ok
#
# Q 86*23 -   2098  T   1978 not ok
#
# Q 74*70 -   5280  T   5180 not ok
#
#
# --------------------------------------------------
# Iteration 28
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 245us/step - loss: 0.1063 - acc: 0.2046 - val_loss: 0.5411 - val_acc: 0.7900
# 27000/27000 [==============================] - 7s 245us/step - loss: 0.1063 - acc: 0.2046 - val_loss: 0.5411 - val_acc: 0.7900
# Examples:
# (10, 10, 15)
# Q 47*23 -   1001  T   1081 not ok
#
# Q 9*13 -    117  T    117 ok
#
# Q 8*72 -    516  T    576 not ok
#
# Q 49*84 -   4216  T   4116 not ok
#
# Q 54*47 -   2218  T   2538 not ok
#
# Q 38*24 -    992  T    912 not ok
#
# Q 44*90 -   3560  T   3960 not ok
#
# Q 89*90 -   8810  T   8010 not ok
#
# Q 69*32 -   2808  T   2208 not ok
#
# Q 89*71 -   5059  T   6319 not ok
#
#
# --------------------------------------------------
# Iteration 29
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1350 - acc: 0.2121Examples:
# (10, 10, 15)
# Q 47*23 -   1001  T   1081 not ok
#
# Q 9*13 -    117  T    117 ok
#
# Q 8*72 -    516  T    576 not ok
#
# Q 49*84 -   4216  T   4116 not ok
#
# Q 54*47 -   2218  T   2538 not ok
#
# Q 38*24 -    992  T    912 not ok
#
# Q 44*90 -   3560  T   3960 not ok
#
# Q 89*90 -   8810  T   8010 not ok
#
# Q 69*32 -   2808  T   2208 not ok
#
# Q 89*71 -   5059  T   6319 not ok
#
#
# --------------------------------------------------
# Iteration 29
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 251us/step - loss: 0.1061 - acc: 0.2052 - val_loss: 0.4938 - val_acc: 0.8041
# 27000/27000 [==============================] - 7s 251us/step - loss: 0.1061 - acc: 0.2052 - val_loss: 0.4938 - val_acc: 0.8041
# Examples:
# (10, 10, 15)
# Q 95*6 -    610  T    570 not ok
#
# Q 92*16 -   1332  T   1472 not ok
#
# Q 27*66 -   1662  T   1782 not ok
#
# Q 46*75 -   3300  T   3450 not ok
#
# Q 7*66 -    422  T    462 not ok
#
# Q 43*87 -   3001  T   3741 not ok
#
# Q 61*26 -   1506  T   1586 not ok
#
# Q 33*9 -    317  T    297 not ok
#
# Q 14*85 -   1210  T   1190 not ok
#
# Q 47*7 -    309  T    329 not ok
#
#
# --------------------------------------------------
# Iteration 30
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.1030 - acc: 0.2260Examples:
# (10, 10, 15)
# Q 95*6 -    610  T    570 not ok
#
# Q 92*16 -   1332  T   1472 not ok
#
# Q 27*66 -   1662  T   1782 not ok
#
# Q 46*75 -   3300  T   3450 not ok
#
# Q 7*66 -    422  T    462 not ok
#
# Q 43*87 -   3001  T   3741 not ok
#
# Q 61*26 -   1506  T   1586 not ok
#
# Q 33*9 -    317  T    297 not ok
#
# Q 14*85 -   1210  T   1190 not ok
#
# Q 47*7 -    309  T    329 not ok
#
#
# --------------------------------------------------
# Iteration 30
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 248us/step - loss: 0.1052 - acc: 0.2054 - val_loss: 0.4717 - val_acc: 0.8061
# 27000/27000 [==============================] - 7s 248us/step - loss: 0.1052 - acc: 0.2054 - val_loss: 0.4717 - val_acc: 0.8061
# Examples:
# (10, 10, 15)
# Q 65*51 -   3805  T   3315 not ok
#
# Q 68*23 -   1524  T   1564 not ok
#
# Q 85*21 -   1825  T   1785 not ok
#
# Q 82*89 -   7118  T   7298 not ok
#
# Q 88*29 -   2712  T   2552 not ok
#
# Q 41*25 -   1015  T   1025 not ok
#
# Q 42*78 -   3116  T   3276 not ok
#
# Q 7*26 -    162  T    182 not ok
#
# Q 39*97 -   3663  T   3783 not ok
#
# Q 97*12 -   1164  T   1164 ok
#
#
# --------------------------------------------------
# Iteration 31
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.0896 - acc: 0.2081Examples:
# (10, 10, 15)
# Q 65*51 -   3805  T   3315 not ok
#
# Q 68*23 -   1524  T   1564 not ok
#
# Q 85*21 -   1825  T   1785 not ok
#
# Q 82*89 -   7118  T   7298 not ok
#
# Q 88*29 -   2712  T   2552 not ok
#
# Q 41*25 -   1015  T   1025 not ok
#
# Q 42*78 -   3116  T   3276 not ok
#
# Q 7*26 -    162  T    182 not ok
#
# Q 39*97 -   3663  T   3783 not ok
#
# Q 97*12 -   1164  T   1164 ok
#
#
# --------------------------------------------------
# Iteration 31
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 256us/step - loss: 0.1045 - acc: 0.2055 - val_loss: 0.4423 - val_acc: 0.8136
# 27000/27000 [==============================] - 7s 256us/step - loss: 0.1045 - acc: 0.2055 - val_loss: 0.4423 - val_acc: 0.8136
# Examples:
# (10, 10, 15)
# Q 49*9 -    481  T    441 not ok
#
# Q 62*84 -   5448  T   5208 not ok
#
# Q 81*19 -   1139  T   1539 not ok
#
# Q 85*89 -   7125  T   7565 not ok
#
# Q 89*51 -   4839  T   4539 not ok
#
# Q 89*19 -   1551  T   1691 not ok
#
# Q 45*79 -   3325  T   3555 not ok
#
# Q 84*53 -   4272  T   4452 not ok
#
# Q 17*42 -    754  T    714 not ok
#
# Q 32*82 -   2044  T   2624 not ok
#
#
# --------------------------------------------------
# Iteration 32
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 4s - loss: 0.0725 - acc: 0.1479Examples:
# (10, 10, 15)
# Q 49*9 -    481  T    441 not ok
#
# Q 62*84 -   5448  T   5208 not ok
#
# Q 81*19 -   1139  T   1539 not ok
#
# Q 85*89 -   7125  T   7565 not ok
#
# Q 89*51 -   4839  T   4539 not ok
#
# Q 89*19 -   1551  T   1691 not ok
#
# Q 45*79 -   3325  T   3555 not ok
#
# Q 84*53 -   4272  T   4452 not ok
#
# Q 17*42 -    754  T    714 not ok
#
# Q 32*82 -   2044  T   2624 not ok
#
#
# --------------------------------------------------
# Iteration 32
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 256us/step - loss: 0.1004 - acc: 0.2067 - val_loss: 0.4806 - val_acc: 0.8101
# 27000/27000 [==============================] - 7s 256us/step - loss: 0.1004 - acc: 0.2067 - val_loss: 0.4806 - val_acc: 0.8101
# Examples:
# (10, 10, 15)
# Q 71*81 -   5511  T   5751 not ok
#
# Q 95*46 -   4310  T   4370 not ok
#
# Q 14*8 -    112  T    112 ok
#
# Q 57*21 -   1317  T   1197 not ok
#
# Q 24*99 -   1656  T   2376 not ok
#
# Q 37*4 -    168  T    148 not ok
#
# Q 6*91 -    540  T    546 not ok
#
# Q 67*69 -   4003  T   4623 not ok
#
# Q 27*93 -   2011  T   2511 not ok
#
# Q 7*4 -     28  T     28 ok
#
#
# --------------------------------------------------
# Iteration 33
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 4s - loss: 0.1230 - acc: 0.2723Examples:
# (10, 10, 15)
# Q 71*81 -   5511  T   5751 not ok
#
# Q 95*46 -   4310  T   4370 not ok
#
# Q 14*8 -    112  T    112 ok
#
# Q 57*21 -   1317  T   1197 not ok
#
# Q 24*99 -   1656  T   2376 not ok
#
# Q 37*4 -    168  T    148 not ok
#
# Q 6*91 -    540  T    546 not ok
#
# Q 67*69 -   4003  T   4623 not ok
#
# Q 27*93 -   2011  T   2511 not ok
#
# Q 7*4 -     28  T     28 ok
#
#
# --------------------------------------------------
# Iteration 33
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 254us/step - loss: 0.0999 - acc: 0.2071 - val_loss: 0.4343 - val_acc: 0.8205
# 27000/27000 [==============================] - 7s 254us/step - loss: 0.0999 - acc: 0.2071 - val_loss: 0.4343 - val_acc: 0.8205
# Examples:
# (10, 10, 15)
# Q 36*58 -   2188  T   2088 not ok
#
# Q 80*81 -   6080  T   6480 not ok
#
# Q 85*46 -   3120  T   3910 not ok
#
# Q 82*15 -   1110  T   1230 not ok
#
# Q 54*81 -   4114  T   4374 not ok
#
# Q 37*34 -   1318  T   1258 not ok
#
# Q 93*56 -   5088  T   5208 not ok
#
# Q 90*51 -   4790  T   4590 not ok
#
# Q 76*29 -   2184  T   2204 not ok
#
# ...
# (10, 10, 15)
# Q 47*97 -   4459  T   4559 not ok
#
# Q 65*52 -   3360  T   3380 not ok
#
# Q 60*40 -   2400  T   2400 ok
#
# Q 55*90 -   4550  T   4950 not ok
#
# Q 44*53 -   2312  T   2332 not ok
#
# Q 77*88 -   6076  T   6776 not ok
#
# Q 24*70 -   1680  T   1680 ok
#
# Q 73*67 -   4051  T   4891 not ok
#
# Q 54*46 -   2344  T   2484 not ok
#
# Q 18*4 -     72  T     72 ok
#
#
# --------------------------------------------------
# Iteration 85
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 259us/step - loss: 0.0697 - acc: 0.2191 - val_loss: 0.3509 - val_acc: 0.8545
# 27000/27000 [==============================] - 7s 259us/step - loss: 0.0697 - acc: 0.2191 - val_loss: 0.3509 - val_acc: 0.8545
# Examples:
# (10, 10, 15)
# Q 46*18 -    748  T    828 not ok
#
# Q 29*32 -    988  T    928 not ok
#
# Q 18*49 -    842  T    882 not ok
#
# Q 1*40 -     40  T     40 ok
#
# Q 12*67 -    824  T    804 not ok
#
# Q 88*11 -    948  T    968 not ok
#
# Q 32*53 -   1676  T   1696 not ok
#
# Q 32*33 -   1036  T   1056 not ok
#
# Q 29*62 -   1778  T   1798 not ok
#
# Q 54*70 -   3780  T   3780 ok
#
#
# --------------------------------------------------
# Iteration 86
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.0655 - acc: 0.2299Examples:
# (10, 10, 15)
# Q 46*18 -    748  T    828 not ok
#
# Q 29*32 -    988  T    928 not ok
#
# Q 18*49 -    842  T    882 not ok
#
# Q 1*40 -     40  T     40 ok
#
# Q 12*67 -    824  T    804 not ok
#
# Q 88*11 -    948  T    968 not ok
#
# Q 32*53 -   1676  T   1696 not ok
#
# Q 32*33 -   1036  T   1056 not ok
#
# Q 29*62 -   1778  T   1798 not ok
#
# Q 54*70 -   3780  T   3780 ok
#
#
# --------------------------------------------------
# Iteration 86
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 260us/step - loss: 0.0694 - acc: 0.2192 - val_loss: 0.3384 - val_acc: 0.8601
# 27000/27000 [==============================] - 7s 260us/step - loss: 0.0694 - acc: 0.2192 - val_loss: 0.3384 - val_acc: 0.8601
# Examples:
# (10, 10, 15)
# Q 96*22 -   2192  T   2112 not ok
#
# Q 60*81 -   4860  T   4860 ok
#
# Q 24*84 -   2996  T   2016 not ok
#
# Q 61*33 -   1093  T   2013 not ok
#
# Q 97*38 -   3626  T   3686 not ok
#
# Q 72*60 -   4320  T   4320 ok
#
# Q 49*12 -    648  T    588 not ok
#
# Q 28*74 -   2092  T   2072 not ok
#
# Q 58*84 -   4892  T   4872 not ok
#
# Q 65*43 -   2995  T   2795 not ok
#
#
# --------------------------------------------------
# Iteration 87
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 8s - loss: 0.0550 - acc: 0.2003Examples:
# (10, 10, 15)
# Q 96*22 -   2192  T   2112 not ok
#
# Q 60*81 -   4860  T   4860 ok
#
# Q 24*84 -   2996  T   2016 not ok
#
# Q 61*33 -   1093  T   2013 not ok
#
# Q 97*38 -   3626  T   3686 not ok
#
# Q 72*60 -   4320  T   4320 ok
#
# Q 49*12 -    648  T    588 not ok
#
# Q 28*74 -   2092  T   2072 not ok
#
# Q 58*84 -   4892  T   4872 not ok
#
# Q 65*43 -   2995  T   2795 not ok
#
#
# --------------------------------------------------
# Iteration 87
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 259us/step - loss: 0.0670 - acc: 0.2203 - val_loss: 0.3341 - val_acc: 0.8629
# 27000/27000 [==============================] - 7s 259us/step - loss: 0.0670 - acc: 0.2203 - val_loss: 0.3341 - val_acc: 0.8629
# Examples:
# (10, 10, 15)
# Q 74*53 -   3922  T   3922 ok
#
# Q 69*10 -    690  T    690 ok
#
# Q 89*70 -   6030  T   6230 not ok
#
# Q 64*23 -   1472  T   1472 ok
#
# Q 56*7 -    392  T    392 ok
#
# Q 46*6 -    296  T    276 not ok
#
# Q 74*20 -   1480  T   1480 ok
#
# Q 21*55 -   1175  T   1155 not ok
#
# Q 4*74 -    296  T    296 ok
#
# Q 2*5 -     10  T     10 ok
#
#
# --------------------------------------------------
# Iteration 88
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 7s - loss: 0.0784 - acc: 0.2472Examples:
# (10, 10, 15)
# Q 74*53 -   3922  T   3922 ok
#
# Q 69*10 -    690  T    690 ok
#
# Q 89*70 -   6030  T   6230 not ok
#
# Q 64*23 -   1472  T   1472 ok
#
# Q 56*7 -    392  T    392 ok
#
# Q 46*6 -    296  T    276 not ok
#
# Q 74*20 -   1480  T   1480 ok
#
# Q 21*55 -   1175  T   1155 not ok
#
# Q 4*74 -    296  T    296 ok
#
# Q 2*5 -     10  T     10 ok
#
#
# --------------------------------------------------
# Iteration 88
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 257us/step - loss: 0.0685 - acc: 0.2196 - val_loss: 0.3661 - val_acc: 0.8516
# 27000/27000 [==============================] - 7s 257us/step - loss: 0.0685 - acc: 0.2196 - val_loss: 0.3661 - val_acc: 0.8516
# Examples:
# (10, 10, 15)
# Q 6*73 -    438  T    438 ok
#
# Q 67*1 -     67  T     67 ok
#
# Q 73*53 -   3979  T   3869 not ok
#
# Q 23*95 -   2125  T   2185 not ok
#
# Q 8*46 -    378  T    368 not ok
#
# Q 67*42 -   2054  T   2814 not ok
#
# Q 24*34 -    736  T    816 not ok
#
# Q 37*40 -   1480  T   1480 ok
#
# Q 72*34 -   2448  T   2448 ok
#
# Q 71*2 -    142  T    142 ok
#
#
# --------------------------------------------------
# Iteration 89
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 5s - loss: 0.0631 - acc: 0.2015Examples:
# (10, 10, 15)
# Q 6*73 -    438  T    438 ok
#
# Q 67*1 -     67  T     67 ok
#
# Q 73*53 -   3979  T   3869 not ok
#
# Q 23*95 -   2125  T   2185 not ok
#
# Q 8*46 -    378  T    368 not ok
#
# Q 67*42 -   2054  T   2814 not ok
#
# Q 24*34 -    736  T    816 not ok
#
# Q 37*40 -   1480  T   1480 ok
#
# Q 72*34 -   2448  T   2448 ok
#
# Q 71*2 -    142  T    142 ok
#
#
# --------------------------------------------------
# Iteration 89
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 266us/step - loss: 0.0673 - acc: 0.2203 - val_loss: 0.3437 - val_acc: 0.8592
# 27000/27000 [==============================] - 7s 266us/step - loss: 0.0673 - acc: 0.2203 - val_loss: 0.3437 - val_acc: 0.8592
# Examples:
# (10, 10, 15)
# Q 64*45 -   2980  T   2880 not ok
#
# Q 39*88 -   3312  T   3432 not ok
#
# Q 16*99 -   1564  T   1584 not ok
#
# Q 17*23 -    411  T    391 not ok
#
# Q 41*31 -   1111  T   1271 not ok
#
# Q 39*42 -   1618  T   1638 not ok
#
# Q 96*15 -   1340  T   1440 not ok
#
# Q 76*57 -   4332  T   4332 ok
#
# Q 97*12 -   1164  T   1164 ok
#
# Q 95*90 -   8850  T   8550 not ok
#
#
# --------------------------------------------------
# Iteration 90
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.0718 - acc: 0.2400Examples:
# (10, 10, 15)
# Q 64*45 -   2980  T   2880 not ok
#
# Q 39*88 -   3312  T   3432 not ok
#
# Q 16*99 -   1564  T   1584 not ok
#
# Q 17*23 -    411  T    391 not ok
#
# Q 41*31 -   1111  T   1271 not ok
#
# Q 39*42 -   1618  T   1638 not ok
#
# Q 96*15 -   1340  T   1440 not ok
#
# Q 76*57 -   4332  T   4332 ok
#
# Q 97*12 -   1164  T   1164 ok
#
# Q 95*90 -   8850  T   8550 not ok
#
#
# --------------------------------------------------
# Iteration 90
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 267us/step - loss: 0.0673 - acc: 0.2200 - val_loss: 0.3441 - val_acc: 0.8568
# 27000/27000 [==============================] - 7s 267us/step - loss: 0.0673 - acc: 0.2200 - val_loss: 0.3441 - val_acc: 0.8568
# Examples:
# (10, 10, 15)
# Q 80*42 -   3560  T   3360 not ok
#
# Q 92*86 -   7932  T   7912 not ok
#
# Q 76*71 -   5196  T   5396 not ok
#
# Q 86*54 -   4864  T   4644 not ok
#
# Q 42*21 -    822  T    882 not ok
#
# Q 66*41 -   2046  T   2706 not ok
#
# Q 82*45 -   3890  T   3690 not ok
#
# Q 39*21 -    799  T    819 not ok
#
# Q 8*31 -    248  T    248 ok
#
# Q 23*22 -    446  T    506 not ok
#
#
# --------------------------------------------------
# Iteration 91
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 4s - loss: 0.0769 - acc: 0.2238Examples:
# (10, 10, 15)
# Q 80*42 -   3560  T   3360 not ok
#
# Q 92*86 -   7932  T   7912 not ok
#
# Q 76*71 -   5196  T   5396 not ok
#
# Q 86*54 -   4864  T   4644 not ok
#
# Q 42*21 -    822  T    882 not ok
#
# Q 66*41 -   2046  T   2706 not ok
#
# Q 82*45 -   3890  T   3690 not ok
#
# Q 39*21 -    799  T    819 not ok
#
# Q 8*31 -    248  T    248 ok
#
# Q 23*22 -    446  T    506 not ok
#
#
# --------------------------------------------------
# Iteration 91
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 266us/step - loss: 0.0681 - acc: 0.2200 - val_loss: 0.3635 - val_acc: 0.8534
# 27000/27000 [==============================] - 7s 266us/step - loss: 0.0681 - acc: 0.2200 - val_loss: 0.3635 - val_acc: 0.8534
# Examples:
# (10, 10, 15)
# Q 54*92 -   5028  T   4968 not ok
#
# Q 72*4 -    228  T    288 not ok
#
# Q 29*65 -   1885  T   1885 ok
#
# Q 78*16 -   1248  T   1248 ok
#
# Q 28*15 -    460  T    420 not ok
#
# Q 80*64 -   5120  T   5120 ok
#
# Q 21*93 -   1913  T   1953 not ok
#
# Q 93*66 -   6118  T   6138 not ok
#
# Q 36*6 -    216  T    216 ok
#
# Q 77*59 -   4603  T   4543 not ok
#
#
# --------------------------------------------------
# Iteration 92
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 8s - loss: 0.0875 - acc: 0.2405Examples:
# (10, 10, 15)
# Q 54*92 -   5028  T   4968 not ok
#
# Q 72*4 -    228  T    288 not ok
#
# Q 29*65 -   1885  T   1885 ok
#
# Q 78*16 -   1248  T   1248 ok
#
# Q 28*15 -    460  T    420 not ok
#
# Q 80*64 -   5120  T   5120 ok
#
# Q 21*93 -   1913  T   1953 not ok
#
# Q 93*66 -   6118  T   6138 not ok
#
# Q 36*6 -    216  T    216 ok
#
# Q 77*59 -   4603  T   4543 not ok
#
#
# --------------------------------------------------
# Iteration 92
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 263us/step - loss: 0.0663 - acc: 0.2207 - val_loss: 0.3420 - val_acc: 0.8595
# 27000/27000 [==============================] - 7s 263us/step - loss: 0.0663 - acc: 0.2207 - val_loss: 0.3420 - val_acc: 0.8595
# Examples:
# (10, 10, 15)
# Q 54*81 -   4324  T   4374 not ok
#
# Q 58*14 -    872  T    812 not ok
#
# Q 76*53 -   3988  T   4028 not ok
#
# Q 55*59 -   3295  T   3245 not ok
#
# Q 89*72 -   6648  T   6408 not ok
#
# Q 93*24 -   2232  T   2232 ok
#
# Q 83*10 -    830  T    830 ok
#
# Q 32*33 -   1096  T   1056 not ok
#
# Q 13*59 -    847  T    767 not ok
#
# Q 16*76 -   1176  T   1216 not ok
#
#
# --------------------------------------------------
# Iteration 93
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 5s - loss: 0.0597 - acc: 0.2098Examples:
# (10, 10, 15)
# Q 54*81 -   4324  T   4374 not ok
#
# Q 58*14 -    872  T    812 not ok
#
# Q 76*53 -   3988  T   4028 not ok
#
# Q 55*59 -   3295  T   3245 not ok
#
# Q 89*72 -   6648  T   6408 not ok
#
# Q 93*24 -   2232  T   2232 ok
#
# Q 83*10 -    830  T    830 ok
#
# Q 32*33 -   1096  T   1056 not ok
#
# Q 13*59 -    847  T    767 not ok
#
# Q 16*76 -   1176  T   1216 not ok
#
#
# --------------------------------------------------
# Iteration 93
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 257us/step - loss: 0.0680 - acc: 0.2198 - val_loss: 0.3735 - val_acc: 0.8546
# 27000/27000 [==============================] - 7s 257us/step - loss: 0.0680 - acc: 0.2198 - val_loss: 0.3735 - val_acc: 0.8546
# Examples:
# (10, 10, 15)
# Q 89*53 -   4757  T   4717 not ok
#
# Q 38*96 -   3588  T   3648 not ok
#
# Q 42*25 -   1950  T   1050 not ok
#
# Q 67*94 -   6138  T   6298 not ok
#
# Q 75*74 -   5150  T   5550 not ok
#
# Q 9*99 -    897  T    891 not ok
#
# Q 15*4 -     60  T     60 ok
#
# Q 17*44 -    788  T    748 not ok
#
# Q 62*96 -   5072  T   5952 not ok
#
# Q 53*49 -   2357  T   2597 not ok
#
#
# --------------------------------------------------
# Iteration 94
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
#   256/27000 [..............................] - ETA: 6s - loss: 0.0527 - acc: 0.2037Examples:
# (10, 10, 15)
# Q 89*53 -   4757  T   4717 not ok
#
# Q 38*96 -   3588  T   3648 not ok
#
# Q 42*25 -   1950  T   1050 not ok
#
# Q 67*94 -   6138  T   6298 not ok
#
# Q 75*74 -   5150  T   5550 not ok
#
# Q 9*99 -    897  T    891 not ok
#
# Q 15*4 -     60  T     60 ok
#
# Q 17*44 -    788  T    748 not ok
#
# Q 62*96 -   5072  T   5952 not ok
#
# Q 53*49 -   2357  T   2597 not ok
#
#
# --------------------------------------------------
# Iteration 94
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 279us/step - loss: 0.0666 - acc: 0.2203 - val_loss: 0.3551 - val_acc: 0.8575
# Examples:
# (10, 10, 15)
# Q 93*64 -   5932  T   5952 not ok
#
# Q 58*8 -    464  T    464 ok
#
# Q 32*96 -   3992  T   3072 not ok
#
# Q 25*96 -   2300  T   2400 not ok
#
# Q 37*11 -    307  T    407 not ok
#
# Q 72*70 -   4840  T   5040 not ok
#
# Q 46*54 -   2364  T   2484 not ok
#
# Q 67*93 -   6391  T   6231 not ok
#
# Q 62*95 -   5790  T   5890 not ok
#
# Q 47*50 -   2350  T   2350 ok
#
#
# --------------------------------------------------
# Iteration 95
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 285us/step - loss: 0.0662 - acc: 0.2206 - val_loss: 0.3296 - val_acc: 0.8621
# Examples:
# (10, 10, 15)
# Q 24*33 -    792  T    792 ok
#
# Q 13*82 -   1026  T   1066 not ok
#
# Q 74*38 -   2752  T   2812 not ok
#
# Q 32*16 -    532  T    512 not ok
#
# Q 72*54 -   3968  T   3888 not ok
#
# Q 88*1 -     88  T     88 ok
#
# Q 16*50 -    800  T    800 ok
#
# Q 18*10 -    180  T    180 ok
#
# Q 66*38 -   2528  T   2508 not ok
#
# Q 52*36 -   1852  T   1872 not ok
#
#
# --------------------------------------------------
# Iteration 96
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 264us/step - loss: 0.0658 - acc: 0.2205 - val_loss: 0.3697 - val_acc: 0.8531
# Examples:
# (10, 10, 15)
# Q 83*39 -   3117  T   3237 not ok
#
# Q 86*3 -    258  T    258 ok
#
# Q 88*90 -   7920  T   7920 ok
#
# Q 96*83 -   7848  T   7968 not ok
#
# Q 59*93 -   5327  T   5487 not ok
#
# Q 13*88 -   1124  T   1144 not ok
#
# Q 3*22 -     66  T     66 ok
#
# Q 41*6 -    246  T    246 ok
#
# Q 78*39 -   2982  T   3042 not ok
#
# Q 20*30 -    600  T    600 ok
#
#
# --------------------------------------------------
# Iteration 97
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 8s 278us/step - loss: 0.0781 - acc: 0.2174 - val_loss: 0.4004 - val_acc: 0.8437
# Examples:
# (10, 10, 15)
# Q 74*18 -   1212  T   1332 not ok
#
# Q 1*76 -     76  T     76 ok
#
# Q 12*76 -    892  T    912 not ok
#
# Q 98*93 -   9174  T   9114 not ok
#
# Q 63*35 -   2205  T   2205 ok
#
# Q 47*73 -   3351  T   3431 not ok
#
# Q 66*9 -    554  T    594 not ok
#
# Q 53*75 -   4375  T   3975 not ok
#
# Q 91*31 -   2001  T   2821 not ok
#
# Q 90*87 -   7830  T   7830 ok
#
#
# --------------------------------------------------
# Iteration 98
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 260us/step - loss: 0.0717 - acc: 0.2187 - val_loss: 0.4333 - val_acc: 0.8383
# Examples:
# (10, 10, 15)
# Q 15*20 -    300  T    300 ok
#
# Q 61*13 -    893  T    793 not ok
#
# Q 53*16 -    888  T    848 not ok
#
# Q 99*82 -   8038  T   8118 not ok
#
# Q 24*8 -    192  T    192 ok
#
# Q 67*8 -    556  T    536 not ok
#
# Q 68*66 -   4828  T   4488 not ok
#
# Q 70*30 -   2200  T   2100 not ok
#
# Q 9*51 -    451  T    459 not ok
#
# Q 41*38 -   1558  T   1558 ok
#
#
# --------------------------------------------------
# Iteration 99
# Train on 27000 samples, validate on 3000 samples
# Epoch 1/1
# 27000/27000 [==============================] - 7s 266us/step - loss: 0.0678 - acc: 0.2203 - val_loss: 0.3388 - val_acc: 0.8602
# Examples:
# (10, 10, 15)
# Q 69*73 -   5017  T   5037 not ok
#
# Q 15*46 -    630  T    690 not ok
#
# Q 42*53 -   2166  T   2226 not ok
#
# Q 28*94 -   2692  T   2632 not ok
#
# Q 13*49 -    637  T    637 ok
#
# Q 52*90 -   4680  T   4680 ok
#
# Q 62*76 -   4652  T   4712 not ok
#
# Q 43*95 -   4005  T   4085 not ok
#
# Q 88*89 -   7752  T   7832 not ok
#
# Q 84*38 -   3192  T   3192 ok

# %%
## seq2seq 学习乘法是比较困难的
## 尽管在train过程中 loss 很低 但是 acc 同样很低
## 在针对两位数的乘法训练，seq2seq 已经比较难以拟合结果
## 它会比较容易学习 10的倍数的数相乘，比如52*90
## 观察实验结果可以发现seq2seq，在错误的例子中业与正确答案有2-3个数字一样
## 可能需要跟复杂的模型才能解决这个问题。
## 比如 CGRU
